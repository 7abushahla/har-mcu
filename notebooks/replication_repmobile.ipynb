# %% [markdown]
# # Replication Notebook — RepMobile (WISDM-first)

# %% [markdown]
# ## Paper Facts and Code Availability
# - Paper DOI: https://doi.org/10.1109/JSEN.2024.3424578
# - Official repo: https://github.com/Yuki0614/RepMobile
# - Original protocol summary: structural reparameterization with folded inference graph.
#
# ## WISDM Adaptation
# - Active config: `configs/papers/repmobile_wisdm.yaml`
# - This notebook runs WISDM-first adaptation while preserving paper architecture intent.

# %% [markdown]
# ## Notebook Contract
# - Runtime / dependency guard
# - Paper facts + code availability
# - WISDM adaptation section
# - FP32 training/eval on `random_stratified` + `user_holdout`
# - PTQ INT8 + QAT INT8 exports
# - FP32 float `.tflite` export for size tracking (`fp32_model_size_kb`)
# - Strict deploy-gate summary (`full_integer_io`, `tflm_compatible`, unsupported ops)
# - Per-paper CSV/MD + master results append

# %% [markdown]
# ## Compression Scope Note
# - KD-related methodology from papers is documented for reproducibility context only.
# - Notebook execution enforces PTQ/QAT compression flow only (`experiment.compression_focus=ptq_qat_only`).
# - This notebook uses a Conv2D-equivalent architecture for QAT compatibility; Conv1D paper operators are preserved semantically via `(k)->(k,1)` mapping.

# %%
from pathlib import Path
import sys
import os
import json
import importlib
import importlib.util

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, Markdown, display

# Optional safeguard: disable GPU if kernel is unstable on CUDA runtime.
USE_GPU = True
if not USE_GPU:
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Ensure repo root is importable when launched from different working directories.
REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "src").exists():
    for parent in [REPO_ROOT, *REPO_ROOT.parents]:
        if (parent / "src").exists():
            REPO_ROOT = parent
            break
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

required_modules = {
    "numpy": "numpy",
    "pandas": "pandas",
    "matplotlib": "matplotlib",
    "IPython": "ipython",
    "yaml": "PyYAML",
    "sklearn": "scikit-learn",
    "tensorflow": "tensorflow",
    "tensorflow_model_optimization": "tensorflow-model-optimization",
}
missing = [
    f"{mod} (pip package: {pkg})"
    for mod, pkg in required_modules.items()
    if importlib.util.find_spec(mod) is None
]
if missing:
    missing_text = "\n- ".join(missing)
    raise ModuleNotFoundError(
        "Missing required notebook dependencies:\n- "
        + missing_text
        + "\n\nActivate tinymlproj and install dependencies:\n"
        + "conda activate tinymlproj && conda env update -n tinymlproj -f environment.yml --prune"
    )

import tensorflow as tf
print("TF version:", tf.__version__)
print("Visible GPUs:", tf.config.list_physical_devices("GPU"))

# Fail fast if local file is stale (pre-FP32-TFLite-size patch).
_rpe_file = REPO_ROOT / "src/run_paper_experiment.py"
if _rpe_file.exists():
    _rpe_src = _rpe_file.read_text(encoding="utf-8")
    if "from src.utils.artifacts import model_fp32_tflite_path" in _rpe_src:
        raise RuntimeError(
            "Outdated src/run_paper_experiment.py detected in workspace. "
            "Please refresh repo files and rerun from the first cell."
        )

importlib.invalidate_caches()
for _stale_mod in ("src.run_paper_experiment",):
    sys.modules.pop(_stale_mod, None)

AUTO_RELOAD_PROJECT_MODULES = True
if AUTO_RELOAD_PROJECT_MODULES:
    for _mod_name in (
        "src.models.xtinyhar_student_tf",
        "src.models.repmobile_folded_tf",
        "src.models.tcn_attention_har_tf",
        "src.models.daghero_cnn_searchspace_tf",
        "src.models.tcn_inception_tf",
        "src.models.serialization",
        "src.eval.evaluate_model",
        "src.quant.ptq_full_int8",
        "src.quant.qat_train",
        "src.utils.artifacts",
        "src.eval.notebook_reporting",
        "src.run_paper_experiment",
    ):
        if _mod_name in sys.modules:
            importlib.reload(sys.modules[_mod_name])

import src.run_paper_experiment as _run_mod
run_paper_experiment = _run_mod.run_paper_experiment

from src.utils.config import load_yaml
from src.utils.device_runtime import runtime_device_report
from src.eval.evaluate_model import evaluate_model_for_protocol
from src.utils.artifacts import model_ckpt_path, split_npz_path

if "load_checkpoint_model" not in evaluate_model_for_protocol.__code__.co_names:
    raise RuntimeError(
        "Stale evaluate_model module detected (safe loader missing). "
        "Restart kernel and rerun from the first cell."
    )

RUN_MODE = "sanity_check"  # switch to "full_run" for full-length runs (GPU-first, CPU fallback enabled)
CONFIG_PATH = REPO_ROOT / 'configs/papers/repmobile_wisdm.yaml'
assert CONFIG_PATH.exists(), f"Missing config: {CONFIG_PATH}"
cfg = load_yaml(CONFIG_PATH)
cfg.setdefault("runtime", {})["run_mode"] = RUN_MODE
cfg.setdefault("experiment", {})["compression_focus"] = "ptq_qat_only"
runtime = runtime_device_report(cfg)

print("repo_root:", REPO_ROOT)
print("paper_slug:", cfg.get("experiment", {}).get("paper_slug"))
print("model_variant:", cfg.get("experiment", {}).get("model_variant"))
is_conv2d_variant = str(cfg.get("experiment", {}).get("model_variant", "")).endswith("_conv2d")
print("conv2d_qat_safe_variant:", is_conv2d_variant)
print("[NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.")
if not is_conv2d_variant:
    print("[WARN] Active model_variant is not *_conv2d; QAT may fail on Conv1D/SeparableConv1D in tfmot 0.8.")
print("window_size:", cfg.get("paper_protocol", {}).get("wisdm_window_override"))
print("run_mode:", runtime["run_mode"])
print("detected_gpus:", runtime["gpus"])
print("stage_device_map:", runtime["resolved_stage_devices"])
print("[NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.")

strict_gate_cfg = {
    "ptq_strict_full_int8": bool(cfg.get("quant", {}).get("ptq", {}).get("strict_full_int8", True)),
    "ptq_require_tflm_compatible": bool(cfg.get("quant", {}).get("ptq", {}).get("require_tflm_compatible", True)),
    "ptq_accepted_integer_io_dtypes": cfg.get("quant", {}).get("ptq", {}).get("accepted_integer_io_dtypes", ["int8", "uint8"]),
    "qat_strict_full_int8": bool(cfg.get("quant", {}).get("qat", {}).get("strict_full_int8", True)),
    "qat_require_tflm_compatible": bool(cfg.get("quant", {}).get("qat", {}).get("require_tflm_compatible", True)),
    "qat_accepted_integer_io_dtypes": cfg.get("quant", {}).get("qat", {}).get("accepted_integer_io_dtypes", ["int8", "uint8"]),
    "deploy_allowed_ops_profile": cfg.get("deploy", {}).get("allowed_ops_profile", "default"),
    "deploy_allowed_ops_override": cfg.get("deploy", {}).get("allowed_ops"),
}
print("strict_gate_cfg:", strict_gate_cfg)
# Out:
# 2026-03-05 02:09:47.636928: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-05 02:09:47.636978: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-05 02:09:47.637015: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-05 02:09:47.645236: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TF version: 2.14.1
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-03-05 02:09:48.852890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:48.860147: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:48.860192: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# repo_root: /home/dellio/github/har-mcu
# paper_slug: repmobile
# model_variant: repmobile_folded_conv2d
# conv2d_qat_safe_variant: True
# [NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.
# window_size: 200
# run_mode: sanity_check
# detected_gpus: ['/physical_device:GPU:0']
# stage_device_map: {'train': 'gpu', 'eval_fp32': 'gpu', 'ptq': 'gpu', 'eval_ptq': 'gpu', 'qat': 'gpu', 'eval_qat': 'gpu'}
# [NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.
# strict_gate_cfg: {'ptq_strict_full_int8': True, 'ptq_require_tflm_compatible': True, 'ptq_accepted_integer_io_dtypes': ['int8', 'uint8'], 'qat_strict_full_int8': True, 'qat_require_tflm_compatible': True, 'qat_accepted_integer_io_dtypes': ['int8', 'uint8'], 'deploy_allowed_ops_profile': 'nano33ble_extended', 'deploy_allowed_ops_override': None}

# %%
# Run FP32 + PTQ + QAT + standardized reporting
out = run_paper_experiment(cfg)
out
# Out:
# 2026-03-05 02:09:49.223021: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:49.223103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:49.223140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:49.440792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:49.440858: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:49.440870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-03-05 02:09:49.440917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:09:49.440944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19250 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:2d:00.0, compute capability: 8.6
# Epoch 1/40
# 2026-03-05 02:10:07.433139: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inrepmobile_folded_conv2d/repblock_0_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-03-05 02:10:07.678916: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2026-03-05 02:10:08.606860: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x64afae80fab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-05 02:10:08.606905: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2026-03-05 02:10:08.706816: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 - 4s - loss: 1.6602 - accuracy: 0.2759 - val_loss: 1.7835 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 4s/epoch - 83ms/step
# Epoch 2/40
# 42/42 - 0s - loss: 1.5329 - accuracy: 0.3713 - val_loss: 1.7725 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 425ms/epoch - 10ms/step
# Epoch 3/40
# 42/42 - 0s - loss: 1.4295 - accuracy: 0.4800 - val_loss: 1.7606 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 415ms/epoch - 10ms/step
# Epoch 4/40
# 42/42 - 0s - loss: 1.3449 - accuracy: 0.5862 - val_loss: 1.7476 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 414ms/epoch - 10ms/step
# Epoch 5/40
# 42/42 - 0s - loss: 1.2837 - accuracy: 0.6416 - val_loss: 1.7338 - val_accuracy: 0.4069 - lr: 1.0000e-04 - 434ms/epoch - 10ms/step
# Epoch 6/40
# 42/42 - 0s - loss: 1.2356 - accuracy: 0.6618 - val_loss: 1.7187 - val_accuracy: 0.4084 - lr: 1.0000e-04 - 411ms/epoch - 10ms/step
# Epoch 7/40
# 42/42 - 0s - loss: 1.1897 - accuracy: 0.6740 - val_loss: 1.7012 - val_accuracy: 0.4091 - lr: 1.0000e-04 - 410ms/epoch - 10ms/step
# Epoch 8/40
# 42/42 - 0s - loss: 1.1533 - accuracy: 0.6813 - val_loss: 1.6770 - val_accuracy: 0.4159 - lr: 1.0000e-04 - 422ms/epoch - 10ms/step
# Epoch 9/40
# 42/42 - 0s - loss: 1.1211 - accuracy: 0.6818 - val_loss: 1.6395 - val_accuracy: 0.4308 - lr: 1.0000e-04 - 434ms/epoch - 10ms/step
# Epoch 10/40
# 42/42 - 0s - loss: 1.0988 - accuracy: 0.6826 - val_loss: 1.5802 - val_accuracy: 0.4488 - lr: 1.0000e-04 - 401ms/epoch - 10ms/step
# Epoch 11/40
# 42/42 - 0s - loss: 1.0697 - accuracy: 0.6902 - val_loss: 1.4955 - val_accuracy: 0.4936 - lr: 1.0000e-04 - 415ms/epoch - 10ms/step
# Epoch 12/40
# 42/42 - 0s - loss: 1.0544 - accuracy: 0.6884 - val_loss: 1.3932 - val_accuracy: 0.5542 - lr: 1.0000e-04 - 420ms/epoch - 10ms/step
# Epoch 13/40
# 42/42 - 0s - loss: 1.0371 - accuracy: 0.6893 - val_loss: 1.2871 - val_accuracy: 0.6088 - lr: 1.0000e-04 - 411ms/epoch - 10ms/step
# Epoch 14/40
# 42/42 - 0s - loss: 1.0172 - accuracy: 0.6938 - val_loss: 1.1933 - val_accuracy: 0.6589 - lr: 1.0000e-04 - 414ms/epoch - 10ms/step
# Epoch 15/40
# 42/42 - 0s - loss: 1.0036 - accuracy: 0.6887 - val_loss: 1.1174 - val_accuracy: 0.6844 - lr: 1.0000e-04 - 406ms/epoch - 10ms/step
# Epoch 16/40
# 42/42 - 0s - loss: 0.9844 - accuracy: 0.6958 - val_loss: 1.0607 - val_accuracy: 0.7023 - lr: 1.0000e-04 - 428ms/epoch - 10ms/step
# Epoch 17/40
# 42/42 - 0s - loss: 0.9726 - accuracy: 0.6951 - val_loss: 1.0194 - val_accuracy: 0.7105 - lr: 1.0000e-04 - 421ms/epoch - 10ms/step
# Epoch 18/40
# 42/42 - 0s - loss: 0.9617 - accuracy: 0.7003 - val_loss: 0.9876 - val_accuracy: 0.7143 - lr: 1.0000e-04 - 410ms/epoch - 10ms/step
# Epoch 19/40
# 42/42 - 0s - loss: 0.9532 - accuracy: 0.7022 - val_loss: 0.9641 - val_accuracy: 0.7165 - lr: 1.0000e-04 - 426ms/epoch - 10ms/step
# Epoch 20/40
# 42/42 - 0s - loss: 0.9439 - accuracy: 0.7033 - val_loss: 0.9454 - val_accuracy: 0.7225 - lr: 1.0000e-04 - 408ms/epoch - 10ms/step
# Epoch 21/40
# 42/42 - 0s - loss: 0.9267 - accuracy: 0.7043 - val_loss: 0.9299 - val_accuracy: 0.7263 - lr: 1.0000e-04 - 406ms/epoch - 10ms/step
# Epoch 22/40
# 42/42 - 0s - loss: 0.9193 - accuracy: 0.7095 - val_loss: 0.9164 - val_accuracy: 0.7300 - lr: 1.0000e-04 - 435ms/epoch - 10ms/step
# Epoch 23/40
# 42/42 - 0s - loss: 0.9071 - accuracy: 0.7106 - val_loss: 0.9049 - val_accuracy: 0.7315 - lr: 1.0000e-04 - 411ms/epoch - 10ms/step
# Epoch 24/40
# 42/42 - 0s - loss: 0.9001 - accuracy: 0.7142 - val_loss: 0.8956 - val_accuracy: 0.7345 - lr: 1.0000e-04 - 393ms/epoch - 9ms/step
# Epoch 25/40
# 42/42 - 0s - loss: 0.8898 - accuracy: 0.7147 - val_loss: 0.8862 - val_accuracy: 0.7337 - lr: 1.0000e-04 - 412ms/epoch - 10ms/step
# Epoch 26/40
# 42/42 - 0s - loss: 0.8831 - accuracy: 0.7250 - val_loss: 0.8772 - val_accuracy: 0.7352 - lr: 1.0000e-04 - 404ms/epoch - 10ms/step
# Epoch 27/40
# 42/42 - 0s - loss: 0.8786 - accuracy: 0.7209 - val_loss: 0.8685 - val_accuracy: 0.7382 - lr: 1.0000e-04 - 402ms/epoch - 10ms/step
# Epoch 28/40
# 42/42 - 0s - loss: 0.8680 - accuracy: 0.7271 - val_loss: 0.8609 - val_accuracy: 0.7420 - lr: 1.0000e-04 - 403ms/epoch - 10ms/step
# Epoch 29/40
# 42/42 - 0s - loss: 0.8578 - accuracy: 0.7306 - val_loss: 0.8536 - val_accuracy: 0.7442 - lr: 1.0000e-04 - 412ms/epoch - 10ms/step
# Epoch 30/40
# 42/42 - 0s - loss: 0.8522 - accuracy: 0.7342 - val_loss: 0.8465 - val_accuracy: 0.7442 - lr: 1.0000e-04 - 404ms/epoch - 10ms/step
# Epoch 31/40
# 42/42 - 0s - loss: 0.8442 - accuracy: 0.7379 - val_loss: 0.8394 - val_accuracy: 0.7472 - lr: 1.0000e-04 - 383ms/epoch - 9ms/step
# Epoch 32/40
# 42/42 - 0s - loss: 0.8388 - accuracy: 0.7377 - val_loss: 0.8327 - val_accuracy: 0.7674 - lr: 1.0000e-04 - 397ms/epoch - 9ms/step
# Epoch 33/40
# 42/42 - 0s - loss: 0.8322 - accuracy: 0.7391 - val_loss: 0.8259 - val_accuracy: 0.7696 - lr: 1.0000e-04 - 354ms/epoch - 8ms/step
# Epoch 34/40
# 42/42 - 0s - loss: 0.8244 - accuracy: 0.7430 - val_loss: 0.8193 - val_accuracy: 0.7719 - lr: 1.0000e-04 - 394ms/epoch - 9ms/step
# Epoch 35/40
# 42/42 - 0s - loss: 0.8186 - accuracy: 0.7486 - val_loss: 0.8128 - val_accuracy: 0.7734 - lr: 1.0000e-04 - 400ms/epoch - 10ms/step
# Epoch 36/40
# 42/42 - 0s - loss: 0.8175 - accuracy: 0.7435 - val_loss: 0.8070 - val_accuracy: 0.7756 - lr: 1.0000e-04 - 414ms/epoch - 10ms/step
# Epoch 37/40
# 42/42 - 0s - loss: 0.8061 - accuracy: 0.7484 - val_loss: 0.8017 - val_accuracy: 0.7756 - lr: 1.0000e-04 - 420ms/epoch - 10ms/step
# Epoch 38/40
# 42/42 - 0s - loss: 0.8000 - accuracy: 0.7531 - val_loss: 0.7959 - val_accuracy: 0.7771 - lr: 1.0000e-04 - 405ms/epoch - 10ms/step
# Epoch 39/40
# 42/42 - 0s - loss: 0.7979 - accuracy: 0.7559 - val_loss: 0.7909 - val_accuracy: 0.7779 - lr: 1.0000e-04 - 404ms/epoch - 10ms/step
# Epoch 40/40
# 42/42 - 0s - loss: 0.7862 - accuracy: 0.7594 - val_loss: 0.7855 - val_accuracy: 0.7779 - lr: 1.0000e-04 - 352ms/epoch - 8ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpuuiztnuy/assets
# INFO:tensorflow:Assets written to: /tmp/tmpuuiztnuy/assets
# 2026-03-05 02:10:28.768736: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:10:28.768777: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:10:28.769325: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpuuiztnuy
# 2026-03-05 02:10:28.773925: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:10:28.773941: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpuuiztnuy
# 2026-03-05 02:10:28.784996: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2026-03-05 02:10:28.786100: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:10:28.817460: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpuuiztnuy
# 2026-03-05 02:10:28.828885: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 59577 microseconds.
# 2026-03-05 02:10:28.853053: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# INFO:tensorflow:Assets written to: /tmp/tmpda7pt69u/assets
# INFO:tensorflow:Assets written to: /tmp/tmpda7pt69u/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:10:31.469371: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:10:31.469409: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:10:31.469574: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpda7pt69u
# 2026-03-05 02:10:31.471498: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:10:31.471510: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpda7pt69u
# 2026-03-05 02:10:31.475776: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:10:31.505144: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpda7pt69u
# 2026-03-05 02:10:31.517999: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 48424 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/8
# 42/42 - 5s - loss: 0.7701 - accuracy: 0.7623 - val_loss: 0.7158 - val_accuracy: 0.7846 - 5s/epoch - 112ms/step
# Epoch 2/8
# 42/42 - 2s - loss: 0.7181 - accuracy: 0.7782 - val_loss: 0.6778 - val_accuracy: 0.7883 - 2s/epoch - 47ms/step
# Epoch 3/8
# 42/42 - 2s - loss: 0.6799 - accuracy: 0.7924 - val_loss: 0.6426 - val_accuracy: 0.7913 - 2s/epoch - 46ms/step
# Epoch 4/8
# 42/42 - 2s - loss: 0.6506 - accuracy: 0.7955 - val_loss: 0.6101 - val_accuracy: 0.7988 - 2s/epoch - 44ms/step
# Epoch 5/8
# 42/42 - 2s - loss: 0.6217 - accuracy: 0.8047 - val_loss: 0.5898 - val_accuracy: 0.8003 - 2s/epoch - 48ms/step
# Epoch 6/8
# 42/42 - 2s - loss: 0.6016 - accuracy: 0.8085 - val_loss: 0.5737 - val_accuracy: 0.8018 - 2s/epoch - 49ms/step
# Epoch 7/8
# 42/42 - 2s - loss: 0.5784 - accuracy: 0.8101 - val_loss: 0.5602 - val_accuracy: 0.8010 - 2s/epoch - 46ms/step
# Epoch 8/8
# 42/42 - 2s - loss: 0.5628 - accuracy: 0.8113 - val_loss: 0.5459 - val_accuracy: 0.8063 - 2s/epoch - 49ms/step
# INFO:tensorflow:Assets written to: /tmp/tmp_s9_jxau/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_s9_jxau/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:10:56.463718: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:10:56.463760: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:10:56.463894: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp_s9_jxau
# 2026-03-05 02:10:56.468312: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:10:56.468326: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp_s9_jxau
# 2026-03-05 02:10:56.482770: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:10:56.566394: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp_s9_jxau
# 2026-03-05 02:10:56.592791: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 128896 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/40
# 42/42 - 2s - loss: 1.6594 - accuracy: 0.2686 - val_loss: 1.7822 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 2s/epoch - 39ms/step
# Epoch 2/40
# 42/42 - 0s - loss: 1.5391 - accuracy: 0.3601 - val_loss: 1.7702 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 406ms/epoch - 10ms/step
# Epoch 3/40
# 42/42 - 0s - loss: 1.4321 - accuracy: 0.4738 - val_loss: 1.7580 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 402ms/epoch - 10ms/step
# Epoch 4/40
# 42/42 - 0s - loss: 1.3536 - accuracy: 0.5705 - val_loss: 1.7453 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 417ms/epoch - 10ms/step
# Epoch 5/40
# 42/42 - 0s - loss: 1.2815 - accuracy: 0.6353 - val_loss: 1.7328 - val_accuracy: 0.4289 - lr: 1.0000e-04 - 402ms/epoch - 10ms/step
# Epoch 6/40
# 42/42 - 0s - loss: 1.2256 - accuracy: 0.6631 - val_loss: 1.7211 - val_accuracy: 0.4266 - lr: 1.0000e-04 - 426ms/epoch - 10ms/step
# Epoch 7/40
# 42/42 - 0s - loss: 1.1821 - accuracy: 0.6755 - val_loss: 1.7075 - val_accuracy: 0.4266 - lr: 1.0000e-04 - 398ms/epoch - 9ms/step
# Epoch 8/40
# 42/42 - 0s - loss: 1.1438 - accuracy: 0.6791 - val_loss: 1.6848 - val_accuracy: 0.4870 - lr: 1.0000e-04 - 381ms/epoch - 9ms/step
# Epoch 9/40
# 42/42 - 0s - loss: 1.1123 - accuracy: 0.6821 - val_loss: 1.6421 - val_accuracy: 0.5107 - lr: 1.0000e-04 - 396ms/epoch - 9ms/step
# Epoch 10/40
# 42/42 - 0s - loss: 1.0835 - accuracy: 0.6842 - val_loss: 1.5686 - val_accuracy: 0.5329 - lr: 1.0000e-04 - 405ms/epoch - 10ms/step
# Epoch 11/40
# 42/42 - 0s - loss: 1.0583 - accuracy: 0.6873 - val_loss: 1.4699 - val_accuracy: 0.5543 - lr: 1.0000e-04 - 414ms/epoch - 10ms/step
# Epoch 12/40
# 42/42 - 0s - loss: 1.0377 - accuracy: 0.6888 - val_loss: 1.3598 - val_accuracy: 0.6292 - lr: 1.0000e-04 - 410ms/epoch - 10ms/step
# Epoch 13/40
# 42/42 - 0s - loss: 1.0190 - accuracy: 0.6913 - val_loss: 1.2580 - val_accuracy: 0.6827 - lr: 1.0000e-04 - 401ms/epoch - 10ms/step
# Epoch 14/40
# 42/42 - 0s - loss: 0.9961 - accuracy: 0.6922 - val_loss: 1.1728 - val_accuracy: 0.6881 - lr: 1.0000e-04 - 422ms/epoch - 10ms/step
# Epoch 15/40
# 42/42 - 0s - loss: 0.9807 - accuracy: 0.6987 - val_loss: 1.1079 - val_accuracy: 0.6881 - lr: 1.0000e-04 - 414ms/epoch - 10ms/step
# Epoch 16/40
# 42/42 - 0s - loss: 0.9646 - accuracy: 0.7044 - val_loss: 1.0620 - val_accuracy: 0.7018 - lr: 1.0000e-04 - 378ms/epoch - 9ms/step
# Epoch 17/40
# 42/42 - 0s - loss: 0.9531 - accuracy: 0.7063 - val_loss: 1.0272 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 403ms/epoch - 10ms/step
# Epoch 18/40
# 42/42 - 0s - loss: 0.9335 - accuracy: 0.7152 - val_loss: 1.0039 - val_accuracy: 0.7118 - lr: 1.0000e-04 - 410ms/epoch - 10ms/step
# Epoch 19/40
# 42/42 - 0s - loss: 0.9210 - accuracy: 0.7200 - val_loss: 0.9867 - val_accuracy: 0.7118 - lr: 1.0000e-04 - 421ms/epoch - 10ms/step
# Epoch 20/40
# 42/42 - 0s - loss: 0.9060 - accuracy: 0.7253 - val_loss: 0.9720 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 410ms/epoch - 10ms/step
# Epoch 21/40
# 42/42 - 0s - loss: 0.8934 - accuracy: 0.7327 - val_loss: 0.9596 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 432ms/epoch - 10ms/step
# Epoch 22/40
# 42/42 - 0s - loss: 0.8886 - accuracy: 0.7333 - val_loss: 0.9487 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 416ms/epoch - 10ms/step
# Epoch 23/40
# 42/42 - 0s - loss: 0.8763 - accuracy: 0.7426 - val_loss: 0.9426 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 397ms/epoch - 9ms/step
# Epoch 24/40
# 42/42 - 0s - loss: 0.8655 - accuracy: 0.7470 - val_loss: 0.9339 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 406ms/epoch - 10ms/step
# Epoch 25/40
# 42/42 - 0s - loss: 0.8580 - accuracy: 0.7480 - val_loss: 0.9283 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 402ms/epoch - 10ms/step
# Epoch 26/40
# 42/42 - 0s - loss: 0.8431 - accuracy: 0.7573 - val_loss: 0.9246 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 388ms/epoch - 9ms/step
# Epoch 27/40
# 42/42 - 0s - loss: 0.8374 - accuracy: 0.7546 - val_loss: 0.9178 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 406ms/epoch - 10ms/step
# Epoch 28/40
# 42/42 - 0s - loss: 0.8314 - accuracy: 0.7607 - val_loss: 0.9154 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 382ms/epoch - 9ms/step
# Epoch 29/40
# 42/42 - 0s - loss: 0.8214 - accuracy: 0.7643 - val_loss: 0.9117 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 382ms/epoch - 9ms/step
# Epoch 30/40
# 42/42 - 0s - loss: 0.8169 - accuracy: 0.7708 - val_loss: 0.9077 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 397ms/epoch - 9ms/step
# Epoch 31/40
# 42/42 - 0s - loss: 0.8070 - accuracy: 0.7691 - val_loss: 0.9028 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 425ms/epoch - 10ms/step
# Epoch 32/40
# 42/42 - 0s - loss: 0.7963 - accuracy: 0.7769 - val_loss: 0.8986 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 407ms/epoch - 10ms/step
# Epoch 33/40
# 42/42 - 0s - loss: 0.7911 - accuracy: 0.7769 - val_loss: 0.8931 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 403ms/epoch - 10ms/step
# Epoch 34/40
# 42/42 - 0s - loss: 0.7833 - accuracy: 0.7828 - val_loss: 0.8875 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 407ms/epoch - 10ms/step
# Epoch 35/40
# 42/42 - 0s - loss: 0.7765 - accuracy: 0.7858 - val_loss: 0.8823 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 411ms/epoch - 10ms/step
# Epoch 36/40
# 42/42 - 0s - loss: 0.7726 - accuracy: 0.7850 - val_loss: 0.8817 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 413ms/epoch - 10ms/step
# Epoch 37/40
# 42/42 - 0s - loss: 0.7649 - accuracy: 0.7875 - val_loss: 0.8771 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 409ms/epoch - 10ms/step
# Epoch 38/40
# 42/42 - 0s - loss: 0.7583 - accuracy: 0.7889 - val_loss: 0.8733 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 418ms/epoch - 10ms/step
# Epoch 39/40
# 42/42 - 0s - loss: 0.7532 - accuracy: 0.7921 - val_loss: 0.8673 - val_accuracy: 0.7080 - lr: 1.0000e-04 - 390ms/epoch - 9ms/step
# Epoch 40/40
# 42/42 - 0s - loss: 0.7475 - accuracy: 0.7936 - val_loss: 0.8636 - val_accuracy: 0.7080 - lr: 1.0000e-04 - 434ms/epoch - 10ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpuy2rpnuu/assets
# INFO:tensorflow:Assets written to: /tmp/tmpuy2rpnuu/assets
# 2026-03-05 02:11:18.865559: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:11:18.865601: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:11:18.865722: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpuy2rpnuu
# 2026-03-05 02:11:18.867692: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:11:18.867706: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpuy2rpnuu
# 2026-03-05 02:11:18.872743: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:11:18.903122: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpuy2rpnuu
# 2026-03-05 02:11:18.915257: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 49535 microseconds.
# INFO:tensorflow:Assets written to: /tmp/tmpte_c_h8n/assets
# INFO:tensorflow:Assets written to: /tmp/tmpte_c_h8n/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:11:21.137992: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:11:21.138033: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:11:21.138170: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpte_c_h8n
# 2026-03-05 02:11:21.141499: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:11:21.141513: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpte_c_h8n
# 2026-03-05 02:11:21.147587: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:11:21.176235: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpte_c_h8n
# 2026-03-05 02:11:21.187248: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 49078 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/8
# 2026-03-05 02:11:25.041500: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inrepmobile_folded_conv2d/quant_repblock_0_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 42/42 - 4s - loss: 0.7193 - accuracy: 0.7982 - val_loss: 0.7712 - val_accuracy: 0.7301 - 4s/epoch - 96ms/step
# Epoch 2/8
# 42/42 - 2s - loss: 0.6707 - accuracy: 0.8062 - val_loss: 0.7431 - val_accuracy: 0.7362 - 2s/epoch - 48ms/step
# Epoch 3/8
# 42/42 - 2s - loss: 0.6273 - accuracy: 0.8178 - val_loss: 0.7177 - val_accuracy: 0.7500 - 2s/epoch - 50ms/step
# Epoch 4/8
# 42/42 - 2s - loss: 0.5942 - accuracy: 0.8227 - val_loss: 0.7005 - val_accuracy: 0.7485 - 2s/epoch - 52ms/step
# Epoch 5/8
# 42/42 - 2s - loss: 0.5657 - accuracy: 0.8225 - val_loss: 0.7014 - val_accuracy: 0.7385 - 2s/epoch - 50ms/step
# Epoch 6/8
# 42/42 - 2s - loss: 0.5449 - accuracy: 0.8263 - val_loss: 0.6949 - val_accuracy: 0.7401 - 2s/epoch - 49ms/step
# Epoch 7/8
# 42/42 - 2s - loss: 0.5199 - accuracy: 0.8288 - val_loss: 0.6975 - val_accuracy: 0.7339 - 2s/epoch - 52ms/step
# Epoch 8/8
# 42/42 - 2s - loss: 0.4997 - accuracy: 0.8292 - val_loss: 0.6866 - val_accuracy: 0.7362 - 2s/epoch - 47ms/step
# INFO:tensorflow:Assets written to: /tmp/tmprsu4voom/assets
# INFO:tensorflow:Assets written to: /tmp/tmprsu4voom/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:11:46.074946: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:11:46.074987: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:11:46.075113: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmprsu4voom
# 2026-03-05 02:11:46.081479: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:11:46.081495: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmprsu4voom
# 2026-03-05 02:11:46.096383: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:11:46.178880: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmprsu4voom
# 2026-03-05 02:11:46.205667: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 130553 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/dellio/github/har-mcu/src/eval/reporting.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([existing, incoming], ignore_index=True)
# /home/dellio/github/har-mcu/src/eval/paper_comparison.py:193: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# {'paper_slug': 'repmobile',
#  'rows': [{'paper_slug': 'repmobile',
#    'protocol': 'random_stratified',
#    'variant': 'repmobile_folded_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'gpu',
#    'eval_qat_device': 'gpu',
#    'fp32_training_time_sec': 19.76040043499961,
#    'fp32_model_size_kb': 94.68359375,
#    'fp32_tflite_model': '/home/dellio/github/har-mcu/models_tflite/repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0_fp32.tflite',
#    'fp32_tflite_status': 'ok',
#    'fp32_tflite_error': None,
#    'qat_training_time_sec': 18.618353685999864,
#    'accuracy': 0.7715674362089915,
#    'macro_f1': 0.577059167353506,
#    'ptq_status': 'ok',
#    'qat_status': 'ok',
#    'ptq_allowed_ops_profile': 'micro_mutable_main',
#    'qat_allowed_ops_profile': 'micro_mutable_main',
#    'ptq_accuracy': 0.7688335358444714,
#    'ptq_macro_f1': 0.5744658932531931,
#    'qat_accuracy': 0.807411907654921,
#    'qat_macro_f1': 0.6037255503044259,
#    'ptq_model_size_kb': 43.4140625,
#    'qat_model_size_kb': 46.9140625,
#    'model_size_kb': 43.4140625,
#    'ptq_inference_latency_ms_median': 0.4126460000861698,
#    'ptq_inference_latency_ms_p95': 0.4808159999356576,
#    'qat_inference_latency_ms_median': 0.5283049999889045,
#    'qat_inference_latency_ms_p95': 0.5476575000784578,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_fp32_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_qat_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_ptq_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_qat_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'deploy_gate': {'ptq': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []},
#     'qat': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_export_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_export_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/repmobile/artifacts/repmobile_repmobile_folded_conv2d_random_stratified_wisdm_r0.json'},
#   {'paper_slug': 'repmobile',
#    'protocol': 'user_holdout',
#    'variant': 'repmobile_folded_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'gpu',
#    'eval_qat_device': 'gpu',
#    'fp32_training_time_sec': 17.628862212999593,
#    'fp32_model_size_kb': 94.68359375,
#    'fp32_tflite_model': '/home/dellio/github/har-mcu/models_tflite/repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0_fp32.tflite',
#    'fp32_tflite_status': 'ok',
#    'fp32_tflite_error': None,
#    'qat_training_time_sec': 18.730120572999567,
#    'accuracy': 0.7372434017595307,
#    'macro_f1': 0.5323846994461402,
#    'ptq_status': 'ok',
#    'qat_status': 'ok',
#    'ptq_allowed_ops_profile': 'micro_mutable_main',
#    'qat_allowed_ops_profile': 'micro_mutable_main',
#    'ptq_accuracy': 0.7284457478005865,
#    'ptq_macro_f1': 0.5315173051412764,
#    'qat_accuracy': 0.7621700879765396,
#    'qat_macro_f1': 0.5156669176716828,
#    'ptq_model_size_kb': 43.4140625,
#    'qat_model_size_kb': 46.9140625,
#    'model_size_kb': 43.4140625,
#    'ptq_inference_latency_ms_median': 0.41620100023465056,
#    'ptq_inference_latency_ms_p95': 0.465745749920643,
#    'qat_inference_latency_ms_median': 0.5446200000278623,
#    'qat_inference_latency_ms_p95': 0.5960000000868604,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_fp32_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_qat_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_ptq_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_qat_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'deploy_gate': {'ptq': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []},
#     'qat': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_export_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_export_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/repmobile/artifacts/repmobile_repmobile_folded_conv2d_user_holdout_wisdm_r0.json'}],
#  'paper_exports': {'random_stratified': {'csv': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_results_random_stratified.csv',
#    'md': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_summary.md'},
#   'user_holdout': {'csv': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_results_user_holdout.csv',
#    'md': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_summary.md'}},
#  'comparison_exports': {'csv': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison.csv',
#   'md': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison.md',
#   'accuracy_png': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison_accuracy.png',
#   'size_png': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison_size.png',
#   'latency_png': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison_latency.png'},
#  'master_exports': {'csv': '/home/dellio/github/har-mcu/reports/results_master.csv',
#   'md': '/home/dellio/github/har-mcu/reports/results_master.md'}}

# %%
# Standardized shared notebook report rendering
from src.eval.notebook_reporting import render_paper_notebook_report

notebook_report = render_paper_notebook_report(cfg, out, drift_tol=1e-9)
notebook_report
# Out:
#   paper_slug           protocol                  variant    run_id  \
# 0  repmobile  random_stratified  repmobile_folded_conv2d  wisdm_r0
# 1  repmobile       user_holdout  repmobile_folded_conv2d  wisdm_r0
#
#    window_size  seed compression_focus      run_mode train_device  \
# 0          200    42      ptq_qat_only  sanity_check          gpu
# 1          200    42      ptq_qat_only  sanity_check          gpu
#
#   eval_fp32_device  ...                                        deploy_gate  \
# 0              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
# 1              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
#
#   paper_target_score delta_vs_paper notes_assumptions  \
# 0               None           None              None
# 1               None           None              None
#
#                                    fp32_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     ptq_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     qat_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      ptq_report_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      qat_report_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                    run_artifact_json
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
# [2 rows x 54 columns]
# <style type="text/css">
# </style>
# <table id="T_e75e0">
#   <caption>Model Size Summary (FP32 float .tflite, PTQ INT8, QAT INT8)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e75e0_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_e75e0_level0_col1" class="col_heading level0 col1" >fp32_model_size_kb</th>
#       <th id="T_e75e0_level0_col2" class="col_heading level0 col2" >ptq_model_size_kb</th>
#       <th id="T_e75e0_level0_col3" class="col_heading level0 col3" >qat_model_size_kb</th>
#       <th id="T_e75e0_level0_col4" class="col_heading level0 col4" >fp32_tflite_status</th>
#       <th id="T_e75e0_level0_col5" class="col_heading level0 col5" >fp32_tflite_model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e75e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e75e0_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_e75e0_row0_col1" class="data row0 col1" >94.68 KB</td>
#       <td id="T_e75e0_row0_col2" class="data row0 col2" >43.41 KB</td>
#       <td id="T_e75e0_row0_col3" class="data row0 col3" >46.91 KB</td>
#       <td id="T_e75e0_row0_col4" class="data row0 col4" >ok</td>
#       <td id="T_e75e0_row0_col5" class="data row0 col5" >/home/dellio/github/har-mcu/models_tflite/repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0_fp32.tflite</td>
#     </tr>
#     <tr>
#       <th id="T_e75e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e75e0_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_e75e0_row1_col1" class="data row1 col1" >94.68 KB</td>
#       <td id="T_e75e0_row1_col2" class="data row1 col2" >43.41 KB</td>
#       <td id="T_e75e0_row1_col3" class="data row1 col3" >46.91 KB</td>
#       <td id="T_e75e0_row1_col4" class="data row1 col4" >ok</td>
#       <td id="T_e75e0_row1_col5" class="data row1 col5" >/home/dellio/github/har-mcu/models_tflite/repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0_fp32.tflite</td>
#     </tr>
#   </tbody>
# </table>
# Note: fp32_model_size_kb is measured from exported float .tflite per protocol.
#
# PTQ operator visibility (per protocol):
# - interpreter_ops: delegate-free runtime ops from PTQ TFLite evaluation metrics
# - tflm_ops: flatbuffer ops used by strict deploy-gate compatibility check
#
# [random_stratified]
#   interpreter_ops (9): ['CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#   tflm_ops       (9): ['CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#
# [user_holdout]
#   interpreter_ops (9): ['CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#   tflm_ops       (9): ['CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#
# Strict deploy-gate status summary:
# [random_stratified] ptq_status=ok | qat_status=ok
# [user_holdout] ptq_status=ok | qat_status=ok
#
# Strict Deploy-Gate Details (from export reports):
# <style type="text/css">
# </style>
# <table id="T_98d76">
#   <caption>Strict deploy-gate details per protocol/tier (PTQ, QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98d76_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_98d76_level0_col1" class="col_heading level0 col1" >tier</th>
#       <th id="T_98d76_level0_col2" class="col_heading level0 col2" >status</th>
#       <th id="T_98d76_level0_col3" class="col_heading level0 col3" >full_integer_io</th>
#       <th id="T_98d76_level0_col4" class="col_heading level0 col4" >tflm_compatible</th>
#       <th id="T_98d76_level0_col5" class="col_heading level0 col5" >allowed_ops_profile</th>
#       <th id="T_98d76_level0_col6" class="col_heading level0 col6" >compatibility_scope</th>
#       <th id="T_98d76_level0_col7" class="col_heading level0 col7" >unsupported_ops_micro_mutable</th>
#       <th id="T_98d76_level0_col8" class="col_heading level0 col8" >possibly_supported_upstream_tflm</th>
#       <th id="T_98d76_level0_col9" class="col_heading level0 col9" >unsupported_in_reference</th>
#       <th id="T_98d76_level0_col10" class="col_heading level0 col10" >error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98d76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98d76_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_98d76_row0_col1" class="data row0 col1" >PTQ</td>
#       <td id="T_98d76_row0_col2" class="data row0 col2" >ok</td>
#       <td id="T_98d76_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_98d76_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_98d76_row0_col5" class="data row0 col5" >micro_mutable_main</td>
#       <td id="T_98d76_row0_col6" class="data row0 col6" >micro_mutable_main</td>
#       <td id="T_98d76_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_98d76_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_98d76_row0_col9" class="data row0 col9" >—</td>
#       <td id="T_98d76_row0_col10" class="data row0 col10" >—</td>
#     </tr>
#     <tr>
#       <th id="T_98d76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98d76_row1_col0" class="data row1 col0" >random_stratified</td>
#       <td id="T_98d76_row1_col1" class="data row1 col1" >QAT</td>
#       <td id="T_98d76_row1_col2" class="data row1 col2" >ok</td>
#       <td id="T_98d76_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_98d76_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_98d76_row1_col5" class="data row1 col5" >micro_mutable_main</td>
#       <td id="T_98d76_row1_col6" class="data row1 col6" >micro_mutable_main</td>
#       <td id="T_98d76_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_98d76_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_98d76_row1_col9" class="data row1 col9" >—</td>
#       <td id="T_98d76_row1_col10" class="data row1 col10" >—</td>
#     </tr>
#     <tr>
#       <th id="T_98d76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98d76_row2_col0" class="data row2 col0" >user_holdout</td>
#       <td id="T_98d76_row2_col1" class="data row2 col1" >PTQ</td>
#       <td id="T_98d76_row2_col2" class="data row2 col2" >ok</td>
#       <td id="T_98d76_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_98d76_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_98d76_row2_col5" class="data row2 col5" >micro_mutable_main</td>
#       <td id="T_98d76_row2_col6" class="data row2 col6" >micro_mutable_main</td>
#       <td id="T_98d76_row2_col7" class="data row2 col7" >—</td>
#       <td id="T_98d76_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_98d76_row2_col9" class="data row2 col9" >—</td>
#       <td id="T_98d76_row2_col10" class="data row2 col10" >—</td>
#     </tr>
#     <tr>
#       <th id="T_98d76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98d76_row3_col0" class="data row3 col0" >user_holdout</td>
#       <td id="T_98d76_row3_col1" class="data row3 col1" >QAT</td>
#       <td id="T_98d76_row3_col2" class="data row3 col2" >ok</td>
#       <td id="T_98d76_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_98d76_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_98d76_row3_col5" class="data row3 col5" >micro_mutable_main</td>
#       <td id="T_98d76_row3_col6" class="data row3 col6" >micro_mutable_main</td>
#       <td id="T_98d76_row3_col7" class="data row3 col7" >—</td>
#       <td id="T_98d76_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_98d76_row3_col9" class="data row3 col9" >—</td>
#       <td id="T_98d76_row3_col10" class="data row3 col10" >—</td>
#     </tr>
#   </tbody>
# </table>
# Note: if you changed model_variant/run_id, compare only current run rows and artifacts. Older files may still exist under reports/<paper_slug>/.
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:410: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   comparison_df.style.format(
# <style type="text/css">
# </style>
# <table id="T_4e028">
#   <caption>Table 1 — Accuracy, macro F1, model size, timing, and accuracy delta vs paper target (baseline/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e028_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_4e028_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_4e028_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_4e028_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_4e028_level0_col4" class="col_heading level0 col4" >macro_f1</th>
#       <th id="T_4e028_level0_col5" class="col_heading level0 col5" >model_size_kb</th>
#       <th id="T_4e028_level0_col6" class="col_heading level0 col6" >training_time_sec</th>
#       <th id="T_4e028_level0_col7" class="col_heading level0 col7" >inference_latency_ms_median</th>
#       <th id="T_4e028_level0_col8" class="col_heading level0 col8" >inference_latency_ms_p95</th>
#       <th id="T_4e028_level0_col9" class="col_heading level0 col9" >status</th>
#       <th id="T_4e028_level0_col10" class="col_heading level0 col10" >ptq_status</th>
#       <th id="T_4e028_level0_col11" class="col_heading level0 col11" >qat_status</th>
#       <th id="T_4e028_level0_col12" class="col_heading level0 col12" >paper_target_accuracy</th>
#       <th id="T_4e028_level0_col13" class="col_heading level0 col13" >acc_delta_vs_target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e028_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e028_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_4e028_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_4e028_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_4e028_row0_col3" class="data row0 col3" >0.7716</td>
#       <td id="T_4e028_row0_col4" class="data row0 col4" >0.5771</td>
#       <td id="T_4e028_row0_col5" class="data row0 col5" >94.68</td>
#       <td id="T_4e028_row0_col6" class="data row0 col6" >19.76s</td>
#       <td id="T_4e028_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_4e028_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_4e028_row0_col9" class="data row0 col9" >ok</td>
#       <td id="T_4e028_row0_col10" class="data row0 col10" >ok</td>
#       <td id="T_4e028_row0_col11" class="data row0 col11" >ok</td>
#       <td id="T_4e028_row0_col12" class="data row0 col12" >None</td>
#       <td id="T_4e028_row0_col13" class="data row0 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4e028_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e028_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_4e028_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_4e028_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_4e028_row1_col3" class="data row1 col3" >0.7688</td>
#       <td id="T_4e028_row1_col4" class="data row1 col4" >0.5745</td>
#       <td id="T_4e028_row1_col5" class="data row1 col5" >43.41</td>
#       <td id="T_4e028_row1_col6" class="data row1 col6" >—</td>
#       <td id="T_4e028_row1_col7" class="data row1 col7" >0.413ms</td>
#       <td id="T_4e028_row1_col8" class="data row1 col8" >0.481ms</td>
#       <td id="T_4e028_row1_col9" class="data row1 col9" >ok</td>
#       <td id="T_4e028_row1_col10" class="data row1 col10" >ok</td>
#       <td id="T_4e028_row1_col11" class="data row1 col11" >None</td>
#       <td id="T_4e028_row1_col12" class="data row1 col12" >None</td>
#       <td id="T_4e028_row1_col13" class="data row1 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4e028_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e028_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_4e028_row2_col1" class="data row2 col1" >random_stratified</td>
#       <td id="T_4e028_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_4e028_row2_col3" class="data row2 col3" >0.8074</td>
#       <td id="T_4e028_row2_col4" class="data row2 col4" >0.6037</td>
#       <td id="T_4e028_row2_col5" class="data row2 col5" >46.91</td>
#       <td id="T_4e028_row2_col6" class="data row2 col6" >18.62s</td>
#       <td id="T_4e028_row2_col7" class="data row2 col7" >0.528ms</td>
#       <td id="T_4e028_row2_col8" class="data row2 col8" >0.548ms</td>
#       <td id="T_4e028_row2_col9" class="data row2 col9" >ok</td>
#       <td id="T_4e028_row2_col10" class="data row2 col10" >None</td>
#       <td id="T_4e028_row2_col11" class="data row2 col11" >ok</td>
#       <td id="T_4e028_row2_col12" class="data row2 col12" >None</td>
#       <td id="T_4e028_row2_col13" class="data row2 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4e028_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e028_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_4e028_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_4e028_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_4e028_row3_col3" class="data row3 col3" >0.7372</td>
#       <td id="T_4e028_row3_col4" class="data row3 col4" >0.5324</td>
#       <td id="T_4e028_row3_col5" class="data row3 col5" >94.68</td>
#       <td id="T_4e028_row3_col6" class="data row3 col6" >17.63s</td>
#       <td id="T_4e028_row3_col7" class="data row3 col7" >—</td>
#       <td id="T_4e028_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_4e028_row3_col9" class="data row3 col9" >ok</td>
#       <td id="T_4e028_row3_col10" class="data row3 col10" >ok</td>
#       <td id="T_4e028_row3_col11" class="data row3 col11" >ok</td>
#       <td id="T_4e028_row3_col12" class="data row3 col12" >None</td>
#       <td id="T_4e028_row3_col13" class="data row3 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4e028_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e028_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_4e028_row4_col1" class="data row4 col1" >user_holdout</td>
#       <td id="T_4e028_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_4e028_row4_col3" class="data row4 col3" >0.7284</td>
#       <td id="T_4e028_row4_col4" class="data row4 col4" >0.5315</td>
#       <td id="T_4e028_row4_col5" class="data row4 col5" >43.41</td>
#       <td id="T_4e028_row4_col6" class="data row4 col6" >—</td>
#       <td id="T_4e028_row4_col7" class="data row4 col7" >0.416ms</td>
#       <td id="T_4e028_row4_col8" class="data row4 col8" >0.466ms</td>
#       <td id="T_4e028_row4_col9" class="data row4 col9" >ok</td>
#       <td id="T_4e028_row4_col10" class="data row4 col10" >ok</td>
#       <td id="T_4e028_row4_col11" class="data row4 col11" >None</td>
#       <td id="T_4e028_row4_col12" class="data row4 col12" >None</td>
#       <td id="T_4e028_row4_col13" class="data row4 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4e028_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e028_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_4e028_row5_col1" class="data row5 col1" >user_holdout</td>
#       <td id="T_4e028_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_4e028_row5_col3" class="data row5 col3" >0.7622</td>
#       <td id="T_4e028_row5_col4" class="data row5 col4" >0.5157</td>
#       <td id="T_4e028_row5_col5" class="data row5 col5" >46.91</td>
#       <td id="T_4e028_row5_col6" class="data row5 col6" >18.73s</td>
#       <td id="T_4e028_row5_col7" class="data row5 col7" >0.545ms</td>
#       <td id="T_4e028_row5_col8" class="data row5 col8" >0.596ms</td>
#       <td id="T_4e028_row5_col9" class="data row5 col9" >ok</td>
#       <td id="T_4e028_row5_col10" class="data row5 col10" >None</td>
#       <td id="T_4e028_row5_col11" class="data row5 col11" >ok</td>
#       <td id="T_4e028_row5_col12" class="data row5 col12" >None</td>
#       <td id="T_4e028_row5_col13" class="data row5 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4e028_level0_row6" class="row_heading level0 row6" >6</th>
# Note: Paper-target QAT may be unavailable in source papers; QAT rows here are replication extensions where target is N/A.
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:281: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# <style type="text/css">
# </style>
# <table id="T_b9771">
#   <caption>Table 2 — Model size (FP32/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9771_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_b9771_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_b9771_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_b9771_level0_col3" class="col_heading level0 col3" >model_size_kb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9771_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9771_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_b9771_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_b9771_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_b9771_row0_col3" class="data row0 col3" >94.68 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b9771_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9771_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_b9771_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_b9771_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_b9771_row1_col3" class="data row1 col3" >43.41 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b9771_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9771_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_b9771_row2_col1" class="data row2 col1" >random_stratified</td>
#       <td id="T_b9771_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_b9771_row2_col3" class="data row2 col3" >46.91 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b9771_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9771_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_b9771_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_b9771_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_b9771_row3_col3" class="data row3 col3" >94.68 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b9771_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9771_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_b9771_row4_col1" class="data row4 col1" >user_holdout</td>
#       <td id="T_b9771_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_b9771_row4_col3" class="data row4 col3" >43.41 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b9771_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9771_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_b9771_row5_col1" class="data row5 col1" >user_holdout</td>
#       <td id="T_b9771_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_b9771_row5_col3" class="data row5 col3" >46.91 KB</td>
#     </tr>
#   </tbody>
# </table>
# Reproducibility drift — WISDM replication (repeat evaluation on saved checkpoint):
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:439: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   reproducibility_df[
# <style type="text/css">
# #T_93686_row0_col5, #T_93686_row1_col5 {
#   color: green;
# }
# </style>
# <table id="T_93686">
#   <caption>Table 3 — Reproducibility drift (two consecutive FP32 evaluations)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93686_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_93686_level0_col1" class="col_heading level0 col1" >split_hash</th>
#       <th id="T_93686_level0_col2" class="col_heading level0 col2" >baseline_acc_first</th>
#       <th id="T_93686_level0_col3" class="col_heading level0 col3" >baseline_acc_repeat</th>
#       <th id="T_93686_level0_col4" class="col_heading level0 col4" >abs_drift</th>
#       <th id="T_93686_level0_col5" class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93686_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93686_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_93686_row0_col1" class="data row0 col1" >68c9e31789bca103</td>
#       <td id="T_93686_row0_col2" class="data row0 col2" >0.7716</td>
#       <td id="T_93686_row0_col3" class="data row0 col3" >0.7716</td>
#       <td id="T_93686_row0_col4" class="data row0 col4" >0.00e+00</td>
#       <td id="T_93686_row0_col5" class="data row0 col5" >PASS</td>
#     </tr>
#     <tr>
#       <th id="T_93686_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93686_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_93686_row1_col1" class="data row1 col1" >2498bff9ddcfc589</td>
#       <td id="T_93686_row1_col2" class="data row1 col2" >0.7372</td>
#       <td id="T_93686_row1_col3" class="data row1 col3" >0.7372</td>
#       <td id="T_93686_row1_col4" class="data row1 col4" >0.00e+00</td>
#       <td id="T_93686_row1_col5" class="data row1 col5" >PASS</td>
#     </tr>
#   </tbody>
# </table>
# ### Protocol: `random_stratified`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Protocol: `user_holdout`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Classification Report Snippets — `random_stratified`
# FP32: macro_f1=0.577059167353506, weighted_f1=0.7036956203724145
# PTQ: macro_f1=0.5744658932531931, weighted_f1=0.7014606510848906
# QAT: macro_f1=0.6037255503044259, weighted_f1=0.7459164743892159
# ### Classification Report Snippets — `user_holdout`
# FP32: macro_f1=0.5323846994461402, weighted_f1=0.6621268572236718
# PTQ: macro_f1=0.5315173051412764, weighted_f1=0.6545941789546581
# QAT: macro_f1=0.5156669176716828, weighted_f1=0.6896052184105866
# ## Saved Comparison CSV Snapshot
#             pipeline           protocol           model  accuracy  macro_f1  \
# 0  WISDM replication  random_stratified  baseline float  0.771567  0.577059
# 1  WISDM replication  random_stratified        PTQ int8  0.768834  0.574466
# 2  WISDM replication  random_stratified        QAT int8  0.807412  0.603726
# 3  WISDM replication       user_holdout  baseline float  0.737243  0.532385
# 4  WISDM replication       user_holdout        PTQ int8  0.728446  0.531517
# 5  WISDM replication       user_holdout        QAT int8  0.762170  0.515667
# 6       paper target                  —  baseline float       NaN       NaN
# 7       paper target                  —        PTQ int8       NaN       NaN
# 8       paper target                  —        QAT int8       NaN       NaN
#
#    model_size_kb  training_time_sec  inference_latency_ms_median  \
# 0      94.683594          19.760400                          NaN
# 1      43.414062                NaN                     0.412646
# 2      46.914062          18.618354                     0.528305
# 3      94.683594          17.628862                          NaN
# 4      43.414062                NaN                     0.416201
# 5      46.914062          18.730121                     0.544620
# 6            NaN                NaN                          NaN
# 7            NaN                NaN                          NaN
# 8            NaN                NaN                          NaN
#
#    inference_latency_ms_p95     status ptq_status qat_status  \
# 0                       NaN         ok         ok         ok
# 1                  0.480816         ok         ok        NaN
# 2                  0.547658         ok        NaN         ok
# 3                       NaN         ok         ok         ok
# 4                  0.465746         ok         ok        NaN
# 5                  0.596000         ok        NaN         ok
# 6                       NaN  reference        NaN        NaN
# 7                       NaN  reference        NaN        NaN
# 8                       NaN  reference        NaN        NaN
#
#    paper_target_accuracy  acc_delta_vs_target
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                    NaN                  NaN
# 7                    NaN                  NaN
# 8                    NaN                  NaN
# ## Master Results Snapshot
#    paper_slug           protocol                  variant    run_id  \
# 2   repmobile  random_stratified         repmobile_folded  wisdm_r0
# 3   repmobile       user_holdout         repmobile_folded  wisdm_r0
# 10  repmobile  random_stratified  repmobile_folded_conv2d  wisdm_r0
# 11  repmobile       user_holdout  repmobile_folded_conv2d  wisdm_r0
#
#     window_size  seed compression_focus      run_mode train_device  \
# 2           200    42      ptq_qat_only  sanity_check          gpu
# 3           200    42      ptq_qat_only  sanity_check          gpu
# 10          200    42      ptq_qat_only  sanity_check          gpu
# 11          200    42      ptq_qat_only  sanity_check          gpu
#
#    eval_fp32_device  ...                                   qat_metrics_json  \
# 2               gpu  ...  /home/dellio/github/har-mcu/reports/repmobile/...
# 3               gpu  ...                                                NaN
# 10              gpu  ...  /home/dellio/github/har-mcu/reports/repmobile/...
# 11              gpu  ...  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                       ptq_report_json  \
# 2   /home/dellio/github/har-mcu/reports/repmobile/...
# 3   /home/dellio/github/har-mcu/reports/repmobile/...
# 10  /home/dellio/github/har-mcu/reports/repmobile/...
# 11  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                       qat_report_json  \
# 2   /home/dellio/github/har-mcu/reports/repmobile/...
# 3   /home/dellio/github/har-mcu/reports/repmobile/...
# 10  /home/dellio/github/har-mcu/reports/repmobile/...
# 11  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     run_artifact_json  \
# 2   /home/dellio/github/har-mcu/reports/repmobile/...
# 3   /home/dellio/github/har-mcu/reports/repmobile/...
# 10  /home/dellio/github/har-mcu/reports/repmobile/...
# 11  /home/dellio/github/har-mcu/reports/repmobile/...
#
#     ptq_allowed_ops_profile  qat_allowed_ops_profile  fp32_model_size_kb  \
# 2                       NaN                      NaN                 NaN
# 3                       NaN                      NaN                 NaN
# 10       micro_mutable_main       micro_mutable_main           94.683594
# 11       micro_mutable_main       micro_mutable_main           94.683594
#
#                                     fp32_tflite_model fp32_tflite_status  \
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 10  /home/dellio/github/har-mcu/models_tflite/repm...                 ok
# 11  /home/dellio/github/har-mcu/models_tflite/repm...                 ok
#
#    fp32_tflite_error
# 2                NaN
# 3                NaN
# 10               NaN
# 11               NaN
#
# [4 rows x 54 columns]
# Saved outputs root: /home/dellio/github/har-mcu/reports/repmobile
# {'rows_df':   paper_slug           protocol                  variant    run_id  \
#  0  repmobile  random_stratified  repmobile_folded_conv2d  wisdm_r0
#  1  repmobile       user_holdout  repmobile_folded_conv2d  wisdm_r0
#
#     window_size  seed compression_focus      run_mode train_device  \
#  0          200    42      ptq_qat_only  sanity_check          gpu
#  1          200    42      ptq_qat_only  sanity_check          gpu
#
#    eval_fp32_device  ...                                        deploy_gate  \
#  0              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
#  1              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
#
#    paper_target_score delta_vs_paper notes_assumptions  \
#  0               None           None              None
#  1               None           None              None
#
#                                     fp32_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/repmobile/...
#  1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      ptq_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/repmobile/...
#  1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      qat_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/repmobile/...
#  1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                       ptq_report_json  \
#  0  /home/dellio/github/har-mcu/reports/repmobile/...
#  1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                       qat_report_json  \
#  0  /home/dellio/github/har-mcu/reports/repmobile/...
#  1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     run_artifact_json
#  0  /home/dellio/github/har-mcu/reports/repmobile/...
#  1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#  [2 rows x 54 columns],
#  'ptq_operator_visibility': [{'protocol': 'random_stratified',
#    'interpreter_ops': ['CONV_2D',
#     'DEPTHWISE_CONV_2D',
#     'FULLY_CONNECTED',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'tflm_ops': ['CONV_2D',
#     'DEPTHWISE_CONV_2D',
#     'FULLY_CONNECTED',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'only_interpreter': [],
#    'only_tflm': []},
#   {'protocol': 'user_holdout',
#    'interpreter_ops': ['CONV_2D',
#     'DEPTHWISE_CONV_2D',
#     'FULLY_CONNECTED',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'tflm_ops': ['CONV_2D',
#     'DEPTHWISE_CONV_2D',
#     'FULLY_CONNECTED',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'only_interpreter': [],
#    'only_tflm': []}],
#  'ptq_operator_warnings': [],
#  'strict_deploy_df':             protocol tier status  full_integer_io  tflm_compatible  \
#  0  random_stratified  PTQ     ok             True             True
#  1  random_stratified  QAT     ok             True             True
#  2       user_holdout  PTQ     ok             True             True
#  3       user_holdout  QAT     ok             True             True
#
#    allowed_ops_profile compatibility_scope unsupported_ops_micro_mutable  \
#  0  micro_mutable_main  micro_mutable_main                          None
#  1  micro_mutable_main  micro_mutable_main                          None
#  2  micro_mutable_main  micro_mutable_main                          None
#  3  micro_mutable_main  micro_mutable_main                          None
#
#    possibly_supported_upstream_tflm unsupported_in_reference error
#  0                             None                     None  None
#  1                             None                     None  None
#  2                             None                     None  None
#  3                             None                     None  None  ,
#  'legacy_artifact_detected': False,
#  'strict_summary_lines': ['[random_stratified] ptq_status=ok | qat_status=ok',
#   '[user_holdout] ptq_status=ok | qat_status=ok'],
#  'comparison_df':             pipeline           protocol           model  accuracy  macro_f1  \
#  0  WISDM replication  random_stratified  baseline float  0.771567  0.577059
#  1  WISDM replication  random_stratified        PTQ int8  0.768834  0.574466
#  2  WISDM replication  random_stratified        QAT int8  0.807412  0.603726
#  3  WISDM replication       user_holdout  baseline float  0.737243  0.532385
#  4  WISDM replication       user_holdout        PTQ int8  0.728446  0.531517
#  5  WISDM replication       user_holdout        QAT int8  0.762170  0.515667
#  6       paper target                  —  baseline float       NaN       NaN
#  7       paper target                  —        PTQ int8       NaN       NaN
#  8       paper target                  —        QAT int8       NaN       NaN
#
#     model_size_kb  training_time_sec  inference_latency_ms_median  \
#  0      94.683594          19.760400                          NaN
#  1      43.414062                NaN                     0.412646
#  2      46.914062          18.618354                     0.528305
#  3      94.683594          17.628862                          NaN
#  4      43.414062                NaN                     0.416201
#  5      46.914062          18.730121                     0.544620
#  6            NaN                NaN                          NaN
#  7            NaN                NaN                          NaN
#  8            NaN                NaN                          NaN
#
#     inference_latency_ms_p95     status ptq_status qat_status  \
#  0                       NaN         ok         ok         ok
#  1                  0.480816         ok         ok       None
#  2                  0.547658         ok       None         ok
#  3                       NaN         ok         ok         ok
#  4                  0.465746         ok         ok       None
#  5                  0.596000         ok       None         ok
#  6                       NaN  reference       None       None
#  7                       NaN  reference       None       None
#  8                       NaN  reference       None       None
#
#    paper_target_accuracy acc_delta_vs_target
#  0                  None                None
#  1                  None                None
#  2                  None                None
#  3                  None                None
#  4                  None                None
#  5                  None                None
#  6                  None                None
#  7                  None                None
#  8                  None                None  ,
#  'reproducibility_df':             protocol        split_hash  baseline_acc_first  \
#  0  random_stratified  68c9e31789bca103            0.771567
#  1       user_holdout  2498bff9ddcfc589            0.737243
#
#     baseline_acc_repeat  abs_drift status
#  0             0.771567        0.0   PASS
#  1             0.737243        0.0   PASS  }

# %% [markdown]
# ## Notes
# - If QAT conversion fails strict deploy-gate checks, results are still exported with explicit failure reason.
# - Document unresolved paper ambiguities in `reports/paper_specs_<slug>.md`.
