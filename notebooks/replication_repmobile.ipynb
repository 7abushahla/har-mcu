# %% [markdown]
# # Replication Notebook — RepMobile (WISDM-first)

# %% [markdown]
# ## Paper Facts and Code Availability
# - Paper DOI: https://doi.org/10.1109/JSEN.2024.3424578
# - Official repo: https://github.com/Yuki0614/RepMobile
# - Original protocol summary: structural reparameterization with folded inference graph.
#
# ## WISDM Adaptation
# - Active config: `configs/papers/repmobile_wisdm.yaml`
# - This notebook runs WISDM-first adaptation while preserving paper architecture intent.

# %% [markdown]
# ## Notebook Contract
# - Runtime / dependency guard
# - Paper facts + code availability
# - WISDM adaptation section
# - FP32 training/eval on `random_stratified` + `user_holdout`
# - PTQ INT8 + QAT INT8 exports
# - Strict deploy-gate summary (`full_integer_io`, `tflm_compatible`, unsupported ops)
# - Per-paper CSV/MD + master results append

# %% [markdown]
# ## Compression Scope Note
# - KD-related methodology from papers is documented for reproducibility context only.
# - Notebook execution enforces PTQ/QAT compression flow only (`experiment.compression_focus=ptq_qat_only`).
# - This notebook uses a Conv2D-equivalent architecture for QAT compatibility; Conv1D paper operators are preserved semantically via `(k)->(k,1)` mapping.

# %%
from pathlib import Path
import sys
import os
import json
import importlib
import importlib.util

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, Markdown, display

# Optional safeguard: disable GPU if kernel is unstable on CUDA runtime.
USE_GPU = True
if not USE_GPU:
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Ensure repo root is importable when launched from different working directories.
REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "src").exists():
    for parent in [REPO_ROOT, *REPO_ROOT.parents]:
        if (parent / "src").exists():
            REPO_ROOT = parent
            break
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

required_modules = {
    "numpy": "numpy",
    "pandas": "pandas",
    "matplotlib": "matplotlib",
    "IPython": "ipython",
    "yaml": "PyYAML",
    "sklearn": "scikit-learn",
    "tensorflow": "tensorflow",
    "tensorflow_model_optimization": "tensorflow-model-optimization",
}
missing = [
    f"{mod} (pip package: {pkg})"
    for mod, pkg in required_modules.items()
    if importlib.util.find_spec(mod) is None
]
if missing:
    missing_text = "\n- ".join(missing)
    raise ModuleNotFoundError(
        "Missing required notebook dependencies:\n- "
        + missing_text
        + "\n\nActivate tinymlproj and install dependencies:\n"
        + "conda activate tinymlproj && conda env update -n tinymlproj -f environment.yml --prune"
    )

import tensorflow as tf
print("TF version:", tf.__version__)
print("Visible GPUs:", tf.config.list_physical_devices("GPU"))

AUTO_RELOAD_PROJECT_MODULES = True
if AUTO_RELOAD_PROJECT_MODULES:
    for _mod_name in (
        "src.models.xtinyhar_student_tf",
        "src.models.repmobile_folded_tf",
        "src.models.tcn_attention_har_tf",
        "src.models.daghero_cnn_searchspace_tf",
        "src.models.tcn_inception_tf",
        "src.models.serialization",
        "src.eval.evaluate_model",
        "src.quant.ptq_full_int8",
        "src.quant.qat_train",
        "src.run_paper_experiment",
    ):
        if _mod_name in sys.modules:
            importlib.reload(sys.modules[_mod_name])

import src.run_paper_experiment as _run_mod
run_paper_experiment = _run_mod.run_paper_experiment

from src.utils.config import load_yaml
from src.utils.device_runtime import runtime_device_report
from src.eval.evaluate_model import evaluate_model_for_protocol
from src.utils.artifacts import model_ckpt_path, split_npz_path

if "load_checkpoint_model" not in evaluate_model_for_protocol.__code__.co_names:
    raise RuntimeError(
        "Stale evaluate_model module detected (safe loader missing). "
        "Restart kernel and rerun from the first cell."
    )

RUN_MODE = "sanity_check"  # switch to "full_run" for final CPU-only benchmark runs
CONFIG_PATH = REPO_ROOT / 'configs/papers/repmobile_wisdm.yaml'
assert CONFIG_PATH.exists(), f"Missing config: {CONFIG_PATH}"
cfg = load_yaml(CONFIG_PATH)
cfg.setdefault("runtime", {})["run_mode"] = RUN_MODE
cfg.setdefault("experiment", {})["compression_focus"] = "ptq_qat_only"
runtime = runtime_device_report(cfg)

print("repo_root:", REPO_ROOT)
print("paper_slug:", cfg.get("experiment", {}).get("paper_slug"))
print("model_variant:", cfg.get("experiment", {}).get("model_variant"))
is_conv2d_variant = str(cfg.get("experiment", {}).get("model_variant", "")).endswith("_conv2d")
print("conv2d_qat_safe_variant:", is_conv2d_variant)
print("[NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.")
if not is_conv2d_variant:
    print("[WARN] Active model_variant is not *_conv2d; QAT may fail on Conv1D/SeparableConv1D in tfmot 0.8.")
print("window_size:", cfg.get("paper_protocol", {}).get("wisdm_window_override"))
print("run_mode:", runtime["run_mode"])
print("detected_gpus:", runtime["gpus"])
print("stage_device_map:", runtime["resolved_stage_devices"])
print("[NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.")
# Out:
# 2026-03-03 02:34:54.837597: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-03 02:34:54.837708: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-03 02:34:54.838997: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-03 02:34:54.954671: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TF version: 2.14.1
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-03-03 02:34:57.528372: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:57.551924: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:57.551977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# repo_root: /home/dellio/github/har-mcu
# paper_slug: repmobile
# model_variant: repmobile_folded_conv2d
# conv2d_qat_safe_variant: True
# [NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.
# window_size: 200
# run_mode: sanity_check
# detected_gpus: ['/physical_device:GPU:0']
# stage_device_map: {'train': 'gpu', 'eval_fp32': 'gpu', 'ptq': 'gpu', 'eval_ptq': 'gpu', 'qat': 'cpu', 'eval_qat': 'cpu'}
# [NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.

# %%
# Run FP32 + PTQ + QAT + standardized reporting
out = run_paper_experiment(cfg)
out
# Out:
# 2026-03-03 02:34:58.158142: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:58.158224: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:58.158260: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:58.334582: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:58.334669: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:58.334683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-03-03 02:34:58.334746: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-03 02:34:58.335053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21764 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:2d:00.0, compute capability: 8.6
# Epoch 1/40
# 2026-03-03 02:34:59.193927: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 12830400 exceeds 10% of free system memory.
# 2026-03-03 02:34:59.227321: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 12830400 exceeds 10% of free system memory.
# 2026-03-03 02:34:59.255073: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 12830400 exceeds 10% of free system memory.
# 2026-03-03 02:34:59.914625: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inrepmobile_folded_conv2d/repblock_0_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-03-03 02:35:00.077518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2026-03-03 02:35:00.948457: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fac5a101ae0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-03 02:35:00.948500: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2026-03-03 02:35:01.026822: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 - 3s - loss: 1.6602 - accuracy: 0.2759 - val_loss: 1.7835 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 2/40
# 42/42 - 1s - loss: 1.5329 - accuracy: 0.3713 - val_loss: 1.7725 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 624ms/epoch - 15ms/step
# Epoch 3/40
# 42/42 - 1s - loss: 1.4295 - accuracy: 0.4800 - val_loss: 1.7606 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 667ms/epoch - 16ms/step
# Epoch 4/40
# 42/42 - 1s - loss: 1.3449 - accuracy: 0.5862 - val_loss: 1.7476 - val_accuracy: 0.3149 - lr: 1.0000e-04 - 595ms/epoch - 14ms/step
# Epoch 5/40
# 42/42 - 1s - loss: 1.2837 - accuracy: 0.6416 - val_loss: 1.7338 - val_accuracy: 0.4069 - lr: 1.0000e-04 - 625ms/epoch - 15ms/step
# Epoch 6/40
# 42/42 - 1s - loss: 1.2356 - accuracy: 0.6618 - val_loss: 1.7187 - val_accuracy: 0.4084 - lr: 1.0000e-04 - 585ms/epoch - 14ms/step
# Epoch 7/40
# 42/42 - 1s - loss: 1.1897 - accuracy: 0.6740 - val_loss: 1.7012 - val_accuracy: 0.4091 - lr: 1.0000e-04 - 592ms/epoch - 14ms/step
# Epoch 8/40
# 42/42 - 1s - loss: 1.1533 - accuracy: 0.6813 - val_loss: 1.6770 - val_accuracy: 0.4159 - lr: 1.0000e-04 - 630ms/epoch - 15ms/step
# Epoch 9/40
# 42/42 - 1s - loss: 1.1211 - accuracy: 0.6818 - val_loss: 1.6395 - val_accuracy: 0.4308 - lr: 1.0000e-04 - 643ms/epoch - 15ms/step
# Epoch 10/40
# 42/42 - 1s - loss: 1.0988 - accuracy: 0.6826 - val_loss: 1.5802 - val_accuracy: 0.4488 - lr: 1.0000e-04 - 639ms/epoch - 15ms/step
# Epoch 11/40
# 42/42 - 1s - loss: 1.0697 - accuracy: 0.6902 - val_loss: 1.4955 - val_accuracy: 0.4936 - lr: 1.0000e-04 - 606ms/epoch - 14ms/step
# Epoch 12/40
# 42/42 - 1s - loss: 1.0543 - accuracy: 0.6884 - val_loss: 1.3932 - val_accuracy: 0.5542 - lr: 1.0000e-04 - 629ms/epoch - 15ms/step
# Epoch 13/40
# 42/42 - 0s - loss: 1.0371 - accuracy: 0.6893 - val_loss: 1.2871 - val_accuracy: 0.6088 - lr: 1.0000e-04 - 487ms/epoch - 12ms/step
# Epoch 14/40
# 42/42 - 0s - loss: 1.0172 - accuracy: 0.6938 - val_loss: 1.1933 - val_accuracy: 0.6589 - lr: 1.0000e-04 - 467ms/epoch - 11ms/step
# Epoch 15/40
# 42/42 - 0s - loss: 1.0036 - accuracy: 0.6887 - val_loss: 1.1174 - val_accuracy: 0.6844 - lr: 1.0000e-04 - 445ms/epoch - 11ms/step
# Epoch 16/40
# 42/42 - 0s - loss: 0.9844 - accuracy: 0.6958 - val_loss: 1.0607 - val_accuracy: 0.7023 - lr: 1.0000e-04 - 464ms/epoch - 11ms/step
# Epoch 17/40
# 42/42 - 0s - loss: 0.9726 - accuracy: 0.6951 - val_loss: 1.0194 - val_accuracy: 0.7105 - lr: 1.0000e-04 - 464ms/epoch - 11ms/step
# Epoch 18/40
# 42/42 - 0s - loss: 0.9617 - accuracy: 0.7003 - val_loss: 0.9876 - val_accuracy: 0.7143 - lr: 1.0000e-04 - 463ms/epoch - 11ms/step
# Epoch 19/40
# 42/42 - 0s - loss: 0.9532 - accuracy: 0.7022 - val_loss: 0.9641 - val_accuracy: 0.7165 - lr: 1.0000e-04 - 455ms/epoch - 11ms/step
# Epoch 20/40
# 42/42 - 0s - loss: 0.9439 - accuracy: 0.7033 - val_loss: 0.9454 - val_accuracy: 0.7225 - lr: 1.0000e-04 - 469ms/epoch - 11ms/step
# Epoch 21/40
# 42/42 - 0s - loss: 0.9267 - accuracy: 0.7043 - val_loss: 0.9299 - val_accuracy: 0.7263 - lr: 1.0000e-04 - 464ms/epoch - 11ms/step
# Epoch 22/40
# 42/42 - 1s - loss: 0.9193 - accuracy: 0.7095 - val_loss: 0.9164 - val_accuracy: 0.7300 - lr: 1.0000e-04 - 511ms/epoch - 12ms/step
# Epoch 23/40
# 42/42 - 0s - loss: 0.9071 - accuracy: 0.7106 - val_loss: 0.9049 - val_accuracy: 0.7315 - lr: 1.0000e-04 - 480ms/epoch - 11ms/step
# Epoch 24/40
# 42/42 - 0s - loss: 0.9001 - accuracy: 0.7142 - val_loss: 0.8956 - val_accuracy: 0.7345 - lr: 1.0000e-04 - 471ms/epoch - 11ms/step
# Epoch 25/40
# 42/42 - 0s - loss: 0.8898 - accuracy: 0.7147 - val_loss: 0.8862 - val_accuracy: 0.7337 - lr: 1.0000e-04 - 458ms/epoch - 11ms/step
# Epoch 26/40
# 42/42 - 0s - loss: 0.8831 - accuracy: 0.7250 - val_loss: 0.8772 - val_accuracy: 0.7352 - lr: 1.0000e-04 - 440ms/epoch - 10ms/step
# Epoch 27/40
# 42/42 - 0s - loss: 0.8786 - accuracy: 0.7209 - val_loss: 0.8685 - val_accuracy: 0.7382 - lr: 1.0000e-04 - 483ms/epoch - 12ms/step
# Epoch 28/40
# 42/42 - 0s - loss: 0.8680 - accuracy: 0.7271 - val_loss: 0.8609 - val_accuracy: 0.7420 - lr: 1.0000e-04 - 446ms/epoch - 11ms/step
# Epoch 29/40
# 42/42 - 1s - loss: 0.8578 - accuracy: 0.7306 - val_loss: 0.8536 - val_accuracy: 0.7442 - lr: 1.0000e-04 - 506ms/epoch - 12ms/step
# Epoch 30/40
# 42/42 - 0s - loss: 0.8522 - accuracy: 0.7342 - val_loss: 0.8465 - val_accuracy: 0.7442 - lr: 1.0000e-04 - 455ms/epoch - 11ms/step
# Epoch 31/40
# 42/42 - 0s - loss: 0.8442 - accuracy: 0.7379 - val_loss: 0.8394 - val_accuracy: 0.7472 - lr: 1.0000e-04 - 453ms/epoch - 11ms/step
# Epoch 32/40
# 42/42 - 0s - loss: 0.8388 - accuracy: 0.7377 - val_loss: 0.8327 - val_accuracy: 0.7674 - lr: 1.0000e-04 - 448ms/epoch - 11ms/step
# Epoch 33/40
# 42/42 - 0s - loss: 0.8322 - accuracy: 0.7391 - val_loss: 0.8259 - val_accuracy: 0.7696 - lr: 1.0000e-04 - 428ms/epoch - 10ms/step
# Epoch 34/40
# 42/42 - 0s - loss: 0.8244 - accuracy: 0.7430 - val_loss: 0.8193 - val_accuracy: 0.7719 - lr: 1.0000e-04 - 487ms/epoch - 12ms/step
# Epoch 35/40
# 42/42 - 0s - loss: 0.8186 - accuracy: 0.7486 - val_loss: 0.8128 - val_accuracy: 0.7734 - lr: 1.0000e-04 - 439ms/epoch - 10ms/step
# Epoch 36/40
# 42/42 - 0s - loss: 0.8175 - accuracy: 0.7435 - val_loss: 0.8070 - val_accuracy: 0.7756 - lr: 1.0000e-04 - 438ms/epoch - 10ms/step
# Epoch 37/40
# 42/42 - 0s - loss: 0.8061 - accuracy: 0.7484 - val_loss: 0.8017 - val_accuracy: 0.7756 - lr: 1.0000e-04 - 456ms/epoch - 11ms/step
# Epoch 38/40
# 42/42 - 0s - loss: 0.8000 - accuracy: 0.7531 - val_loss: 0.7959 - val_accuracy: 0.7771 - lr: 1.0000e-04 - 439ms/epoch - 10ms/step
# Epoch 39/40
# 42/42 - 0s - loss: 0.7979 - accuracy: 0.7559 - val_loss: 0.7909 - val_accuracy: 0.7779 - lr: 1.0000e-04 - 418ms/epoch - 10ms/step
# Epoch 40/40
# 42/42 - 0s - loss: 0.7862 - accuracy: 0.7594 - val_loss: 0.7855 - val_accuracy: 0.7779 - lr: 1.0000e-04 - 472ms/epoch - 11ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpunrt8gpp/assets
# INFO:tensorflow:Assets written to: /tmp/tmpunrt8gpp/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-03 02:35:25.341785: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-03 02:35:25.341833: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-03 02:35:25.343214: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpunrt8gpp
# 2026-03-03 02:35:25.346131: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-03 02:35:25.346148: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpunrt8gpp
# 2026-03-03 02:35:25.355310: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2026-03-03 02:35:25.356478: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-03 02:35:25.390163: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpunrt8gpp
# 2026-03-03 02:35:25.400868: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 57656 microseconds.
# 2026-03-03 02:35:25.431381: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Epoch 1/8
# 2026-03-03 02:35:28.745715: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 12830400 exceeds 10% of free system memory.
# 2026-03-03 02:35:28.777189: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 12830400 exceeds 10% of free system memory.
# 2026-03-03 02:35:29.951850: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x42e38f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2026-03-03 02:35:29.952054: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2026-03-03 02:35:30.042665: E ./tensorflow/compiler/xla/stream_executor/stream_executor_internal.h:124] SetPriority unimplemented for this stream.
# 2026-03-03 02:35:30.042861: E ./tensorflow/compiler/xla/stream_executor/stream_executor_internal.h:124] SetPriority unimplemented for this stream.
# 2026-03-03 02:35:30.043045: E ./tensorflow/compiler/xla/stream_executor/stream_executor_internal.h:124] SetPriority unimplemented for this stream.
# 2026-03-03 02:35:30.043406: E ./tensorflow/compiler/xla/stream_executor/stream_executor_internal.h:124] SetPriority unimplemented for this stream.
# 2026-03-03 02:35:30.043838: E ./tensorflow/compiler/xla/stream_executor/stream_executor_internal.h:124] SetPriority unimplemented for this stream.
# 42/42 - 6s - loss: 0.7700 - accuracy: 0.7615 - val_loss: 0.7164 - val_accuracy: 0.7853 - 6s/epoch - 149ms/step
# Epoch 2/8
# 42/42 - 5s - loss: 0.7184 - accuracy: 0.7785 - val_loss: 0.6766 - val_accuracy: 0.7883 - 5s/epoch - 120ms/step
# Epoch 3/8
# 42/42 - 5s - loss: 0.6800 - accuracy: 0.7922 - val_loss: 0.6422 - val_accuracy: 0.7913 - 5s/epoch - 119ms/step
# Epoch 4/8
# 42/42 - 5s - loss: 0.6503 - accuracy: 0.7961 - val_loss: 0.6118 - val_accuracy: 0.7988 - 5s/epoch - 119ms/step
# Epoch 5/8
# 42/42 - 5s - loss: 0.6213 - accuracy: 0.8043 - val_loss: 0.5905 - val_accuracy: 0.8018 - 5s/epoch - 128ms/step
# Epoch 6/8
# 42/42 - 6s - loss: 0.6014 - accuracy: 0.8079 - val_loss: 0.5734 - val_accuracy: 0.8003 - 6s/epoch - 134ms/step
# Epoch 7/8
# 42/42 - 5s - loss: 0.5780 - accuracy: 0.8107 - val_loss: 0.5601 - val_accuracy: 0.8018 - 5s/epoch - 126ms/step
# Epoch 8/8
# 42/42 - 6s - loss: 0.5627 - accuracy: 0.8120 - val_loss: 0.5460 - val_accuracy: 0.8040 - 6s/epoch - 138ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpr1f_6ciu/assets
# INFO:tensorflow:Assets written to: /tmp/tmpr1f_6ciu/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-03 02:36:15.588687: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-03 02:36:15.588739: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-03 02:36:15.593102: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpr1f_6ciu
# 2026-03-03 02:36:15.598945: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-03 02:36:15.598966: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpr1f_6ciu
# 2026-03-03 02:36:15.620995: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-03 02:36:15.716536: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpr1f_6ciu
# 2026-03-03 02:36:15.743400: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 150227 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/40
# 2026-03-03 02:36:19.489256: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inrepmobile_folded_conv2d/repblock_0_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 42/42 - 2s - loss: 1.6594 - accuracy: 0.2686 - val_loss: 1.7822 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 2s/epoch - 50ms/step
# Epoch 2/40
# 42/42 - 0s - loss: 1.5391 - accuracy: 0.3601 - val_loss: 1.7702 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 462ms/epoch - 11ms/step
# Epoch 3/40
# 42/42 - 0s - loss: 1.4321 - accuracy: 0.4738 - val_loss: 1.7580 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 461ms/epoch - 11ms/step
# Epoch 4/40
# 42/42 - 1s - loss: 1.3536 - accuracy: 0.5705 - val_loss: 1.7453 - val_accuracy: 0.3540 - lr: 1.0000e-04 - 504ms/epoch - 12ms/step
# Epoch 5/40
# 42/42 - 0s - loss: 1.2815 - accuracy: 0.6353 - val_loss: 1.7328 - val_accuracy: 0.4289 - lr: 1.0000e-04 - 455ms/epoch - 11ms/step
# Epoch 6/40
# 42/42 - 0s - loss: 1.2256 - accuracy: 0.6631 - val_loss: 1.7211 - val_accuracy: 0.4266 - lr: 1.0000e-04 - 436ms/epoch - 10ms/step
# Epoch 7/40
# 42/42 - 0s - loss: 1.1821 - accuracy: 0.6755 - val_loss: 1.7075 - val_accuracy: 0.4266 - lr: 1.0000e-04 - 478ms/epoch - 11ms/step
# Epoch 8/40
# 42/42 - 0s - loss: 1.1438 - accuracy: 0.6791 - val_loss: 1.6848 - val_accuracy: 0.4870 - lr: 1.0000e-04 - 473ms/epoch - 11ms/step
# Epoch 9/40
# 42/42 - 0s - loss: 1.1123 - accuracy: 0.6821 - val_loss: 1.6421 - val_accuracy: 0.5107 - lr: 1.0000e-04 - 494ms/epoch - 12ms/step
# Epoch 10/40
# 42/42 - 0s - loss: 1.0835 - accuracy: 0.6842 - val_loss: 1.5686 - val_accuracy: 0.5329 - lr: 1.0000e-04 - 451ms/epoch - 11ms/step
# Epoch 11/40
# 42/42 - 0s - loss: 1.0583 - accuracy: 0.6873 - val_loss: 1.4699 - val_accuracy: 0.5543 - lr: 1.0000e-04 - 482ms/epoch - 11ms/step
# Epoch 12/40
# 42/42 - 0s - loss: 1.0377 - accuracy: 0.6888 - val_loss: 1.3598 - val_accuracy: 0.6292 - lr: 1.0000e-04 - 408ms/epoch - 10ms/step
# Epoch 13/40
# 42/42 - 0s - loss: 1.0190 - accuracy: 0.6913 - val_loss: 1.2580 - val_accuracy: 0.6827 - lr: 1.0000e-04 - 453ms/epoch - 11ms/step
# Epoch 14/40
# 42/42 - 0s - loss: 0.9961 - accuracy: 0.6922 - val_loss: 1.1728 - val_accuracy: 0.6881 - lr: 1.0000e-04 - 467ms/epoch - 11ms/step
# Epoch 15/40
# 42/42 - 0s - loss: 0.9807 - accuracy: 0.6987 - val_loss: 1.1079 - val_accuracy: 0.6881 - lr: 1.0000e-04 - 420ms/epoch - 10ms/step
# Epoch 16/40
# 42/42 - 0s - loss: 0.9646 - accuracy: 0.7044 - val_loss: 1.0620 - val_accuracy: 0.7018 - lr: 1.0000e-04 - 432ms/epoch - 10ms/step
# Epoch 17/40
# 42/42 - 0s - loss: 0.9531 - accuracy: 0.7063 - val_loss: 1.0272 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 433ms/epoch - 10ms/step
# Epoch 18/40
# 42/42 - 0s - loss: 0.9335 - accuracy: 0.7152 - val_loss: 1.0039 - val_accuracy: 0.7118 - lr: 1.0000e-04 - 416ms/epoch - 10ms/step
# Epoch 19/40
# 42/42 - 0s - loss: 0.9210 - accuracy: 0.7200 - val_loss: 0.9867 - val_accuracy: 0.7118 - lr: 1.0000e-04 - 448ms/epoch - 11ms/step
# Epoch 20/40
# 42/42 - 0s - loss: 0.9060 - accuracy: 0.7253 - val_loss: 0.9720 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 428ms/epoch - 10ms/step
# Epoch 21/40
# 42/42 - 0s - loss: 0.8934 - accuracy: 0.7327 - val_loss: 0.9596 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 430ms/epoch - 10ms/step
# Epoch 22/40
# 42/42 - 0s - loss: 0.8886 - accuracy: 0.7333 - val_loss: 0.9487 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 433ms/epoch - 10ms/step
# Epoch 23/40
# 42/42 - 0s - loss: 0.8763 - accuracy: 0.7426 - val_loss: 0.9426 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 450ms/epoch - 11ms/step
# Epoch 24/40
# 42/42 - 0s - loss: 0.8655 - accuracy: 0.7470 - val_loss: 0.9339 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 445ms/epoch - 11ms/step
# Epoch 25/40
# 42/42 - 0s - loss: 0.8580 - accuracy: 0.7480 - val_loss: 0.9283 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 466ms/epoch - 11ms/step
# Epoch 26/40
# 42/42 - 0s - loss: 0.8431 - accuracy: 0.7573 - val_loss: 0.9246 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 450ms/epoch - 11ms/step
# Epoch 27/40
# 42/42 - 0s - loss: 0.8374 - accuracy: 0.7546 - val_loss: 0.9178 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 470ms/epoch - 11ms/step
# Epoch 28/40
# 42/42 - 0s - loss: 0.8314 - accuracy: 0.7607 - val_loss: 0.9154 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 458ms/epoch - 11ms/step
# Epoch 29/40
# 42/42 - 0s - loss: 0.8214 - accuracy: 0.7643 - val_loss: 0.9117 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 474ms/epoch - 11ms/step
# Epoch 30/40
# 42/42 - 0s - loss: 0.8169 - accuracy: 0.7708 - val_loss: 0.9077 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 457ms/epoch - 11ms/step
# Epoch 31/40
# 42/42 - 0s - loss: 0.8070 - accuracy: 0.7691 - val_loss: 0.9028 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 450ms/epoch - 11ms/step
# Epoch 32/40
# 42/42 - 0s - loss: 0.7963 - accuracy: 0.7769 - val_loss: 0.8986 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 459ms/epoch - 11ms/step
# Epoch 33/40
# 42/42 - 0s - loss: 0.7911 - accuracy: 0.7769 - val_loss: 0.8931 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 443ms/epoch - 11ms/step
# Epoch 34/40
# 42/42 - 0s - loss: 0.7833 - accuracy: 0.7828 - val_loss: 0.8875 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 441ms/epoch - 10ms/step
# Epoch 35/40
# 42/42 - 0s - loss: 0.7765 - accuracy: 0.7858 - val_loss: 0.8823 - val_accuracy: 0.7102 - lr: 1.0000e-04 - 422ms/epoch - 10ms/step
# Epoch 36/40
# 42/42 - 0s - loss: 0.7726 - accuracy: 0.7850 - val_loss: 0.8817 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 436ms/epoch - 10ms/step
# Epoch 37/40
# 42/42 - 0s - loss: 0.7649 - accuracy: 0.7875 - val_loss: 0.8771 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 418ms/epoch - 10ms/step
# Epoch 38/40
# 42/42 - 0s - loss: 0.7583 - accuracy: 0.7889 - val_loss: 0.8733 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 439ms/epoch - 10ms/step
# Epoch 39/40
# 42/42 - 0s - loss: 0.7532 - accuracy: 0.7921 - val_loss: 0.8673 - val_accuracy: 0.7080 - lr: 1.0000e-04 - 435ms/epoch - 10ms/step
# Epoch 40/40
# 42/42 - 0s - loss: 0.7475 - accuracy: 0.7936 - val_loss: 0.8636 - val_accuracy: 0.7080 - lr: 1.0000e-04 - 422ms/epoch - 10ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpyvbiaeae/assets
# INFO:tensorflow:Assets written to: /tmp/tmpyvbiaeae/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-03 02:36:41.371536: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-03 02:36:41.371579: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-03 02:36:41.371725: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpyvbiaeae
# 2026-03-03 02:36:41.374947: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-03 02:36:41.374961: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpyvbiaeae
# 2026-03-03 02:36:41.381932: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-03 02:36:41.410397: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpyvbiaeae
# 2026-03-03 02:36:41.420914: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 49190 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/8
# 2026-03-03 02:36:45.428222: E ./tensorflow/compiler/xla/stream_executor/stream_executor_internal.h:124] SetPriority unimplemented for this stream.
# 42/42 - 6s - loss: 0.7197 - accuracy: 0.7976 - val_loss: 0.7743 - val_accuracy: 0.7286 - 6s/epoch - 154ms/step
# Epoch 2/8
# 42/42 - 5s - loss: 0.6702 - accuracy: 0.8069 - val_loss: 0.7438 - val_accuracy: 0.7378 - 5s/epoch - 115ms/step
# Epoch 3/8
# 42/42 - 5s - loss: 0.6272 - accuracy: 0.8172 - val_loss: 0.7175 - val_accuracy: 0.7523 - 5s/epoch - 112ms/step
# Epoch 4/8
# 42/42 - 5s - loss: 0.5942 - accuracy: 0.8229 - val_loss: 0.7019 - val_accuracy: 0.7492 - 5s/epoch - 112ms/step
# Epoch 5/8
# 42/42 - 5s - loss: 0.5656 - accuracy: 0.8231 - val_loss: 0.7010 - val_accuracy: 0.7378 - 5s/epoch - 113ms/step
# Epoch 6/8
# 42/42 - 5s - loss: 0.5448 - accuracy: 0.8261 - val_loss: 0.6956 - val_accuracy: 0.7408 - 5s/epoch - 111ms/step
# Epoch 7/8
# 42/42 - 5s - loss: 0.5200 - accuracy: 0.8290 - val_loss: 0.6970 - val_accuracy: 0.7339 - 5s/epoch - 111ms/step
# Epoch 8/8
# 42/42 - 5s - loss: 0.5000 - accuracy: 0.8292 - val_loss: 0.6877 - val_accuracy: 0.7362 - 5s/epoch - 113ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpm8d3dl0s/assets
# INFO:tensorflow:Assets written to: /tmp/tmpm8d3dl0s/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-03 02:37:27.032343: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-03 02:37:27.032396: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-03 02:37:27.033371: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpm8d3dl0s
# 2026-03-03 02:37:27.039046: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-03 02:37:27.039070: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpm8d3dl0s
# 2026-03-03 02:37:27.057618: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-03 02:37:27.145521: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpm8d3dl0s
# 2026-03-03 02:37:27.173433: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 140063 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/dellio/github/har-mcu/src/eval/paper_comparison.py:185: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# {'paper_slug': 'repmobile',
#  'rows': [{'paper_slug': 'repmobile',
#    'protocol': 'random_stratified',
#    'variant': 'repmobile_folded_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'cpu',
#    'eval_qat_device': 'cpu',
#    'fp32_training_time_sec': 23.348663579992717,
#    'qat_training_time_sec': 43.36158431900549,
#    'accuracy': 0.7715674362089915,
#    'macro_f1': 0.577059167353506,
#    'ptq_status': 'failed',
#    'qat_status': 'failed',
#    'ptq_accuracy': 0.7688335358444714,
#    'ptq_macro_f1': 0.5744271191201293,
#    'qat_accuracy': 0.8071081409477521,
#    'qat_macro_f1': 0.6031907060929053,
#    'ptq_model_size_kb': 43.4140625,
#    'qat_model_size_kb': 46.9140625,
#    'model_size_kb': 43.4140625,
#    'ptq_inference_latency_ms_median': 0.4046955000376329,
#    'ptq_inference_latency_ms_p95': 0.4454810004972387,
#    'qat_inference_latency_ms_median': 0.5415110063040629,
#    'qat_inference_latency_ms_p95': 0.6000085049890913,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_fp32_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_qat_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_ptq_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_qat_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'deploy_gate': {'ptq': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'unsupported_ops': ['DEPTHWISE_CONV_2D', 'MEAN']},
#     'qat': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'unsupported_ops': ['DEPTHWISE_CONV_2D', 'MEAN']}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_repmobile_folded_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_export_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_export_repmobile_folded_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/repmobile/artifacts/repmobile_repmobile_folded_conv2d_random_stratified_wisdm_r0.json'},
#   {'paper_slug': 'repmobile',
#    'protocol': 'user_holdout',
#    'variant': 'repmobile_folded_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'cpu',
#    'eval_qat_device': 'cpu',
#    'fp32_training_time_sec': 19.805762067000614,
#    'qat_training_time_sec': 39.64139947600779,
#    'accuracy': 0.7372434017595307,
#    'macro_f1': 0.5323846994461402,
#    'ptq_status': 'failed',
#    'qat_status': 'failed',
#    'ptq_accuracy': 0.7284457478005865,
#    'ptq_macro_f1': 0.5315173051412764,
#    'qat_accuracy': 0.7627565982404693,
#    'qat_macro_f1': 0.5184094806975891,
#    'ptq_model_size_kb': 43.4140625,
#    'qat_model_size_kb': 46.9140625,
#    'model_size_kb': 43.4140625,
#    'ptq_inference_latency_ms_median': 0.40797999827191234,
#    'ptq_inference_latency_ms_p95': 0.4412935049913358,
#    'qat_inference_latency_ms_median': 0.539925997145474,
#    'qat_inference_latency_ms_p95': 0.6573759965249337,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_fp32_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/repmobile/curve_qat_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_ptq_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/repmobile/confusion_qat_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'deploy_gate': {'ptq': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'unsupported_ops': ['DEPTHWISE_CONV_2D', 'MEAN']},
#     'qat': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'unsupported_ops': ['DEPTHWISE_CONV_2D', 'MEAN']}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_repmobile_folded_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/repmobile/ptq_export_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/repmobile/qat_export_repmobile_folded_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/repmobile/artifacts/repmobile_repmobile_folded_conv2d_user_holdout_wisdm_r0.json'}],
#  'paper_exports': {'random_stratified': {'csv': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_results_random_stratified.csv',
#    'md': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_summary.md'},
#   'user_holdout': {'csv': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_results_user_holdout.csv',
#    'md': '/home/dellio/github/har-mcu/reports/repmobile/repmobile_summary.md'}},
#  'comparison_exports': {'csv': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison.csv',
#   'md': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison.md',
#   'accuracy_png': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison_accuracy.png',
#   'size_png': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison_size.png',
#   'latency_png': '/home/dellio/github/har-mcu/reports/repmobile/comparison/repmobile_comparison_latency.png'},
#  'master_exports': {'csv': '/home/dellio/github/har-mcu/reports/results_master.csv',
#   'md': '/home/dellio/github/har-mcu/reports/results_master.md'}}

# %%
# Run-level summary table
rows_df = pd.DataFrame(out["rows"])
display(rows_df)

# Build DeepConvLSTM-style paper-target vs WISDM replication rows
paper_targets = cfg.get("experiment", {}).get("paper_targets", {}) or {}
target_by_model = {
    "baseline float": paper_targets.get("fp32_accuracy"),
    "PTQ int8": paper_targets.get("ptq_accuracy"),
    "QAT int8": paper_targets.get("qat_accuracy"),
}

_comp_rows = []
for _model in ["baseline float", "PTQ int8", "QAT int8"]:
    _comp_rows.append(
        {
            "pipeline": "paper target",
            "protocol": "—",
            "model": _model,
            "accuracy": target_by_model.get(_model),
            "macro_f1": None,
            "model_size_kb": None,
            "training_time_sec": None,
            "inference_latency_ms_median": None,
            "inference_latency_ms_p95": None,
            "acc_delta_vs_target": None,
        }
    )

for _r in out["rows"]:
    _proto = _r.get("protocol")
    _fp32_target = target_by_model.get("baseline float")
    _ptq_target = target_by_model.get("PTQ int8")
    _qat_target = target_by_model.get("QAT int8")

    _fp32_acc = float(_r["accuracy"]) if _r.get("accuracy") is not None else None
    _fp32_f1 = float(_r["macro_f1"]) if _r.get("macro_f1") is not None else None
    _comp_rows.append(
        {
            "pipeline": "WISDM replication",
            "protocol": _proto,
            "model": "baseline float",
            "accuracy": round(_fp32_acc, 4) if _fp32_acc is not None else None,
            "macro_f1": round(_fp32_f1, 4) if _fp32_f1 is not None else None,
            "model_size_kb": None,
            "training_time_sec": _r.get("fp32_training_time_sec"),
            "inference_latency_ms_median": None,
            "inference_latency_ms_p95": None,
            "acc_delta_vs_target": round(_fp32_acc - float(_fp32_target), 4)
            if _fp32_acc is not None and _fp32_target is not None
            else None,
        }
    )

    _ptq_acc = float(_r["ptq_accuracy"]) if _r.get("ptq_accuracy") is not None else None
    _ptq_f1 = float(_r["ptq_macro_f1"]) if _r.get("ptq_macro_f1") is not None else None
    _comp_rows.append(
        {
            "pipeline": "WISDM replication",
            "protocol": _proto,
            "model": "PTQ int8",
            "accuracy": round(_ptq_acc, 4) if _ptq_acc is not None else None,
            "macro_f1": round(_ptq_f1, 4) if _ptq_f1 is not None else None,
            "model_size_kb": _r.get("ptq_model_size_kb"),
            "training_time_sec": None,
            "inference_latency_ms_median": _r.get("ptq_inference_latency_ms_median"),
            "inference_latency_ms_p95": _r.get("ptq_inference_latency_ms_p95"),
            "acc_delta_vs_target": round(_ptq_acc - float(_ptq_target), 4)
            if _ptq_acc is not None and _ptq_target is not None
            else None,
        }
    )

    _qat_acc = float(_r["qat_accuracy"]) if _r.get("qat_accuracy") is not None else None
    _qat_f1 = float(_r["qat_macro_f1"]) if _r.get("qat_macro_f1") is not None else None
    _comp_rows.append(
        {
            "pipeline": "WISDM replication",
            "protocol": _proto,
            "model": "QAT int8",
            "accuracy": round(_qat_acc, 4) if _qat_acc is not None else None,
            "macro_f1": round(_qat_f1, 4) if _qat_f1 is not None else None,
            "model_size_kb": _r.get("qat_model_size_kb"),
            "training_time_sec": _r.get("qat_training_time_sec"),
            "inference_latency_ms_median": _r.get("qat_inference_latency_ms_median"),
            "inference_latency_ms_p95": _r.get("qat_inference_latency_ms_p95"),
            "acc_delta_vs_target": round(_qat_acc - float(_qat_target), 4)
            if _qat_acc is not None and _qat_target is not None
            else None,
        }
    )

comp_df = pd.DataFrame(_comp_rows).reset_index(drop=True)
display(
    comp_df.style.format(
        {
            "accuracy": lambda v: f"{v:.4f}" if v is not None and pd.notna(v) else "—",
            "macro_f1": lambda v: f"{v:.4f}" if v is not None and pd.notna(v) else "—",
            "model_size_kb": lambda v: f"{v:.2f}" if v is not None and pd.notna(v) else "—",
            "training_time_sec": lambda v: f"{v:.2f}s" if v is not None and pd.notna(v) else "—",
            "inference_latency_ms_median": lambda v: f"{v:.3f}ms" if v is not None and pd.notna(v) else "—",
            "inference_latency_ms_p95": lambda v: f"{v:.3f}ms" if v is not None and pd.notna(v) else "—",
            "acc_delta_vs_target": lambda v: f"{v:+.4f}" if v is not None and pd.notna(v) else "—",
        }
    )
    .applymap(
        lambda v: "color: green"
        if isinstance(v, float) and v > 0
        else ("color: red" if isinstance(v, float) and v < -0.0001 else ""),
        subset=["acc_delta_vs_target"],
    )
    .set_caption(
        "Table 1 — Accuracy, macro F1, model size, timing, and accuracy delta vs paper target (baseline/PTQ/QAT)"
    )
)

print("Note: Paper-target QAT may be unavailable in source papers; QAT rows here are replication extensions where target is N/A.")

# Accuracy chart
_plot_rows = [r for r in _comp_rows if r["accuracy"] is not None]
_labels = [
    f"{r['pipeline'].replace('(', '').replace(')', '').strip()}\n{r['protocol']}\n{r['model']}"
    for r in _plot_rows
]
_accs = [float(r["accuracy"]) for r in _plot_rows]

_colors = []
for r in _plot_rows:
    if r["pipeline"] == "paper target":
        if r["model"] == "baseline float":
            _colors.append("#9e9e9e")
        elif r["model"] == "PTQ int8":
            _colors.append("#bdbdbd")
        else:
            _colors.append("#d9d9d9")
    else:
        if r["model"] == "baseline float":
            _colors.append("#1f77b4")
        elif r["model"] == "PTQ int8":
            _colors.append("#ff7f0e")
        else:
            _colors.append("#2ca02c")

if _plot_rows:
    fig, ax = plt.subplots(figsize=(max(10, len(_plot_rows) * 1.4), 5.6))
    bars = ax.bar(_labels, _accs, color=_colors, edgecolor="white", width=0.6)

    _target_baseline = target_by_model.get("baseline float")
    _target_ptq = target_by_model.get("PTQ int8")
    if _target_baseline is not None:
        ax.axhline(float(_target_baseline), color="#1f77b4", linestyle="--", linewidth=1.0, label=f"Paper target baseline ({float(_target_baseline):.4f})")
    if _target_ptq is not None:
        ax.axhline(float(_target_ptq), color="#ff7f0e", linestyle="--", linewidth=1.0, label=f"Paper target PTQ ({float(_target_ptq):.4f})")

    for bar, acc in zip(bars, _accs):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.002, f"{acc:.4f}", ha="center", va="bottom", fontsize=8)

    ax.set_ylim(max(0.0, min(_accs) - 0.05), 1.02)
    ax.set_ylabel("Accuracy")
    ax.set_title("Paper Target vs WISDM Replication — Accuracy comparison (baseline/PTQ/QAT)")
    ax.text(
        0.01,
        0.02,
        "Note: QAT paper-target values may be unavailable; those are shown as replication-only rows.",
        transform=ax.transAxes,
        fontsize=8,
        ha="left",
        va="bottom",
        bbox={"facecolor": "white", "alpha": 0.85, "edgecolor": "none"},
    )
    ax.legend(fontsize=8)
    ax.grid(axis="y", alpha=0.4)
    plt.xticks(fontsize=7.5)
    plt.tight_layout()
    plt.show()
else:
    print("(No accuracy rows available for comparison chart.)")

# Model size table/chart
_size_rows = [
    r
    for r in _comp_rows
    if r["model"] in {"PTQ int8", "QAT int8"} and r["model_size_kb"] is not None and r["pipeline"] == "WISDM replication"
]
if _size_rows:
    size_df = pd.DataFrame(
        [(r["pipeline"], r["protocol"], r["model"], r["model_size_kb"]) for r in _size_rows],
        columns=["pipeline", "protocol", "model", "model_size_kb"],
    )
    display(size_df.style.format({"model_size_kb": "{:.2f} KB"}).set_caption("Table 2 — Quantized model size (PTQ/QAT)"))

# Latency chart (median + p95)
_latency_rows = [
    r
    for r in _comp_rows
    if r["pipeline"] == "WISDM replication"
    and r["model"] in {"PTQ int8", "QAT int8"}
    and r["inference_latency_ms_median"] is not None
]
if _latency_rows:
    _lat_df = pd.DataFrame(_latency_rows)
    _labels = [f"{r['protocol']}\n{r['model']}" for r in _latency_rows]
    _x = np.arange(len(_latency_rows))
    _med = _lat_df["inference_latency_ms_median"].astype(float).to_numpy()
    _p95 = _lat_df["inference_latency_ms_p95"].astype(float).to_numpy()
    _w = 0.38
    fig, ax = plt.subplots(figsize=(max(8, len(_latency_rows) * 1.2), 5.0))
    ax.bar(_x - _w / 2, _med, width=_w, label="median (ms)", color="#59a14f")
    ax.bar(_x + _w / 2, _p95, width=_w, label="p95 (ms)", color="#e15759")
    ax.set_xticks(_x)
    ax.set_xticklabels(_labels, fontsize=8)
    ax.set_ylabel("Latency (ms/sample)")
    ax.set_title("TFLite Inference Latency (Median + p95)")
    ax.legend()
    ax.grid(axis="y", alpha=0.35)
    plt.tight_layout()
    plt.show()

# Reproducibility drift (repeat FP32 evaluation from saved checkpoint)
print("\nReproducibility drift — WISDM replication (repeat evaluation on saved checkpoint):")
DRIFT_TOL = 1e-9
repro_rows = []
paper_reports_dir = Path(cfg["paths"]["reports_dir"]) / cfg["experiment"]["paper_slug"]

for _r in out["rows"]:
    _proto = _r["protocol"]
    _ws = int(_r["window_size"])
    _run_id = str(_r["run_id"])
    _variant = str(_r["variant"])
    _split_path = split_npz_path(cfg["paths"]["processed_dir"], _ws, _proto)
    _split_hash = None
    if _split_path.exists():
        with np.load(_split_path, allow_pickle=True) as _npz:
            if "split_hash" in _npz:
                _raw_hash = _npz["split_hash"]
                _split_hash = _raw_hash.item() if hasattr(_raw_hash, "item") else str(_raw_hash)

    _ckpt = model_ckpt_path(
        cfg["paths"]["checkpoints_dir"],
        model_name=_variant,
        window_size=_ws,
        protocol=_proto,
        run_id=_run_id,
    )
    _repeat_out = evaluate_model_for_protocol(
        cfg,
        model_path=str(_ckpt),
        protocol=_proto,
        window_size=_ws,
        run_id=_run_id,
        reports_dir_override=paper_reports_dir,
    )
    _repeat_metrics = json.loads(Path(_repeat_out["metrics_json"]).read_text(encoding="utf-8"))

    _first_acc = float(_r["accuracy"])
    _repeat_acc = float(_repeat_metrics["accuracy"])
    _drift = abs(_repeat_acc - _first_acc)

    repro_rows.append(
        {
            "protocol": _proto,
            "split_hash": _split_hash,
            "baseline_acc_first": _first_acc,
            "baseline_acc_repeat": _repeat_acc,
            "abs_drift": _drift,
            "status": "PASS" if _drift <= DRIFT_TOL else "WARN",
        }
    )

repro_df = pd.DataFrame(repro_rows)
display(
    repro_df[["protocol", "split_hash", "baseline_acc_first", "baseline_acc_repeat", "abs_drift", "status"]]
    .style
    .format(
        {
            "baseline_acc_first": "{:.4f}",
            "baseline_acc_repeat": "{:.4f}",
            "abs_drift": "{:.2e}",
        }
    )
    .applymap(lambda v: "color: green" if v == "PASS" else ("color: orange" if v == "WARN" else ""), subset=["status"])
    .set_caption("Table 3 — Reproducibility drift (two consecutive FP32 evaluations)")
)

# Curves + confusion matrices
for r in out["rows"]:
    display(Markdown(f"### Protocol: `{r.get('protocol')}`"))
    for label, key in [
        ("FP32 training curve", "fp32_curve_png"),
        ("QAT training curve", "qat_curve_png"),
        ("FP32 confusion", "fp32_confusion_plot"),
        ("PTQ confusion", "ptq_confusion_plot"),
        ("QAT confusion", "qat_confusion_plot"),
    ]:
        p = r.get(key)
        if p and Path(p).exists():
            display(Markdown(f"**{label}**"))
            display(Image(filename=str(p), width=760))

# Condensed classification report display
for r in out["rows"]:
    display(Markdown(f"### Classification Report Snippets — `{r.get('protocol')}`"))
    for tier, key in [
        ("FP32", "fp32_metrics_json"),
        ("PTQ", "ptq_metrics_json"),
        ("QAT", "qat_metrics_json"),
    ]:
        metrics_path = r.get(key)
        if not metrics_path or not Path(metrics_path).exists():
            continue
        payload = json.loads(Path(metrics_path).read_text(encoding="utf-8"))
        cr = payload.get("classification_report", {})
        macro = cr.get("macro avg", {}) if isinstance(cr, dict) else {}
        weighted = cr.get("weighted avg", {}) if isinstance(cr, dict) else {}
        print(f"{tier}: macro_f1={macro.get('f1-score')}, weighted_f1={weighted.get('f1-score')}")

# Paper comparison exports (table + charts)
cmp = out.get("comparison_exports", {})
if cmp.get("csv") and Path(cmp["csv"]).exists():
    display(Markdown("## Saved Comparison CSV Snapshot"))
    display(pd.read_csv(cmp["csv"]))
for key in ["accuracy_png", "size_png", "latency_png"]:
    p = cmp.get(key)
    if p and Path(p).exists():
        display(Image(filename=str(p), width=920))

# Master aggregate snapshot
master_csv = Path(cfg["paths"]["reports_dir"]) / "results_master.csv"
if master_csv.exists():
    df_master = pd.read_csv(master_csv)
    display(Markdown("## Master Results Snapshot"))
    display(df_master[df_master["paper_slug"] == cfg["experiment"]["paper_slug"]])

print("Saved outputs root:", Path(cfg["paths"]["reports_dir"]) / cfg["experiment"]["paper_slug"])
# Out:
#   paper_slug           protocol                  variant    run_id  \
# 0  repmobile  random_stratified  repmobile_folded_conv2d  wisdm_r0
# 1  repmobile       user_holdout  repmobile_folded_conv2d  wisdm_r0
#
#    window_size  seed compression_focus      run_mode train_device  \
# 0          200    42      ptq_qat_only  sanity_check          gpu
# 1          200    42      ptq_qat_only  sanity_check          gpu
#
#   eval_fp32_device  ...                                        deploy_gate  \
# 0              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
# 1              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
#
#   paper_target_score delta_vs_paper notes_assumptions  \
# 0               None           None              None
# 1               None           None              None
#
#                                    fp32_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     ptq_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     qat_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      ptq_report_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      qat_report_json  \
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                    run_artifact_json
# 0  /home/dellio/github/har-mcu/reports/repmobile/...
# 1  /home/dellio/github/har-mcu/reports/repmobile/...
#
# [2 rows x 48 columns]
# /tmp/ipykernel_5060/2087302422.py:95: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   comp_df.style.format(
# <style type="text/css">
# </style>
# <table id="T_4aa95">
#   <caption>Table 1 — Accuracy, macro F1, model size, timing, and accuracy delta vs paper target (baseline/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4aa95_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_4aa95_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_4aa95_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_4aa95_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_4aa95_level0_col4" class="col_heading level0 col4" >macro_f1</th>
#       <th id="T_4aa95_level0_col5" class="col_heading level0 col5" >model_size_kb</th>
#       <th id="T_4aa95_level0_col6" class="col_heading level0 col6" >training_time_sec</th>
#       <th id="T_4aa95_level0_col7" class="col_heading level0 col7" >inference_latency_ms_median</th>
#       <th id="T_4aa95_level0_col8" class="col_heading level0 col8" >inference_latency_ms_p95</th>
#       <th id="T_4aa95_level0_col9" class="col_heading level0 col9" >acc_delta_vs_target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4aa95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4aa95_row0_col0" class="data row0 col0" >paper target</td>
#       <td id="T_4aa95_row0_col1" class="data row0 col1" >—</td>
#       <td id="T_4aa95_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_4aa95_row0_col3" class="data row0 col3" >—</td>
#       <td id="T_4aa95_row0_col4" class="data row0 col4" >—</td>
#       <td id="T_4aa95_row0_col5" class="data row0 col5" >—</td>
#       <td id="T_4aa95_row0_col6" class="data row0 col6" >—</td>
#       <td id="T_4aa95_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_4aa95_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_4aa95_row0_col9" class="data row0 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4aa95_row1_col0" class="data row1 col0" >paper target</td>
#       <td id="T_4aa95_row1_col1" class="data row1 col1" >—</td>
#       <td id="T_4aa95_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_4aa95_row1_col3" class="data row1 col3" >—</td>
#       <td id="T_4aa95_row1_col4" class="data row1 col4" >—</td>
#       <td id="T_4aa95_row1_col5" class="data row1 col5" >—</td>
#       <td id="T_4aa95_row1_col6" class="data row1 col6" >—</td>
#       <td id="T_4aa95_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_4aa95_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_4aa95_row1_col9" class="data row1 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4aa95_row2_col0" class="data row2 col0" >paper target</td>
#       <td id="T_4aa95_row2_col1" class="data row2 col1" >—</td>
#       <td id="T_4aa95_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_4aa95_row2_col3" class="data row2 col3" >—</td>
#       <td id="T_4aa95_row2_col4" class="data row2 col4" >—</td>
#       <td id="T_4aa95_row2_col5" class="data row2 col5" >—</td>
#       <td id="T_4aa95_row2_col6" class="data row2 col6" >—</td>
#       <td id="T_4aa95_row2_col7" class="data row2 col7" >—</td>
#       <td id="T_4aa95_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_4aa95_row2_col9" class="data row2 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4aa95_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_4aa95_row3_col1" class="data row3 col1" >random_stratified</td>
#       <td id="T_4aa95_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_4aa95_row3_col3" class="data row3 col3" >0.7716</td>
#       <td id="T_4aa95_row3_col4" class="data row3 col4" >0.5771</td>
#       <td id="T_4aa95_row3_col5" class="data row3 col5" >—</td>
#       <td id="T_4aa95_row3_col6" class="data row3 col6" >23.35s</td>
#       <td id="T_4aa95_row3_col7" class="data row3 col7" >—</td>
#       <td id="T_4aa95_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_4aa95_row3_col9" class="data row3 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4aa95_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_4aa95_row4_col1" class="data row4 col1" >random_stratified</td>
#       <td id="T_4aa95_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_4aa95_row4_col3" class="data row4 col3" >0.7688</td>
#       <td id="T_4aa95_row4_col4" class="data row4 col4" >0.5744</td>
#       <td id="T_4aa95_row4_col5" class="data row4 col5" >43.41</td>
#       <td id="T_4aa95_row4_col6" class="data row4 col6" >—</td>
#       <td id="T_4aa95_row4_col7" class="data row4 col7" >0.405ms</td>
#       <td id="T_4aa95_row4_col8" class="data row4 col8" >0.445ms</td>
#       <td id="T_4aa95_row4_col9" class="data row4 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4aa95_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_4aa95_row5_col1" class="data row5 col1" >random_stratified</td>
#       <td id="T_4aa95_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_4aa95_row5_col3" class="data row5 col3" >0.8071</td>
#       <td id="T_4aa95_row5_col4" class="data row5 col4" >0.6032</td>
#       <td id="T_4aa95_row5_col5" class="data row5 col5" >46.91</td>
#       <td id="T_4aa95_row5_col6" class="data row5 col6" >43.36s</td>
#       <td id="T_4aa95_row5_col7" class="data row5 col7" >0.542ms</td>
#       <td id="T_4aa95_row5_col8" class="data row5 col8" >0.600ms</td>
#       <td id="T_4aa95_row5_col9" class="data row5 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4aa95_row6_col0" class="data row6 col0" >WISDM replication</td>
#       <td id="T_4aa95_row6_col1" class="data row6 col1" >user_holdout</td>
#       <td id="T_4aa95_row6_col2" class="data row6 col2" >baseline float</td>
#       <td id="T_4aa95_row6_col3" class="data row6 col3" >0.7372</td>
#       <td id="T_4aa95_row6_col4" class="data row6 col4" >0.5324</td>
#       <td id="T_4aa95_row6_col5" class="data row6 col5" >—</td>
#       <td id="T_4aa95_row6_col6" class="data row6 col6" >19.81s</td>
#       <td id="T_4aa95_row6_col7" class="data row6 col7" >—</td>
#       <td id="T_4aa95_row6_col8" class="data row6 col8" >—</td>
#       <td id="T_4aa95_row6_col9" class="data row6 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4aa95_row7_col0" class="data row7 col0" >WISDM replication</td>
#       <td id="T_4aa95_row7_col1" class="data row7 col1" >user_holdout</td>
#       <td id="T_4aa95_row7_col2" class="data row7 col2" >PTQ int8</td>
#       <td id="T_4aa95_row7_col3" class="data row7 col3" >0.7284</td>
#       <td id="T_4aa95_row7_col4" class="data row7 col4" >0.5315</td>
#       <td id="T_4aa95_row7_col5" class="data row7 col5" >43.41</td>
#       <td id="T_4aa95_row7_col6" class="data row7 col6" >—</td>
#       <td id="T_4aa95_row7_col7" class="data row7 col7" >0.408ms</td>
#       <td id="T_4aa95_row7_col8" class="data row7 col8" >0.441ms</td>
#       <td id="T_4aa95_row7_col9" class="data row7 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_4aa95_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4aa95_row8_col0" class="data row8 col0" >WISDM replication</td>
#       <td id="T_4aa95_row8_col1" class="data row8 col1" >user_holdout</td>
#       <td id="T_4aa95_row8_col2" class="data row8 col2" >QAT int8</td>
#       <td id="T_4aa95_row8_col3" class="data row8 col3" >0.7628</td>
#       <td id="T_4aa95_row8_col4" class="data row8 col4" >0.5184</td>
#       <td id="T_4aa95_row8_col5" class="data row8 col5" >46.91</td>
#       <td id="T_4aa95_row8_col6" class="data row8 col6" >39.64s</td>
#       <td id="T_4aa95_r
# Note: Paper-target QAT may be unavailable in source papers; QAT rows here are replication extensions where target is N/A.
# /tmp/ipykernel_5060/2087302422.py:171: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# <style type="text/css">
# </style>
# <table id="T_b212b">
#   <caption>Table 2 — Quantized model size (PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b212b_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_b212b_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_b212b_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_b212b_level0_col3" class="col_heading level0 col3" >model_size_kb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b212b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b212b_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_b212b_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_b212b_row0_col2" class="data row0 col2" >PTQ int8</td>
#       <td id="T_b212b_row0_col3" class="data row0 col3" >43.41 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b212b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b212b_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_b212b_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_b212b_row1_col2" class="data row1 col2" >QAT int8</td>
#       <td id="T_b212b_row1_col3" class="data row1 col3" >46.91 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b212b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b212b_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_b212b_row2_col1" class="data row2 col1" >user_holdout</td>
#       <td id="T_b212b_row2_col2" class="data row2 col2" >PTQ int8</td>
#       <td id="T_b212b_row2_col3" class="data row2 col3" >43.41 KB</td>
#     </tr>
#     <tr>
#       <th id="T_b212b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b212b_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_b212b_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_b212b_row3_col2" class="data row3 col2" >QAT int8</td>
#       <td id="T_b212b_row3_col3" class="data row3 col3" >46.91 KB</td>
#     </tr>
#   </tbody>
# </table>
# Reproducibility drift — WISDM replication (repeat evaluation on saved checkpoint):
# /tmp/ipykernel_5060/2087302422.py:272: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   repro_df[["protocol", "split_hash", "baseline_acc_first", "baseline_acc_repeat", "abs_drift", "status"]]
# <style type="text/css">
# #T_7133e_row0_col5, #T_7133e_row1_col5 {
#   color: green;
# }
# </style>
# <table id="T_7133e">
#   <caption>Table 3 — Reproducibility drift (two consecutive FP32 evaluations)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7133e_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_7133e_level0_col1" class="col_heading level0 col1" >split_hash</th>
#       <th id="T_7133e_level0_col2" class="col_heading level0 col2" >baseline_acc_first</th>
#       <th id="T_7133e_level0_col3" class="col_heading level0 col3" >baseline_acc_repeat</th>
#       <th id="T_7133e_level0_col4" class="col_heading level0 col4" >abs_drift</th>
#       <th id="T_7133e_level0_col5" class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7133e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7133e_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_7133e_row0_col1" class="data row0 col1" >68c9e31789bca103</td>
#       <td id="T_7133e_row0_col2" class="data row0 col2" >0.7716</td>
#       <td id="T_7133e_row0_col3" class="data row0 col3" >0.7716</td>
#       <td id="T_7133e_row0_col4" class="data row0 col4" >0.00e+00</td>
#       <td id="T_7133e_row0_col5" class="data row0 col5" >PASS</td>
#     </tr>
#     <tr>
#       <th id="T_7133e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7133e_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_7133e_row1_col1" class="data row1 col1" >2498bff9ddcfc589</td>
#       <td id="T_7133e_row1_col2" class="data row1 col2" >0.7372</td>
#       <td id="T_7133e_row1_col3" class="data row1 col3" >0.7372</td>
#       <td id="T_7133e_row1_col4" class="data row1 col4" >0.00e+00</td>
#       <td id="T_7133e_row1_col5" class="data row1 col5" >PASS</td>
#     </tr>
#   </tbody>
# </table>
# ### Protocol: `random_stratified`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Protocol: `user_holdout`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Classification Report Snippets — `random_stratified`
# FP32: macro_f1=0.577059167353506, weighted_f1=0.7036956203724145
# PTQ: macro_f1=0.5744271191201293, weighted_f1=0.7014090326276982
# QAT: macro_f1=0.6031907060929053, weighted_f1=0.7460299464920724
# ### Classification Report Snippets — `user_holdout`
# FP32: macro_f1=0.5323846994461402, weighted_f1=0.6621268572236718
# PTQ: macro_f1=0.5315173051412764, weighted_f1=0.6545941789546581
# QAT: macro_f1=0.5184094806975891, weighted_f1=0.6906876579242627
# ## Saved Comparison CSV Snapshot
#             pipeline           protocol           model  accuracy  macro_f1  \
# 0  WISDM replication  random_stratified  baseline float  0.771567  0.577059
# 1  WISDM replication  random_stratified        PTQ int8  0.768834  0.574427
# 2  WISDM replication  random_stratified        QAT int8  0.807108  0.603191
# 3  WISDM replication       user_holdout  baseline float  0.737243  0.532385
# 4  WISDM replication       user_holdout        PTQ int8  0.728446  0.531517
# 5  WISDM replication       user_holdout        QAT int8  0.762757  0.518409
# 6       paper target                  —  baseline float       NaN       NaN
# 7       paper target                  —        PTQ int8       NaN       NaN
# 8       paper target                  —        QAT int8       NaN       NaN
#
#    model_size_kb  training_time_sec  inference_latency_ms_median  \
# 0            NaN          23.348664                          NaN
# 1      43.414062                NaN                     0.404696
# 2      46.914062          43.361584                     0.541511
# 3            NaN          19.805762                          NaN
# 4      43.414062                NaN                     0.407980
# 5      46.914062          39.641399                     0.539926
# 6            NaN                NaN                          NaN
# 7            NaN                NaN                          NaN
# 8            NaN                NaN                          NaN
#
#    inference_latency_ms_p95     status  paper_target_accuracy  \
# 0                       NaN         ok                    NaN
# 1                  0.445481     failed                    NaN
# 2                  0.600009     failed                    NaN
# 3                       NaN         ok                    NaN
# 4                  0.441294     failed                    NaN
# 5                  0.657376     failed                    NaN
# 6                       NaN  reference                    NaN
# 7                       NaN  reference                    NaN
# 8                       NaN  reference                    NaN
#
#    acc_delta_vs_target
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# ## Master Results Snapshot
#   paper_slug           protocol                  variant    run_id  \
# 2  repmobile  random_stratified         repmobile_folded  wisdm_r0
# 3  repmobile       user_holdout         repmobile_folded  wisdm_r0
# 6  repmobile  random_stratified  repmobile_folded_conv2d  wisdm_r0
# 7  repmobile       user_holdout  repmobile_folded_conv2d  wisdm_r0
#
#    window_size  seed compression_focus      run_mode train_device  \
# 2          200    42      ptq_qat_only  sanity_check          gpu
# 3          200    42      ptq_qat_only  sanity_check          gpu
# 6          200    42      ptq_qat_only  sanity_check          gpu
# 7          200    42      ptq_qat_only  sanity_check          gpu
#
#   eval_fp32_device  ...                                        deploy_gate  \
# 2              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
# 3              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
# 6              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
# 7              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
#
#   paper_target_score delta_vs_paper notes_assumptions  \
# 2                NaN            NaN               NaN
# 3                NaN            NaN               NaN
# 6                NaN            NaN               NaN
# 7                NaN            NaN               NaN
#
#                                    fp32_metrics_json  \
# 2  /home/dellio/github/har-mcu/reports/repmobile/...
# 3  /home/dellio/github/har-mcu/reports/repmobile/...
# 6  /home/dellio/github/har-mcu/reports/repmobile/...
# 7  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     ptq_metrics_json  \
# 2  /home/dellio/github/har-mcu/reports/repmobile/...
# 3  /home/dellio/github/har-mcu/reports/repmobile/...
# 6  /home/dellio/github/har-mcu/reports/repmobile/...
# 7  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                     qat_metrics_json  \
# 2  /home/dellio/github/har-mcu/reports/repmobile/...
# 3                                                NaN
# 6  /home/dellio/github/har-mcu/reports/repmobile/...
# 7  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      ptq_report_json  \
# 2  /home/dellio/github/har-mcu/reports/repmobile/...
# 3  /home/dellio/github/har-mcu/reports/repmobile/...
# 6  /home/dellio/github/har-mcu/reports/repmobile/...
# 7  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                      qat_report_json  \
# 2  /home/dellio/github/har-mcu/reports/repmobile/...
# 3  /home/dellio/github/har-mcu/reports/repmobile/...
# 6  /home/dellio/github/har-mcu/reports/repmobile/...
# 7  /home/dellio/github/har-mcu/reports/repmobile/...
#
#                                    run_artifact_json
# 2  /home/dellio/github/har-mcu/reports/repmobile/...
# 3  /home/dellio/github/har-mcu/reports/repmobile/...
# 6  /home/dellio/github/har-mcu/reports/repmobile/...
# 7  /home/dellio/github/har-mcu/reports/repmobile/...
#
# [4 rows x 48 columns]
# Saved outputs root: /home/dellio/github/har-mcu/reports/repmobile

# %% [markdown]
# ## Notes
# - If QAT conversion fails strict deploy-gate checks, results are still exported with explicit failure reason.
# - Document unresolved paper ambiguities in `reports/paper_specs_<slug>.md`.
