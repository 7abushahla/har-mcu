# %% [markdown]
# # Replication Notebook — Daghero Quantized+Adaptive CNN (WISDM-first)

# %% [markdown]
# ## Paper Facts and Code Availability
# - Paper DOI: https://doi.org/10.1145/3542819
# - Official single repo: none declared
# - Toolchain context: PLiNIO, DORY, PULP-NN.
#
# ## WISDM Adaptation
# - Active config: `configs/papers/daghero_wisdm.yaml`
# - This notebook runs WISDM-first adaptation while preserving paper architecture intent.

# %% [markdown]
# ## Notebook Contract
# - Runtime / dependency guard
# - Paper facts + code availability
# - WISDM adaptation section
# - FP32 training/eval on `random_stratified` + `user_holdout`
# - PTQ INT8 + QAT INT8 exports
# - FP32 float `.tflite` export for size tracking (`fp32_model_size_kb`)
# - Strict deploy-gate summary (`full_integer_io`, `tflm_compatible`, unsupported ops)
# - Per-paper CSV/MD + master results append

# %% [markdown]
# ## Compression Scope Note
# - KD-related methodology from papers is documented for reproducibility context only.
# - Notebook execution enforces PTQ/QAT compression flow only (`experiment.compression_focus=ptq_qat_only`).
# - This notebook uses a Conv2D-equivalent architecture for QAT compatibility; Conv1D paper operators are preserved semantically via `(k)->(k,1)` mapping.

# %%
from pathlib import Path
import sys
import os
import json
import importlib
import importlib.util

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, Markdown, display

# Optional safeguard: disable GPU if kernel is unstable on CUDA runtime.
USE_GPU = True
if not USE_GPU:
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Ensure repo root is importable when launched from different working directories.
REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "src").exists():
    for parent in [REPO_ROOT, *REPO_ROOT.parents]:
        if (parent / "src").exists():
            REPO_ROOT = parent
            break
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

required_modules = {
    "numpy": "numpy",
    "pandas": "pandas",
    "matplotlib": "matplotlib",
    "IPython": "ipython",
    "yaml": "PyYAML",
    "sklearn": "scikit-learn",
    "tensorflow": "tensorflow",
    "tensorflow_model_optimization": "tensorflow-model-optimization",
}
missing = [
    f"{mod} (pip package: {pkg})"
    for mod, pkg in required_modules.items()
    if importlib.util.find_spec(mod) is None
]
if missing:
    missing_text = "\n- ".join(missing)
    raise ModuleNotFoundError(
        "Missing required notebook dependencies:\n- "
        + missing_text
        + "\n\nActivate tinymlproj and install dependencies:\n"
        + "conda activate tinymlproj && conda env update -n tinymlproj -f environment.yml --prune"
    )

import tensorflow as tf
print("TF version:", tf.__version__)
print("Visible GPUs:", tf.config.list_physical_devices("GPU"))

# Fail fast if local file is stale (pre-FP32-TFLite-size patch).
_rpe_file = REPO_ROOT / "src/run_paper_experiment.py"
if _rpe_file.exists():
    _rpe_src = _rpe_file.read_text(encoding="utf-8")
    if "from src.utils.artifacts import model_fp32_tflite_path" in _rpe_src:
        raise RuntimeError(
            "Outdated src/run_paper_experiment.py detected in workspace. "
            "Please refresh repo files and rerun from the first cell."
        )

importlib.invalidate_caches()
for _stale_mod in ("src.run_paper_experiment",):
    sys.modules.pop(_stale_mod, None)

AUTO_RELOAD_PROJECT_MODULES = True
if AUTO_RELOAD_PROJECT_MODULES:
    for _mod_name in (
        "src.models.xtinyhar_student_tf",
        "src.models.repmobile_folded_tf",
        "src.models.tcn_attention_har_tf",
        "src.models.daghero_cnn_searchspace_tf",
        "src.models.tcn_inception_tf",
        "src.models.serialization",
        "src.eval.evaluate_model",
        "src.quant.ptq_full_int8",
        "src.quant.qat_train",
        "src.utils.artifacts",
        "src.eval.notebook_reporting",
        "src.run_paper_experiment",
    ):
        if _mod_name in sys.modules:
            importlib.reload(sys.modules[_mod_name])

import src.run_paper_experiment as _run_mod
run_paper_experiment = _run_mod.run_paper_experiment

from src.utils.config import load_yaml
from src.utils.device_runtime import runtime_device_report
from src.eval.evaluate_model import evaluate_model_for_protocol
from src.utils.artifacts import model_ckpt_path, split_npz_path

if "load_checkpoint_model" not in evaluate_model_for_protocol.__code__.co_names:
    raise RuntimeError(
        "Stale evaluate_model module detected (safe loader missing). "
        "Restart kernel and rerun from the first cell."
    )

RUN_MODE = "sanity_check"  # switch to "full_run" for full-length runs (GPU-first, CPU fallback enabled)
CONFIG_PATH = REPO_ROOT / 'configs/papers/daghero_wisdm.yaml'
assert CONFIG_PATH.exists(), f"Missing config: {CONFIG_PATH}"
cfg = load_yaml(CONFIG_PATH)
cfg.setdefault("runtime", {})["run_mode"] = RUN_MODE
cfg.setdefault("experiment", {})["compression_focus"] = "ptq_qat_only"
runtime = runtime_device_report(cfg)

print("repo_root:", REPO_ROOT)
print("paper_slug:", cfg.get("experiment", {}).get("paper_slug"))
print("model_variant:", cfg.get("experiment", {}).get("model_variant"))
is_conv2d_variant = str(cfg.get("experiment", {}).get("model_variant", "")).endswith("_conv2d")
print("conv2d_qat_safe_variant:", is_conv2d_variant)
print("[NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.")
if not is_conv2d_variant:
    print("[WARN] Active model_variant is not *_conv2d; QAT may fail on Conv1D/SeparableConv1D in tfmot 0.8.")
print("window_size:", cfg.get("paper_protocol", {}).get("wisdm_window_override"))
print("run_mode:", runtime["run_mode"])
print("detected_gpus:", runtime["gpus"])
print("stage_device_map:", runtime["resolved_stage_devices"])
print("[NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.")

strict_gate_cfg = {
    "ptq_strict_full_int8": bool(cfg.get("quant", {}).get("ptq", {}).get("strict_full_int8", True)),
    "ptq_require_tflm_compatible": bool(cfg.get("quant", {}).get("ptq", {}).get("require_tflm_compatible", True)),
    "ptq_accepted_integer_io_dtypes": cfg.get("quant", {}).get("ptq", {}).get("accepted_integer_io_dtypes", ["int8", "uint8"]),
    "qat_strict_full_int8": bool(cfg.get("quant", {}).get("qat", {}).get("strict_full_int8", True)),
    "qat_require_tflm_compatible": bool(cfg.get("quant", {}).get("qat", {}).get("require_tflm_compatible", True)),
    "qat_accepted_integer_io_dtypes": cfg.get("quant", {}).get("qat", {}).get("accepted_integer_io_dtypes", ["int8", "uint8"]),
    "deploy_allowed_ops_profile": cfg.get("deploy", {}).get("allowed_ops_profile", "default"),
    "deploy_allowed_ops_override": cfg.get("deploy", {}).get("allowed_ops"),
}
print("strict_gate_cfg:", strict_gate_cfg)
# Out:
# 2026-03-05 02:03:01.634195: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-05 02:03:01.634251: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-05 02:03:01.634306: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-05 02:03:01.642495: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TF version: 2.14.1
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-03-05 02:03:02.892127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:02.899442: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:02.899487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# repo_root: /home/dellio/github/har-mcu
# paper_slug: daghero_qadnn
# model_variant: daghero_cnn_2layer_conv2d
# conv2d_qat_safe_variant: True
# [NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.
# window_size: 200
# run_mode: sanity_check
# detected_gpus: ['/physical_device:GPU:0']
# stage_device_map: {'train': 'gpu', 'eval_fp32': 'gpu', 'ptq': 'gpu', 'eval_ptq': 'gpu', 'qat': 'gpu', 'eval_qat': 'gpu'}
# [NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.
# strict_gate_cfg: {'ptq_strict_full_int8': True, 'ptq_require_tflm_compatible': True, 'ptq_accepted_integer_io_dtypes': ['int8', 'uint8'], 'qat_strict_full_int8': True, 'qat_require_tflm_compatible': True, 'qat_accepted_integer_io_dtypes': ['int8', 'uint8'], 'deploy_allowed_ops_profile': 'nano33ble_extended', 'deploy_allowed_ops_override': None}

# %%
# Run FP32 + PTQ + QAT + standardized reporting
out = run_paper_experiment(cfg)
out
# Out:
# 2026-03-05 02:03:03.266661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:03.266742: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:03.266779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:03.473371: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:03.473477: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:03.473497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-03-05 02:03:03.473566: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:03:03.473605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21764 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:2d:00.0, compute capability: 8.6
# Epoch 1/50
# 2026-03-05 02:03:05.101592: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2026-03-05 02:03:05.950265: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5a88cf36bd50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-05 02:03:05.950307: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2026-03-05 02:03:05.955538: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-03-05 02:03:06.034233: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 - 4s - loss: 0.5222 - accuracy: 0.8116 - val_loss: 0.5948 - val_accuracy: 0.8362 - lr: 0.0100 - 4s/epoch - 25ms/step
# Epoch 2/50
# 168/168 - 1s - loss: 0.3670 - accuracy: 0.8629 - val_loss: 0.3161 - val_accuracy: 0.9013 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 3/50
# 168/168 - 1s - loss: 0.2905 - accuracy: 0.8962 - val_loss: 0.1706 - val_accuracy: 0.9267 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 4/50
# 168/168 - 1s - loss: 0.2154 - accuracy: 0.9205 - val_loss: 0.1290 - val_accuracy: 0.9663 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 5/50
# 168/168 - 1s - loss: 0.1944 - accuracy: 0.9291 - val_loss: 0.1354 - val_accuracy: 0.9529 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 6/50
# 168/168 - 1s - loss: 0.1340 - accuracy: 0.9547 - val_loss: 0.1629 - val_accuracy: 0.9469 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 7/50
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 168/168 - 1s - loss: 0.2235 - accuracy: 0.9257 - val_loss: 0.1922 - val_accuracy: 0.9417 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 8/50
# 168/168 - 1s - loss: 0.1178 - accuracy: 0.9650 - val_loss: 0.0742 - val_accuracy: 0.9783 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 9/50
# 168/168 - 1s - loss: 0.1033 - accuracy: 0.9673 - val_loss: 0.0674 - val_accuracy: 0.9783 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 10/50
# 168/168 - 1s - loss: 0.0909 - accuracy: 0.9714 - val_loss: 0.0582 - val_accuracy: 0.9806 - lr: 1.0000e-03 - 1s/epoch - 9ms/step
# Epoch 11/50
# 168/168 - 1s - loss: 0.0891 - accuracy: 0.9689 - val_loss: 0.0546 - val_accuracy: 0.9828 - lr: 1.0000e-03 - 1s/epoch - 9ms/step
# Epoch 12/50
# 168/168 - 1s - loss: 0.0819 - accuracy: 0.9734 - val_loss: 0.0546 - val_accuracy: 0.9835 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 13/50
# 168/168 - 1s - loss: 0.0750 - accuracy: 0.9776 - val_loss: 0.0479 - val_accuracy: 0.9873 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 14/50
# 168/168 - 1s - loss: 0.0738 - accuracy: 0.9779 - val_loss: 0.0441 - val_accuracy: 0.9873 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 15/50
# 168/168 - 1s - loss: 0.0697 - accuracy: 0.9776 - val_loss: 0.0483 - val_accuracy: 0.9850 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 16/50
# 168/168 - 1s - loss: 0.0720 - accuracy: 0.9766 - val_loss: 0.0448 - val_accuracy: 0.9858 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 17/50
# 168/168 - 1s - loss: 0.0670 - accuracy: 0.9792 - val_loss: 0.0406 - val_accuracy: 0.9873 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 18/50
# 168/168 - 1s - loss: 0.0639 - accuracy: 0.9796 - val_loss: 0.0360 - val_accuracy: 0.9880 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 19/50
# 168/168 - 1s - loss: 0.0611 - accuracy: 0.9774 - val_loss: 0.0368 - val_accuracy: 0.9888 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 20/50
# 168/168 - 1s - loss: 0.0600 - accuracy: 0.9813 - val_loss: 0.0325 - val_accuracy: 0.9918 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 21/50
# 168/168 - 1s - loss: 0.0640 - accuracy: 0.9783 - val_loss: 0.0324 - val_accuracy: 0.9895 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 22/50
# 168/168 - 1s - loss: 0.0664 - accuracy: 0.9785 - val_loss: 0.0308 - val_accuracy: 0.9895 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 23/50
# 168/168 - 1s - loss: 0.0508 - accuracy: 0.9828 - val_loss: 0.0301 - val_accuracy: 0.9903 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 24/50
# 168/168 - 1s - loss: 0.0575 - accuracy: 0.9807 - val_loss: 0.0266 - val_accuracy: 0.9903 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 25/50
# 168/168 - 1s - loss: 0.0570 - accuracy: 0.9794 - val_loss: 0.0274 - val_accuracy: 0.9903 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 26/50
# 168/168 - 1s - loss: 0.0521 - accuracy: 0.9841 - val_loss: 0.0254 - val_accuracy: 0.9903 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 27/50
# 168/168 - 1s - loss: 0.0485 - accuracy: 0.9843 - val_loss: 0.0253 - val_accuracy: 0.9895 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 28/50
# 168/168 - 1s - loss: 0.0455 - accuracy: 0.9847 - val_loss: 0.0284 - val_accuracy: 0.9880 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 29/50
# 168/168 - 1s - loss: 0.0425 - accuracy: 0.9860 - val_loss: 0.0217 - val_accuracy: 0.9918 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 30/50
# 168/168 - 1s - loss: 0.0411 - accuracy: 0.9860 - val_loss: 0.0197 - val_accuracy: 0.9918 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 31/50
# 168/168 - 1s - loss: 0.0420 - accuracy: 0.9878 - val_loss: 0.0198 - val_accuracy: 0.9918 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 32/50
# 168/168 - 1s - loss: 0.0440 - accuracy: 0.9865 - val_loss: 0.0218 - val_accuracy: 0.9903 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 33/50
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 168/168 - 1s - loss: 0.0416 - accuracy: 0.9848 - val_loss: 0.0201 - val_accuracy: 0.9910 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 34/50
# 168/168 - 1s - loss: 0.0357 - accuracy: 0.9884 - val_loss: 0.0191 - val_accuracy: 0.9910 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 35/50
# 168/168 - 1s - loss: 0.0373 - accuracy: 0.9880 - val_loss: 0.0185 - val_accuracy: 0.9925 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 36/50
# 168/168 - 1s - loss: 0.0378 - accuracy: 0.9869 - val_loss: 0.0176 - val_accuracy: 0.9933 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 37/50
# 168/168 - 1s - loss: 0.0373 - accuracy: 0.9882 - val_loss: 0.0171 - val_accuracy: 0.9933 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 38/50
# 168/168 - 1s - loss: 0.0376 - accuracy: 0.9878 - val_loss: 0.0174 - val_accuracy: 0.9925 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 39/50
# 168/168 - 1s - loss: 0.0330 - accuracy: 0.9903 - val_loss: 0.0174 - val_accuracy: 0.9925 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 40/50
# 168/168 - 1s - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.0169 - val_accuracy: 0.9933 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 41/50
# 168/168 - 1s - loss: 0.0308 - accuracy: 0.9916 - val_loss: 0.0165 - val_accuracy: 0.9933 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 42/50
# 168/168 - 1s - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.0172 - val_accuracy: 0.9925 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 43/50
# 168/168 - 1s - loss: 0.0335 - accuracy: 0.9899 - val_loss: 0.0166 - val_accuracy: 0.9933 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 44/50
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 168/168 - 1s - loss: 0.0352 - accuracy: 0.9880 - val_loss: 0.0166 - val_accuracy: 0.9933 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 45/50
# 168/168 - 1s - loss: 0.0306 - accuracy: 0.9897 - val_loss: 0.0169 - val_accuracy: 0.9933 - lr: 1.0000e-05 - 1s/epoch - 8ms/step
# Epoch 46/50
# Restoring model weights from the end of the best epoch: 41.
# 168/168 - 1s - loss: 0.0337 - accuracy: 0.9905 - val_loss: 0.0168 - val_accuracy: 0.9933 - lr: 1.0000e-05 - 1s/epoch - 8ms/step
# Epoch 46: early stopping
# INFO:tensorflow:Assets written to: /tmp/tmpvny7_m2f/assets
# INFO:tensorflow:Assets written to: /tmp/tmpvny7_m2f/assets
# 2026-03-05 02:04:11.845310: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:04:11.845350: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:04:11.845545: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpvny7_m2f
# 2026-03-05 02:04:11.847973: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:04:11.847985: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpvny7_m2f
# 2026-03-05 02:04:11.853909: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2026-03-05 02:04:11.854527: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:04:11.872688: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpvny7_m2f
# 2026-03-05 02:04:11.879118: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 33573 microseconds.
# INFO:tensorflow:Assets written to: /tmp/tmpx50f5tqs/assets
# INFO:tensorflow:Assets written to: /tmp/tmpx50f5tqs/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:04:13.727893: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:04:13.727936: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:04:13.728059: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpx50f5tqs
# 2026-03-05 02:04:13.729043: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:04:13.729055: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpx50f5tqs
# 2026-03-05 02:04:13.730926: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:04:13.747848: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpx50f5tqs
# 2026-03-05 02:04:13.754723: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 26664 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/10
# 168/168 - 5s - loss: 0.0428 - accuracy: 0.9865 - val_loss: 0.0202 - val_accuracy: 0.9933 - 5s/epoch - 31ms/step
# Epoch 2/10
# 168/168 - 4s - loss: 0.0353 - accuracy: 0.9877 - val_loss: 0.0165 - val_accuracy: 0.9940 - 4s/epoch - 22ms/step
# Epoch 3/10
# 168/168 - 4s - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.0202 - val_accuracy: 0.9955 - 4s/epoch - 22ms/step
# Epoch 4/10
# 168/168 - 3s - loss: 0.0312 - accuracy: 0.9908 - val_loss: 0.0196 - val_accuracy: 0.9918 - 3s/epoch - 21ms/step
# Epoch 5/10
# 168/168 - 3s - loss: 0.0328 - accuracy: 0.9892 - val_loss: 0.0172 - val_accuracy: 0.9925 - 3s/epoch - 20ms/step
# Epoch 6/10
# 168/168 - 3s - loss: 0.0300 - accuracy: 0.9895 - val_loss: 0.0165 - val_accuracy: 0.9925 - 3s/epoch - 21ms/step
# Epoch 7/10
# 168/168 - 3s - loss: 0.0304 - accuracy: 0.9899 - val_loss: 0.0230 - val_accuracy: 0.9910 - 3s/epoch - 21ms/step
# Epoch 8/10
# 168/168 - 3s - loss: 0.0290 - accuracy: 0.9905 - val_loss: 0.0144 - val_accuracy: 0.9955 - 3s/epoch - 21ms/step
# Epoch 9/10
# 168/168 - 3s - loss: 0.0396 - accuracy: 0.9873 - val_loss: 0.0140 - val_accuracy: 0.9948 - 3s/epoch - 20ms/step
# Epoch 10/10
# 168/168 - 4s - loss: 0.0274 - accuracy: 0.9921 - val_loss: 0.0134 - val_accuracy: 0.9955 - 4s/epoch - 21ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpzig_tgsj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpzig_tgsj/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:04:53.684226: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:04:53.684264: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:04:53.684383: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpzig_tgsj
# 2026-03-05 02:04:53.688303: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:04:53.688317: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpzig_tgsj
# 2026-03-05 02:04:53.698771: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:04:53.748289: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpzig_tgsj
# 2026-03-05 02:04:53.762495: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 78112 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/50
# 165/165 - 3s - loss: 0.4373 - accuracy: 0.8469 - val_loss: 0.8471 - val_accuracy: 0.7454 - lr: 0.0100 - 3s/epoch - 16ms/step
# Epoch 2/50
# 165/165 - 1s - loss: 0.2411 - accuracy: 0.9129 - val_loss: 1.1674 - val_accuracy: 0.7301 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 3/50
# 165/165 - 1s - loss: 0.1662 - accuracy: 0.9416 - val_loss: 1.0589 - val_accuracy: 0.7240 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 4/50
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 165/165 - 1s - loss: 0.1134 - accuracy: 0.9604 - val_loss: 0.8889 - val_accuracy: 0.7722 - lr: 0.0100 - 1s/epoch - 8ms/step
# Epoch 5/50
# 165/165 - 1s - loss: 0.0699 - accuracy: 0.9774 - val_loss: 0.8413 - val_accuracy: 0.7699 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 6/50
# 165/165 - 1s - loss: 0.0562 - accuracy: 0.9844 - val_loss: 0.9128 - val_accuracy: 0.7661 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 7/50
# 165/165 - 1s - loss: 0.0428 - accuracy: 0.9892 - val_loss: 0.8982 - val_accuracy: 0.7668 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 8/50
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 165/165 - 1s - loss: 0.0377 - accuracy: 0.9882 - val_loss: 0.9543 - val_accuracy: 0.7668 - lr: 1.0000e-03 - 1s/epoch - 8ms/step
# Epoch 9/50
# 165/165 - 1s - loss: 0.0350 - accuracy: 0.9895 - val_loss: 0.9866 - val_accuracy: 0.7676 - lr: 1.0000e-04 - 1s/epoch - 9ms/step
# Epoch 10/50
# Restoring model weights from the end of the best epoch: 5.
# 165/165 - 1s - loss: 0.0362 - accuracy: 0.9905 - val_loss: 0.9999 - val_accuracy: 0.7676 - lr: 1.0000e-04 - 1s/epoch - 8ms/step
# Epoch 10: early stopping
# INFO:tensorflow:Assets written to: /tmp/tmplc_10zhp/assets
# INFO:tensorflow:Assets written to: /tmp/tmplc_10zhp/assets
# 2026-03-05 02:05:10.732464: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:05:10.732503: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:05:10.732623: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmplc_10zhp
# 2026-03-05 02:05:10.734462: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:05:10.734473: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmplc_10zhp
# 2026-03-05 02:05:10.738875: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:05:10.755615: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmplc_10zhp
# 2026-03-05 02:05:10.762501: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 29877 microseconds.
# INFO:tensorflow:Assets written to: /tmp/tmp5nn0d058/assets
# INFO:tensorflow:Assets written to: /tmp/tmp5nn0d058/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:05:12.555146: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:05:12.555189: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:05:12.555311: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp5nn0d058
# 2026-03-05 02:05:12.556639: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:05:12.556652: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp5nn0d058
# 2026-03-05 02:05:12.559063: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:05:12.575759: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp5nn0d058
# 2026-03-05 02:05:12.583484: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 28171 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/10
# 165/165 - 4s - loss: 0.0600 - accuracy: 0.9823 - val_loss: 1.0405 - val_accuracy: 0.7561 - 4s/epoch - 27ms/step
# Epoch 2/10
# 165/165 - 3s - loss: 0.0410 - accuracy: 0.9882 - val_loss: 1.0369 - val_accuracy: 0.7676 - 3s/epoch - 20ms/step
# Epoch 3/10
# 165/165 - 3s - loss: 0.0358 - accuracy: 0.9897 - val_loss: 0.9989 - val_accuracy: 0.7653 - 3s/epoch - 20ms/step
# Epoch 4/10
# 165/165 - 3s - loss: 0.0333 - accuracy: 0.9932 - val_loss: 1.1468 - val_accuracy: 0.7599 - 3s/epoch - 20ms/step
# Epoch 5/10
# 165/165 - 3s - loss: 0.0403 - accuracy: 0.9880 - val_loss: 0.9719 - val_accuracy: 0.7745 - 3s/epoch - 20ms/step
# Epoch 6/10
# 165/165 - 3s - loss: 0.0364 - accuracy: 0.9899 - val_loss: 1.0239 - val_accuracy: 0.7699 - 3s/epoch - 21ms/step
# Epoch 7/10
# 165/165 - 3s - loss: 0.0259 - accuracy: 0.9932 - val_loss: 1.0894 - val_accuracy: 0.7615 - 3s/epoch - 21ms/step
# Epoch 8/10
# 165/165 - 3s - loss: 0.0251 - accuracy: 0.9930 - val_loss: 1.1650 - val_accuracy: 0.7615 - 3s/epoch - 20ms/step
# Epoch 9/10
# 165/165 - 3s - loss: 0.0265 - accuracy: 0.9916 - val_loss: 0.9240 - val_accuracy: 0.7913 - 3s/epoch - 21ms/step
# Epoch 10/10
# 165/165 - 3s - loss: 0.0263 - accuracy: 0.9926 - val_loss: 1.0608 - val_accuracy: 0.7752 - 3s/epoch - 20ms/step
# INFO:tensorflow:Assets written to: /tmp/tmp0eo758r8/assets
# INFO:tensorflow:Assets written to: /tmp/tmp0eo758r8/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:05:49.842744: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:05:49.842785: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:05:49.842901: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp0eo758r8
# 2026-03-05 02:05:49.846666: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:05:49.846679: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp0eo758r8
# 2026-03-05 02:05:49.856627: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:05:49.901500: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp0eo758r8
# 2026-03-05 02:05:49.915257: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 72355 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/dellio/github/har-mcu/src/eval/reporting.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([existing, incoming], ignore_index=True)
# /home/dellio/github/har-mcu/src/eval/paper_comparison.py:193: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# {'paper_slug': 'daghero_qadnn',
#  'rows': [{'paper_slug': 'daghero_qadnn',
#    'protocol': 'random_stratified',
#    'variant': 'daghero_cnn_2layer_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'gpu',
#    'eval_qat_device': 'gpu',
#    'fp32_training_time_sec': 66.56295186700004,
#    'fp32_model_size_kb': 81.63671875,
#    'fp32_tflite_model': '/home/dellio/github/har-mcu/models_tflite/daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0_fp32.tflite',
#    'fp32_tflite_status': 'ok',
#    'fp32_tflite_error': None,
#    'qat_training_time_sec': 36.79993988199999,
#    'accuracy': 0.9930133657351154,
#    'macro_f1': 0.9848455901863185,
#    'ptq_status': 'ok',
#    'qat_status': 'ok',
#    'ptq_allowed_ops_profile': 'micro_mutable_main',
#    'qat_allowed_ops_profile': 'micro_mutable_main',
#    'ptq_accuracy': 0.9939246658566221,
#    'ptq_macro_f1': 0.9874841057833196,
#    'qat_accuracy': 0.9924058323207776,
#    'qat_macro_f1': 0.9851424090002044,
#    'ptq_model_size_kb': 27.3671875,
#    'qat_model_size_kb': 29.4140625,
#    'model_size_kb': 27.3671875,
#    'ptq_inference_latency_ms_median': 0.08982899998954963,
#    'ptq_inference_latency_ms_p95': 0.10327649999908317,
#    'qat_inference_latency_ms_median': 0.11571900006401847,
#    'qat_inference_latency_ms_p95': 0.14466575009919325,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/curve_fp32_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/curve_qat_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/daghero_qadnn/confusion_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/daghero_qadnn/confusion_ptq_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/daghero_qadnn/confusion_qat_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'deploy_gate': {'ptq': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []},
#     'qat': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/ptq_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/qat_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/ptq_export_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/qat_export_daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/artifacts/daghero_qadnn_daghero_cnn_2layer_conv2d_random_stratified_wisdm_r0.json'},
#   {'paper_slug': 'daghero_qadnn',
#    'protocol': 'user_holdout',
#    'variant': 'daghero_cnn_2layer_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'gpu',
#    'eval_qat_device': 'gpu',
#    'fp32_training_time_sec': 14.96201608499996,
#    'fp32_model_size_kb': 81.63671875,
#    'fp32_tflite_model': '/home/dellio/github/har-mcu/models_tflite/daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0_fp32.tflite',
#    'fp32_tflite_status': 'ok',
#    'fp32_tflite_error': None,
#    'qat_training_time_sec': 34.82446578600002,
#    'accuracy': 0.8208211143695014,
#    'macro_f1': 0.7648593735898475,
#    'ptq_status': 'ok',
#    'qat_status': 'ok',
#    'ptq_allowed_ops_profile': 'micro_mutable_main',
#    'qat_allowed_ops_profile': 'micro_mutable_main',
#    'ptq_accuracy': 0.8234604105571848,
#    'ptq_macro_f1': 0.7658416992159635,
#    'qat_accuracy': 0.8598240469208212,
#    'qat_macro_f1': 0.8283029705525448,
#    'ptq_model_size_kb': 27.3671875,
#    'qat_model_size_kb': 29.4140625,
#    'model_size_kb': 27.3671875,
#    'ptq_inference_latency_ms_median': 0.09025449992350332,
#    'ptq_inference_latency_ms_p95': 0.10305900002549606,
#    'qat_inference_latency_ms_median': 0.11503400003221032,
#    'qat_inference_latency_ms_p95': 0.12756124988300144,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/curve_fp32_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/curve_qat_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/daghero_qadnn/confusion_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/daghero_qadnn/confusion_ptq_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/daghero_qadnn/confusion_qat_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'deploy_gate': {'ptq': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []},
#     'qat': {'status': 'ok',
#      'full_integer_io': True,
#      'tflm_compatible': True,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': [],
#      'unsupported_ops': [],
#      'unsupported_ops_profile': [],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': []}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/ptq_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/qat_daghero_cnn_2layer_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/ptq_export_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/qat_export_daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/daghero_qadnn/artifacts/daghero_qadnn_daghero_cnn_2layer_conv2d_user_holdout_wisdm_r0.json'}],
#  'paper_exports': {'random_stratified': {'csv': '/home/dellio/github/har-mcu/reports/daghero_qadnn/daghero_qadnn_results_random_stratified.csv',
#    'md': '/home/dellio/github/har-mcu/reports/daghero_qadnn/daghero_qadnn_summary.md'},
#   'user_holdout': {'csv': '/home/dellio/github/har-mcu/reports/daghero_qadnn/daghero_qadnn_results_user_holdout.csv',
#    'md': '/home/dellio/github/har-mcu/reports/daghero_qadnn/daghero_qadnn_summary.md'}},
#  'comparison_exports': {'csv': '/home/dellio/github/har-mcu/reports/daghero_qadnn/comparison/daghero_qadnn_comparison.csv',
#   'md': '/home/dellio/github/har-mcu/reports/daghero_qadnn/comparison/daghero_qadnn_comparison.md',
#   'accuracy_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/comparison/daghero_qadnn_comparison_accuracy.png',
#   'size_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/comparison/daghero_qadnn_comparison_size.png',
#   'latency_png': '/home/dellio/github/har-mcu/reports/daghero_qadnn/comparison/daghero_qadnn_comparison_latency.png'},
#  'master_exports': {'csv': '/home/dellio/github/har-mcu/reports/results_master.csv',
#   'md': '/home/dellio/github/har-mcu/reports/results_master.md'}}

# %%
# Standardized shared notebook report rendering
from src.eval.notebook_reporting import render_paper_notebook_report

notebook_report = render_paper_notebook_report(cfg, out, drift_tol=1e-9)
notebook_report
# Out:
#       paper_slug           protocol                    variant    run_id  \
# 0  daghero_qadnn  random_stratified  daghero_cnn_2layer_conv2d  wisdm_r0
# 1  daghero_qadnn       user_holdout  daghero_cnn_2layer_conv2d  wisdm_r0
#
#    window_size  seed compression_focus      run_mode train_device  \
# 0          200    42      ptq_qat_only  sanity_check          gpu
# 1          200    42      ptq_qat_only  sanity_check          gpu
#
#   eval_fp32_device  ...                                        deploy_gate  \
# 0              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
# 1              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
#
#   paper_target_score delta_vs_paper notes_assumptions  \
# 0               None           None              None
# 1               None           None              None
#
#                                    fp32_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/daghero_qa...
# 1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                     ptq_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/daghero_qa...
# 1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                     qat_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/daghero_qa...
# 1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                      ptq_report_json  \
# 0  /home/dellio/github/har-mcu/reports/daghero_qa...
# 1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                      qat_report_json  \
# 0  /home/dellio/github/har-mcu/reports/daghero_qa...
# 1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                    run_artifact_json
# 0  /home/dellio/github/har-mcu/reports/daghero_qa...
# 1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
# [2 rows x 54 columns]
# <style type="text/css">
# </style>
# <table id="T_b848d">
#   <caption>Model Size Summary (FP32 float .tflite, PTQ INT8, QAT INT8)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b848d_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_b848d_level0_col1" class="col_heading level0 col1" >fp32_model_size_kb</th>
#       <th id="T_b848d_level0_col2" class="col_heading level0 col2" >ptq_model_size_kb</th>
#       <th id="T_b848d_level0_col3" class="col_heading level0 col3" >qat_model_size_kb</th>
#       <th id="T_b848d_level0_col4" class="col_heading level0 col4" >fp32_tflite_status</th>
#       <th id="T_b848d_level0_col5" class="col_heading level0 col5" >fp32_tflite_model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b848d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b848d_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_b848d_row0_col1" class="data row0 col1" >81.64 KB</td>
#       <td id="T_b848d_row0_col2" class="data row0 col2" >27.37 KB</td>
#       <td id="T_b848d_row0_col3" class="data row0 col3" >29.41 KB</td>
#       <td id="T_b848d_row0_col4" class="data row0 col4" >ok</td>
#       <td id="T_b848d_row0_col5" class="data row0 col5" >/home/dellio/github/har-mcu/models_tflite/daghero_cnn_2layer_conv2d_T200_Prandom_stratified_wisdm_r0_fp32.tflite</td>
#     </tr>
#     <tr>
#       <th id="T_b848d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b848d_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_b848d_row1_col1" class="data row1 col1" >81.64 KB</td>
#       <td id="T_b848d_row1_col2" class="data row1 col2" >27.37 KB</td>
#       <td id="T_b848d_row1_col3" class="data row1 col3" >29.41 KB</td>
#       <td id="T_b848d_row1_col4" class="data row1 col4" >ok</td>
#       <td id="T_b848d_row1_col5" class="data row1 col5" >/home/dellio/github/har-mcu/models_tflite/daghero_cnn_2layer_conv2d_T200_Puser_holdout_wisdm_r0_fp32.tflite</td>
#     </tr>
#   </tbody>
# </table>
# Note: fp32_model_size_kb is measured from exported float .tflite per protocol.
#
# PTQ operator visibility (per protocol):
# - interpreter_ops: delegate-free runtime ops from PTQ TFLite evaluation metrics
# - tflm_ops: flatbuffer ops used by strict deploy-gate compatibility check
#
# [random_stratified]
#   interpreter_ops (9): ['CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#   tflm_ops       (9): ['CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#
# [user_holdout]
#   interpreter_ops (9): ['CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#   tflm_ops       (9): ['CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'PACK', 'RESHAPE', 'SHAPE', 'SOFTMAX', 'STRIDED_SLICE']
#
# Strict deploy-gate status summary:
# [random_stratified] ptq_status=ok | qat_status=ok
# [user_holdout] ptq_status=ok | qat_status=ok
#
# Strict Deploy-Gate Details (from export reports):
# <style type="text/css">
# </style>
# <table id="T_c3d2f">
#   <caption>Strict deploy-gate details per protocol/tier (PTQ, QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3d2f_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_c3d2f_level0_col1" class="col_heading level0 col1" >tier</th>
#       <th id="T_c3d2f_level0_col2" class="col_heading level0 col2" >status</th>
#       <th id="T_c3d2f_level0_col3" class="col_heading level0 col3" >full_integer_io</th>
#       <th id="T_c3d2f_level0_col4" class="col_heading level0 col4" >tflm_compatible</th>
#       <th id="T_c3d2f_level0_col5" class="col_heading level0 col5" >allowed_ops_profile</th>
#       <th id="T_c3d2f_level0_col6" class="col_heading level0 col6" >compatibility_scope</th>
#       <th id="T_c3d2f_level0_col7" class="col_heading level0 col7" >unsupported_ops_micro_mutable</th>
#       <th id="T_c3d2f_level0_col8" class="col_heading level0 col8" >possibly_supported_upstream_tflm</th>
#       <th id="T_c3d2f_level0_col9" class="col_heading level0 col9" >unsupported_in_reference</th>
#       <th id="T_c3d2f_level0_col10" class="col_heading level0 col10" >error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3d2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3d2f_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_c3d2f_row0_col1" class="data row0 col1" >PTQ</td>
#       <td id="T_c3d2f_row0_col2" class="data row0 col2" >ok</td>
#       <td id="T_c3d2f_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_c3d2f_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_c3d2f_row0_col5" class="data row0 col5" >micro_mutable_main</td>
#       <td id="T_c3d2f_row0_col6" class="data row0 col6" >micro_mutable_main</td>
#       <td id="T_c3d2f_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_c3d2f_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_c3d2f_row0_col9" class="data row0 col9" >—</td>
#       <td id="T_c3d2f_row0_col10" class="data row0 col10" >—</td>
#     </tr>
#     <tr>
#       <th id="T_c3d2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3d2f_row1_col0" class="data row1 col0" >random_stratified</td>
#       <td id="T_c3d2f_row1_col1" class="data row1 col1" >QAT</td>
#       <td id="T_c3d2f_row1_col2" class="data row1 col2" >ok</td>
#       <td id="T_c3d2f_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_c3d2f_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_c3d2f_row1_col5" class="data row1 col5" >micro_mutable_main</td>
#       <td id="T_c3d2f_row1_col6" class="data row1 col6" >micro_mutable_main</td>
#       <td id="T_c3d2f_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_c3d2f_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_c3d2f_row1_col9" class="data row1 col9" >—</td>
#       <td id="T_c3d2f_row1_col10" class="data row1 col10" >—</td>
#     </tr>
#     <tr>
#       <th id="T_c3d2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3d2f_row2_col0" class="data row2 col0" >user_holdout</td>
#       <td id="T_c3d2f_row2_col1" class="data row2 col1" >PTQ</td>
#       <td id="T_c3d2f_row2_col2" class="data row2 col2" >ok</td>
#       <td id="T_c3d2f_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_c3d2f_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_c3d2f_row2_col5" class="data row2 col5" >micro_mutable_main</td>
#       <td id="T_c3d2f_row2_col6" class="data row2 col6" >micro_mutable_main</td>
#       <td id="T_c3d2f_row2_col7" class="data row2 col7" >—</td>
#       <td id="T_c3d2f_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_c3d2f_row2_col9" class="data row2 col9" >—</td>
#       <td id="T_c3d2f_row2_col10" class="data row2 col10" >—</td>
#     </tr>
#     <tr>
#       <th id="T_c3d2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3d2f_row3_col0" class="data row3 col0" >user_holdout</td>
#       <td id="T_c3d2f_row3_col1" class="data row3 col1" >QAT</td>
#       <td id="T_c3d2f_row3_col2" class="data row3 col2" >ok</td>
#       <td id="T_c3d2f_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_c3d2f_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_c3d2f_row3_col5" class="data row3 col5" >micro_mutable_main</td>
#       <td id="T_c3d2f_row3_col6" class="data row3 col6" >micro_mutable_main</td>
#       <td id="T_c3d2f_row3_col7" class="data row3 col7" >—</td>
#       <td id="T_c3d2f_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_c3d2f_row3_col9" class="data row3 col9" >—</td>
#       <td id="T_c3d2f_row3_col10" class="data row3 col10" >—</td>
#     </tr>
#   </tbody>
# </table>
# Note: if you changed model_variant/run_id, compare only current run rows and artifacts. Older files may still exist under reports/<paper_slug>/.
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:410: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   comparison_df.style.format(
# <style type="text/css">
# </style>
# <table id="T_912cc">
#   <caption>Table 1 — Accuracy, macro F1, model size, timing, and accuracy delta vs paper target (baseline/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_912cc_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_912cc_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_912cc_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_912cc_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_912cc_level0_col4" class="col_heading level0 col4" >macro_f1</th>
#       <th id="T_912cc_level0_col5" class="col_heading level0 col5" >model_size_kb</th>
#       <th id="T_912cc_level0_col6" class="col_heading level0 col6" >training_time_sec</th>
#       <th id="T_912cc_level0_col7" class="col_heading level0 col7" >inference_latency_ms_median</th>
#       <th id="T_912cc_level0_col8" class="col_heading level0 col8" >inference_latency_ms_p95</th>
#       <th id="T_912cc_level0_col9" class="col_heading level0 col9" >status</th>
#       <th id="T_912cc_level0_col10" class="col_heading level0 col10" >ptq_status</th>
#       <th id="T_912cc_level0_col11" class="col_heading level0 col11" >qat_status</th>
#       <th id="T_912cc_level0_col12" class="col_heading level0 col12" >paper_target_accuracy</th>
#       <th id="T_912cc_level0_col13" class="col_heading level0 col13" >acc_delta_vs_target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_912cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_912cc_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_912cc_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_912cc_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_912cc_row0_col3" class="data row0 col3" >0.9930</td>
#       <td id="T_912cc_row0_col4" class="data row0 col4" >0.9848</td>
#       <td id="T_912cc_row0_col5" class="data row0 col5" >81.64</td>
#       <td id="T_912cc_row0_col6" class="data row0 col6" >66.56s</td>
#       <td id="T_912cc_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_912cc_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_912cc_row0_col9" class="data row0 col9" >ok</td>
#       <td id="T_912cc_row0_col10" class="data row0 col10" >ok</td>
#       <td id="T_912cc_row0_col11" class="data row0 col11" >ok</td>
#       <td id="T_912cc_row0_col12" class="data row0 col12" >None</td>
#       <td id="T_912cc_row0_col13" class="data row0 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_912cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_912cc_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_912cc_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_912cc_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_912cc_row1_col3" class="data row1 col3" >0.9939</td>
#       <td id="T_912cc_row1_col4" class="data row1 col4" >0.9875</td>
#       <td id="T_912cc_row1_col5" class="data row1 col5" >27.37</td>
#       <td id="T_912cc_row1_col6" class="data row1 col6" >—</td>
#       <td id="T_912cc_row1_col7" class="data row1 col7" >0.090ms</td>
#       <td id="T_912cc_row1_col8" class="data row1 col8" >0.103ms</td>
#       <td id="T_912cc_row1_col9" class="data row1 col9" >ok</td>
#       <td id="T_912cc_row1_col10" class="data row1 col10" >ok</td>
#       <td id="T_912cc_row1_col11" class="data row1 col11" >None</td>
#       <td id="T_912cc_row1_col12" class="data row1 col12" >None</td>
#       <td id="T_912cc_row1_col13" class="data row1 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_912cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_912cc_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_912cc_row2_col1" class="data row2 col1" >random_stratified</td>
#       <td id="T_912cc_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_912cc_row2_col3" class="data row2 col3" >0.9924</td>
#       <td id="T_912cc_row2_col4" class="data row2 col4" >0.9851</td>
#       <td id="T_912cc_row2_col5" class="data row2 col5" >29.41</td>
#       <td id="T_912cc_row2_col6" class="data row2 col6" >36.80s</td>
#       <td id="T_912cc_row2_col7" class="data row2 col7" >0.116ms</td>
#       <td id="T_912cc_row2_col8" class="data row2 col8" >0.145ms</td>
#       <td id="T_912cc_row2_col9" class="data row2 col9" >ok</td>
#       <td id="T_912cc_row2_col10" class="data row2 col10" >None</td>
#       <td id="T_912cc_row2_col11" class="data row2 col11" >ok</td>
#       <td id="T_912cc_row2_col12" class="data row2 col12" >None</td>
#       <td id="T_912cc_row2_col13" class="data row2 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_912cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_912cc_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_912cc_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_912cc_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_912cc_row3_col3" class="data row3 col3" >0.8208</td>
#       <td id="T_912cc_row3_col4" class="data row3 col4" >0.7649</td>
#       <td id="T_912cc_row3_col5" class="data row3 col5" >81.64</td>
#       <td id="T_912cc_row3_col6" class="data row3 col6" >14.96s</td>
#       <td id="T_912cc_row3_col7" class="data row3 col7" >—</td>
#       <td id="T_912cc_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_912cc_row3_col9" class="data row3 col9" >ok</td>
#       <td id="T_912cc_row3_col10" class="data row3 col10" >ok</td>
#       <td id="T_912cc_row3_col11" class="data row3 col11" >ok</td>
#       <td id="T_912cc_row3_col12" class="data row3 col12" >None</td>
#       <td id="T_912cc_row3_col13" class="data row3 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_912cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_912cc_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_912cc_row4_col1" class="data row4 col1" >user_holdout</td>
#       <td id="T_912cc_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_912cc_row4_col3" class="data row4 col3" >0.8235</td>
#       <td id="T_912cc_row4_col4" class="data row4 col4" >0.7658</td>
#       <td id="T_912cc_row4_col5" class="data row4 col5" >27.37</td>
#       <td id="T_912cc_row4_col6" class="data row4 col6" >—</td>
#       <td id="T_912cc_row4_col7" class="data row4 col7" >0.090ms</td>
#       <td id="T_912cc_row4_col8" class="data row4 col8" >0.103ms</td>
#       <td id="T_912cc_row4_col9" class="data row4 col9" >ok</td>
#       <td id="T_912cc_row4_col10" class="data row4 col10" >ok</td>
#       <td id="T_912cc_row4_col11" class="data row4 col11" >None</td>
#       <td id="T_912cc_row4_col12" class="data row4 col12" >None</td>
#       <td id="T_912cc_row4_col13" class="data row4 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_912cc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_912cc_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_912cc_row5_col1" class="data row5 col1" >user_holdout</td>
#       <td id="T_912cc_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_912cc_row5_col3" class="data row5 col3" >0.8598</td>
#       <td id="T_912cc_row5_col4" class="data row5 col4" >0.8283</td>
#       <td id="T_912cc_row5_col5" class="data row5 col5" >29.41</td>
#       <td id="T_912cc_row5_col6" class="data row5 col6" >34.82s</td>
#       <td id="T_912cc_row5_col7" class="data row5 col7" >0.115ms</td>
#       <td id="T_912cc_row5_col8" class="data row5 col8" >0.128ms</td>
#       <td id="T_912cc_row5_col9" class="data row5 col9" >ok</td>
#       <td id="T_912cc_row5_col10" class="data row5 col10" >None</td>
#       <td id="T_912cc_row5_col11" class="data row5 col11" >ok</td>
#       <td id="T_912cc_row5_col12" class="data row5 col12" >None</td>
#       <td id="T_912cc_row5_col13" class="data row5 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_912cc_level0_row6" class="row_heading level0 row6" >6</th>
# Note: Paper-target QAT may be unavailable in source papers; QAT rows here are replication extensions where target is N/A.
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:281: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# <style type="text/css">
# </style>
# <table id="T_267c3">
#   <caption>Table 2 — Model size (FP32/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_267c3_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_267c3_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_267c3_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_267c3_level0_col3" class="col_heading level0 col3" >model_size_kb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_267c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_267c3_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_267c3_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_267c3_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_267c3_row0_col3" class="data row0 col3" >81.64 KB</td>
#     </tr>
#     <tr>
#       <th id="T_267c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_267c3_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_267c3_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_267c3_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_267c3_row1_col3" class="data row1 col3" >27.37 KB</td>
#     </tr>
#     <tr>
#       <th id="T_267c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_267c3_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_267c3_row2_col1" class="data row2 col1" >random_stratified</td>
#       <td id="T_267c3_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_267c3_row2_col3" class="data row2 col3" >29.41 KB</td>
#     </tr>
#     <tr>
#       <th id="T_267c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_267c3_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_267c3_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_267c3_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_267c3_row3_col3" class="data row3 col3" >81.64 KB</td>
#     </tr>
#     <tr>
#       <th id="T_267c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_267c3_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_267c3_row4_col1" class="data row4 col1" >user_holdout</td>
#       <td id="T_267c3_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_267c3_row4_col3" class="data row4 col3" >27.37 KB</td>
#     </tr>
#     <tr>
#       <th id="T_267c3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_267c3_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_267c3_row5_col1" class="data row5 col1" >user_holdout</td>
#       <td id="T_267c3_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_267c3_row5_col3" class="data row5 col3" >29.41 KB</td>
#     </tr>
#   </tbody>
# </table>
# Reproducibility drift — WISDM replication (repeat evaluation on saved checkpoint):
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:439: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   reproducibility_df[
# <style type="text/css">
# #T_8553f_row0_col5, #T_8553f_row1_col5 {
#   color: green;
# }
# </style>
# <table id="T_8553f">
#   <caption>Table 3 — Reproducibility drift (two consecutive FP32 evaluations)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8553f_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_8553f_level0_col1" class="col_heading level0 col1" >split_hash</th>
#       <th id="T_8553f_level0_col2" class="col_heading level0 col2" >baseline_acc_first</th>
#       <th id="T_8553f_level0_col3" class="col_heading level0 col3" >baseline_acc_repeat</th>
#       <th id="T_8553f_level0_col4" class="col_heading level0 col4" >abs_drift</th>
#       <th id="T_8553f_level0_col5" class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8553f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8553f_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_8553f_row0_col1" class="data row0 col1" >68c9e31789bca103</td>
#       <td id="T_8553f_row0_col2" class="data row0 col2" >0.9930</td>
#       <td id="T_8553f_row0_col3" class="data row0 col3" >0.9930</td>
#       <td id="T_8553f_row0_col4" class="data row0 col4" >0.00e+00</td>
#       <td id="T_8553f_row0_col5" class="data row0 col5" >PASS</td>
#     </tr>
#     <tr>
#       <th id="T_8553f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8553f_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_8553f_row1_col1" class="data row1 col1" >2498bff9ddcfc589</td>
#       <td id="T_8553f_row1_col2" class="data row1 col2" >0.8208</td>
#       <td id="T_8553f_row1_col3" class="data row1 col3" >0.8208</td>
#       <td id="T_8553f_row1_col4" class="data row1 col4" >0.00e+00</td>
#       <td id="T_8553f_row1_col5" class="data row1 col5" >PASS</td>
#     </tr>
#   </tbody>
# </table>
# ### Protocol: `random_stratified`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Protocol: `user_holdout`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Classification Report Snippets — `random_stratified`
# FP32: macro_f1=0.9848455901863185, weighted_f1=0.993007183825509
# PTQ: macro_f1=0.9874841057833196, weighted_f1=0.9939205097736455
# QAT: macro_f1=0.9851424090002044, weighted_f1=0.992400615544649
# ### Classification Report Snippets — `user_holdout`
# FP32: macro_f1=0.7648593735898475, weighted_f1=0.8328907476340022
# PTQ: macro_f1=0.7658416992159635, weighted_f1=0.8347646726636818
# QAT: macro_f1=0.8283029705525448, weighted_f1=0.8685965887374871
# ## Saved Comparison CSV Snapshot
#             pipeline           protocol           model  accuracy  macro_f1  \
# 0  WISDM replication  random_stratified  baseline float  0.993013  0.984846
# 1  WISDM replication  random_stratified        PTQ int8  0.993925  0.987484
# 2  WISDM replication  random_stratified        QAT int8  0.992406  0.985142
# 3  WISDM replication       user_holdout  baseline float  0.820821  0.764859
# 4  WISDM replication       user_holdout        PTQ int8  0.823460  0.765842
# 5  WISDM replication       user_holdout        QAT int8  0.859824  0.828303
# 6       paper target                  —  baseline float       NaN       NaN
# 7       paper target                  —        PTQ int8       NaN       NaN
# 8       paper target                  —        QAT int8       NaN       NaN
#
#    model_size_kb  training_time_sec  inference_latency_ms_median  \
# 0      81.636719          66.562952                          NaN
# 1      27.367188                NaN                     0.089829
# 2      29.414062          36.799940                     0.115719
# 3      81.636719          14.962016                          NaN
# 4      27.367188                NaN                     0.090254
# 5      29.414062          34.824466                     0.115034
# 6            NaN                NaN                          NaN
# 7            NaN                NaN                          NaN
# 8            NaN                NaN                          NaN
#
#    inference_latency_ms_p95     status ptq_status qat_status  \
# 0                       NaN         ok         ok         ok
# 1                  0.103276         ok         ok        NaN
# 2                  0.144666         ok        NaN         ok
# 3                       NaN         ok         ok         ok
# 4                  0.103059         ok         ok        NaN
# 5                  0.127561         ok        NaN         ok
# 6                       NaN  reference        NaN        NaN
# 7                       NaN  reference        NaN        NaN
# 8                       NaN  reference        NaN        NaN
#
#    paper_target_accuracy  acc_delta_vs_target
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                    NaN                  NaN
# 7                    NaN                  NaN
# 8                    NaN                  NaN
# ## Master Results Snapshot
#        paper_slug           protocol                    variant    run_id  \
# 10  daghero_qadnn  random_stratified  daghero_cnn_2layer_conv2d  wisdm_r0
# 11  daghero_qadnn       user_holdout  daghero_cnn_2layer_conv2d  wisdm_r0
#
#     window_size  seed compression_focus      run_mode train_device  \
# 10          200    42      ptq_qat_only  sanity_check          gpu
# 11          200    42      ptq_qat_only  sanity_check          gpu
#
#    eval_fp32_device  ...                                   qat_metrics_json  \
# 10              gpu  ...  /home/dellio/github/har-mcu/reports/daghero_qa...
# 11              gpu  ...  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                       ptq_report_json  \
# 10  /home/dellio/github/har-mcu/reports/daghero_qa...
# 11  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                       qat_report_json  \
# 10  /home/dellio/github/har-mcu/reports/daghero_qa...
# 11  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                     run_artifact_json  \
# 10  /home/dellio/github/har-mcu/reports/daghero_qa...
# 11  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#     ptq_allowed_ops_profile  qat_allowed_ops_profile  fp32_model_size_kb  \
# 10       micro_mutable_main       micro_mutable_main           81.636719
# 11       micro_mutable_main       micro_mutable_main           81.636719
#
#                                     fp32_tflite_model fp32_tflite_status  \
# 10  /home/dellio/github/har-mcu/models_tflite/dagh...                 ok
# 11  /home/dellio/github/har-mcu/models_tflite/dagh...                 ok
#
#    fp32_tflite_error
# 10               NaN
# 11               NaN
#
# [2 rows x 54 columns]
# Saved outputs root: /home/dellio/github/har-mcu/reports/daghero_qadnn
# {'rows_df':       paper_slug           protocol                    variant    run_id  \
#  0  daghero_qadnn  random_stratified  daghero_cnn_2layer_conv2d  wisdm_r0
#  1  daghero_qadnn       user_holdout  daghero_cnn_2layer_conv2d  wisdm_r0
#
#     window_size  seed compression_focus      run_mode train_device  \
#  0          200    42      ptq_qat_only  sanity_check          gpu
#  1          200    42      ptq_qat_only  sanity_check          gpu
#
#    eval_fp32_device  ...                                        deploy_gate  \
#  0              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
#  1              gpu  ...  {'ptq': {'status': 'ok', 'full_integer_io': Tr...
#
#    paper_target_score delta_vs_paper notes_assumptions  \
#  0               None           None              None
#  1               None           None              None
#
#                                     fp32_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/daghero_qa...
#  1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                      ptq_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/daghero_qa...
#  1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                      qat_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/daghero_qa...
#  1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                       ptq_report_json  \
#  0  /home/dellio/github/har-mcu/reports/daghero_qa...
#  1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                       qat_report_json  \
#  0  /home/dellio/github/har-mcu/reports/daghero_qa...
#  1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#                                     run_artifact_json
#  0  /home/dellio/github/har-mcu/reports/daghero_qa...
#  1  /home/dellio/github/har-mcu/reports/daghero_qa...
#
#  [2 rows x 54 columns],
#  'ptq_operator_visibility': [{'protocol': 'random_stratified',
#    'interpreter_ops': ['CONV_2D',
#     'FULLY_CONNECTED',
#     'MAX_POOL_2D',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'tflm_ops': ['CONV_2D',
#     'FULLY_CONNECTED',
#     'MAX_POOL_2D',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'only_interpreter': [],
#    'only_tflm': []},
#   {'protocol': 'user_holdout',
#    'interpreter_ops': ['CONV_2D',
#     'FULLY_CONNECTED',
#     'MAX_POOL_2D',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'tflm_ops': ['CONV_2D',
#     'FULLY_CONNECTED',
#     'MAX_POOL_2D',
#     'MEAN',
#     'PACK',
#     'RESHAPE',
#     'SHAPE',
#     'SOFTMAX',
#     'STRIDED_SLICE'],
#    'only_interpreter': [],
#    'only_tflm': []}],
#  'ptq_operator_warnings': [],
#  'strict_deploy_df':             protocol tier status  full_integer_io  tflm_compatible  \
#  0  random_stratified  PTQ     ok             True             True
#  1  random_stratified  QAT     ok             True             True
#  2       user_holdout  PTQ     ok             True             True
#  3       user_holdout  QAT     ok             True             True
#
#    allowed_ops_profile compatibility_scope unsupported_ops_micro_mutable  \
#  0  micro_mutable_main  micro_mutable_main                          None
#  1  micro_mutable_main  micro_mutable_main                          None
#  2  micro_mutable_main  micro_mutable_main                          None
#  3  micro_mutable_main  micro_mutable_main                          None
#
#    possibly_supported_upstream_tflm unsupported_in_reference error
#  0                             None                     None  None
#  1                             None                     None  None
#  2                             None                     None  None
#  3                             None                     None  None  ,
#  'legacy_artifact_detected': False,
#  'strict_summary_lines': ['[random_stratified] ptq_status=ok | qat_status=ok',
#   '[user_holdout] ptq_status=ok | qat_status=ok'],
#  'comparison_df':             pipeline           protocol           model  accuracy  macro_f1  \
#  0  WISDM replication  random_stratified  baseline float  0.993013  0.984846
#  1  WISDM replication  random_stratified        PTQ int8  0.993925  0.987484
#  2  WISDM replication  random_stratified        QAT int8  0.992406  0.985142
#  3  WISDM replication       user_holdout  baseline float  0.820821  0.764859
#  4  WISDM replication       user_holdout        PTQ int8  0.823460  0.765842
#  5  WISDM replication       user_holdout        QAT int8  0.859824  0.828303
#  6       paper target                  —  baseline float       NaN       NaN
#  7       paper target                  —        PTQ int8       NaN       NaN
#  8       paper target                  —        QAT int8       NaN       NaN
#
#     model_size_kb  training_time_sec  inference_latency_ms_median  \
#  0      81.636719          66.562952                          NaN
#  1      27.367188                NaN                     0.089829
#  2      29.414062          36.799940                     0.115719
#  3      81.636719          14.962016                          NaN
#  4      27.367188                NaN                     0.090254
#  5      29.414062          34.824466                     0.115034
#  6            NaN                NaN                          NaN
#  7            NaN                NaN                          NaN
#  8            NaN                NaN                          NaN
#
#     inference_latency_ms_p95     status ptq_status qat_status  \
#  0                       NaN         ok         ok         ok
#  1                  0.103276         ok         ok       None
#  2                  0.144666         ok       None         ok
#  3                       NaN         ok         ok         ok
#  4                  0.103059         ok         ok       None
#  5                  0.127561         ok       None         ok
#  6                       NaN  reference       None       None
#  7                       NaN  reference       None       None
#  8                       NaN  reference       None       None
#
#    paper_target_accuracy acc_delta_vs_target
#  0                  None                None
#  1                  None                None
#  2                  None                None
#  3                  None                None
#  4                  None                None
#  5                  None                None
#  6                  None                None
#  7                  None                None
#  8                  None                None  ,
#  'reproducibility_df':             protocol        split_hash  baseline_acc_first  \
#  0  random_stratified  68c9e31789bca103            0.993013
#  1       user_holdout  2498bff9ddcfc589            0.820821
#
#     baseline_acc_repeat  abs_drift status
#  0             0.993013        0.0   PASS
#  1             0.820821        0.0   PASS  }

# %% [markdown]
# ## Notes
# - If QAT conversion fails strict deploy-gate checks, results are still exported with explicit failure reason.
# - Document unresolved paper ambiguities in `reports/paper_specs_<slug>.md`.
