# %% [markdown]
# # Replication Notebook — XTinyHAR (WISDM-first)

# %% [markdown]
# ## Paper Facts and Code Availability
# - Paper DOI: https://doi.org/10.1038/s41598-025-26297-2
# - Official repo: https://github.com/Ism-ail11/XTinyHAR
# - Original protocol summary: 3s window, 50% overlap, 50Hz resample, KD T=3 alpha=0.7.
#
# ## WISDM Adaptation
# - Active config: `configs/papers/xtinyhar_wisdm.yaml`
# - This notebook runs WISDM-first adaptation while preserving paper architecture intent.

# %% [markdown]
# ## Notebook Contract
# - Runtime / dependency guard
# - Paper facts + code availability
# - WISDM adaptation section
# - FP32 training/eval on `random_stratified` + `user_holdout`
# - PTQ INT8 + QAT INT8 exports
# - FP32 float `.tflite` export for size tracking (`fp32_model_size_kb`)
# - Strict deploy-gate summary (`full_integer_io`, `tflm_compatible`, unsupported ops)
# - Per-paper CSV/MD + master results append

# %% [markdown]
# ## Compression Scope Note
# - KD-related methodology from papers is documented for reproducibility context only.
# - Notebook execution enforces PTQ/QAT compression flow only (`experiment.compression_focus=ptq_qat_only`).
# - This notebook uses a Conv2D-equivalent architecture for QAT compatibility; Conv1D paper operators are preserved semantically via `(k)->(k,1)` mapping.

# %%
from pathlib import Path
import sys
import os
import json
import importlib
import importlib.util

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, Markdown, display

# Optional safeguard: disable GPU if kernel is unstable on CUDA runtime.
USE_GPU = True
if not USE_GPU:
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Ensure repo root is importable when launched from different working directories.
REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "src").exists():
    for parent in [REPO_ROOT, *REPO_ROOT.parents]:
        if (parent / "src").exists():
            REPO_ROOT = parent
            break
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

required_modules = {
    "numpy": "numpy",
    "pandas": "pandas",
    "matplotlib": "matplotlib",
    "IPython": "ipython",
    "yaml": "PyYAML",
    "sklearn": "scikit-learn",
    "tensorflow": "tensorflow",
    "tensorflow_model_optimization": "tensorflow-model-optimization",
}
missing = [
    f"{mod} (pip package: {pkg})"
    for mod, pkg in required_modules.items()
    if importlib.util.find_spec(mod) is None
]
if missing:
    missing_text = "\n- ".join(missing)
    raise ModuleNotFoundError(
        "Missing required notebook dependencies:\n- "
        + missing_text
        + "\n\nActivate tinymlproj and install dependencies:\n"
        + "conda activate tinymlproj && conda env update -n tinymlproj -f environment.yml --prune"
    )

import tensorflow as tf
print("TF version:", tf.__version__)
print("Visible GPUs:", tf.config.list_physical_devices("GPU"))

# Fail fast if local file is stale (pre-FP32-TFLite-size patch).
_rpe_file = REPO_ROOT / "src/run_paper_experiment.py"
if _rpe_file.exists():
    _rpe_src = _rpe_file.read_text(encoding="utf-8")
    if "from src.utils.artifacts import model_fp32_tflite_path" in _rpe_src:
        raise RuntimeError(
            "Outdated src/run_paper_experiment.py detected in workspace. "
            "Please refresh repo files and rerun from the first cell."
        )

importlib.invalidate_caches()
for _stale_mod in ("src.run_paper_experiment",):
    sys.modules.pop(_stale_mod, None)

AUTO_RELOAD_PROJECT_MODULES = True
if AUTO_RELOAD_PROJECT_MODULES:
    for _mod_name in (
        "src.models.xtinyhar_student_tf",
        "src.models.repmobile_folded_tf",
        "src.models.tcn_attention_har_tf",
        "src.models.daghero_cnn_searchspace_tf",
        "src.models.tcn_inception_tf",
        "src.models.serialization",
        "src.eval.evaluate_model",
        "src.quant.ptq_full_int8",
        "src.quant.qat_train",
        "src.utils.artifacts",
        "src.eval.notebook_reporting",
        "src.run_paper_experiment",
    ):
        if _mod_name in sys.modules:
            importlib.reload(sys.modules[_mod_name])

import src.run_paper_experiment as _run_mod
run_paper_experiment = _run_mod.run_paper_experiment

from src.utils.config import load_yaml
from src.utils.device_runtime import runtime_device_report
from src.eval.evaluate_model import evaluate_model_for_protocol
from src.utils.artifacts import model_ckpt_path, split_npz_path

if "load_checkpoint_model" not in evaluate_model_for_protocol.__code__.co_names:
    raise RuntimeError(
        "Stale evaluate_model module detected (safe loader missing). "
        "Restart kernel and rerun from the first cell."
    )

RUN_MODE = "sanity_check"  # switch to "full_run" for full-length runs (GPU-first, CPU fallback enabled)
CONFIG_PATH = REPO_ROOT / 'configs/papers/xtinyhar_wisdm.yaml'
assert CONFIG_PATH.exists(), f"Missing config: {CONFIG_PATH}"
cfg = load_yaml(CONFIG_PATH)
cfg.setdefault("runtime", {})["run_mode"] = RUN_MODE
cfg.setdefault("experiment", {})["compression_focus"] = "ptq_qat_only"
runtime = runtime_device_report(cfg)

print("repo_root:", REPO_ROOT)
print("paper_slug:", cfg.get("experiment", {}).get("paper_slug"))
print("model_variant:", cfg.get("experiment", {}).get("model_variant"))
is_conv2d_variant = str(cfg.get("experiment", {}).get("model_variant", "")).endswith("_conv2d")
print("conv2d_qat_safe_variant:", is_conv2d_variant)
print("[NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.")
if not is_conv2d_variant:
    print("[WARN] Active model_variant is not *_conv2d; QAT may fail on Conv1D/SeparableConv1D in tfmot 0.8.")
print("window_size:", cfg.get("paper_protocol", {}).get("wisdm_window_override"))
print("run_mode:", runtime["run_mode"])
print("detected_gpus:", runtime["gpus"])
print("stage_device_map:", runtime["resolved_stage_devices"])
print("[NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.")

strict_gate_cfg = {
    "ptq_strict_full_int8": bool(cfg.get("quant", {}).get("ptq", {}).get("strict_full_int8", True)),
    "ptq_require_tflm_compatible": bool(cfg.get("quant", {}).get("ptq", {}).get("require_tflm_compatible", True)),
    "ptq_accepted_integer_io_dtypes": cfg.get("quant", {}).get("ptq", {}).get("accepted_integer_io_dtypes", ["int8", "uint8"]),
    "qat_strict_full_int8": bool(cfg.get("quant", {}).get("qat", {}).get("strict_full_int8", True)),
    "qat_require_tflm_compatible": bool(cfg.get("quant", {}).get("qat", {}).get("require_tflm_compatible", True)),
    "qat_accepted_integer_io_dtypes": cfg.get("quant", {}).get("qat", {}).get("accepted_integer_io_dtypes", ["int8", "uint8"]),
    "deploy_allowed_ops_profile": cfg.get("deploy", {}).get("allowed_ops_profile", "default"),
    "deploy_allowed_ops_override": cfg.get("deploy", {}).get("allowed_ops"),
}
print("strict_gate_cfg:", strict_gate_cfg)
# Out:
# 2026-03-05 02:47:14.725963: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-05 02:47:14.726046: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-05 02:47:14.726157: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-05 02:47:14.751202: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TF version: 2.14.1
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-03-05 02:47:16.542238: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:16.578023: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:16.578074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# repo_root: /home/dellio/github/har-mcu
# paper_slug: xtinyhar
# model_variant: xtinyhar_student_conv2d
# conv2d_qat_safe_variant: True
# [NOTE] Conv1D paper ops are executed via Conv2D-equivalent mapping (k)->(k,1) for QAT compatibility.
# window_size: 200
# run_mode: sanity_check
# detected_gpus: ['/physical_device:GPU:0']
# stage_device_map: {'train': 'gpu', 'eval_fp32': 'gpu', 'ptq': 'gpu', 'eval_ptq': 'gpu', 'qat': 'gpu', 'eval_qat': 'gpu'}
# [NOTE] Auto-reload is ON to prevent stale module paths in notebook runtime.
# strict_gate_cfg: {'ptq_strict_full_int8': True, 'ptq_require_tflm_compatible': True, 'ptq_accepted_integer_io_dtypes': ['int8', 'uint8'], 'qat_strict_full_int8': True, 'qat_require_tflm_compatible': True, 'qat_accepted_integer_io_dtypes': ['int8', 'uint8'], 'deploy_allowed_ops_profile': 'nano33ble_extended', 'deploy_allowed_ops_override': None}

# %%
# Run FP32 + PTQ + QAT + standardized reporting
out = run_paper_experiment(cfg)
out
# Out:
# 2026-03-05 02:47:17.014837: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:17.014917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:17.014954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:17.206865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:17.206921: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:17.206930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-03-05 02:47:17.206969: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-05 02:47:17.207030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21764 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:2d:00.0, compute capability: 8.6
# Epoch 1/20
# 2026-03-05 02:47:20.831236: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2026-03-05 02:47:22.007560: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x61c127180750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-05 02:47:22.007603: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2026-03-05 02:47:22.011703: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-03-05 02:47:22.086105: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 84/84 - 8s - loss: 1.1466 - accuracy: 0.6089 - val_loss: 0.8551 - val_accuracy: 0.7375 - lr: 1.0000e-04 - 8s/epoch - 99ms/step
# Epoch 2/20
# 84/84 - 2s - loss: 0.8118 - accuracy: 0.7593 - val_loss: 0.6643 - val_accuracy: 0.7891 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 3/20
# 84/84 - 2s - loss: 0.6520 - accuracy: 0.8019 - val_loss: 0.5689 - val_accuracy: 0.8153 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 4/20
# 84/84 - 2s - loss: 0.5587 - accuracy: 0.8259 - val_loss: 0.4953 - val_accuracy: 0.8310 - lr: 1.0000e-04 - 2s/epoch - 26ms/step
# Epoch 5/20
# 84/84 - 2s - loss: 0.4946 - accuracy: 0.8401 - val_loss: 0.4586 - val_accuracy: 0.8414 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 6/20
# 84/84 - 2s - loss: 0.4436 - accuracy: 0.8522 - val_loss: 0.4229 - val_accuracy: 0.8519 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 7/20
# 84/84 - 2s - loss: 0.4117 - accuracy: 0.8605 - val_loss: 0.4051 - val_accuracy: 0.8527 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 8/20
# 84/84 - 2s - loss: 0.3754 - accuracy: 0.8767 - val_loss: 0.3882 - val_accuracy: 0.8586 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 9/20
# 84/84 - 2s - loss: 0.3571 - accuracy: 0.8795 - val_loss: 0.3647 - val_accuracy: 0.8646 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 10/20
# 84/84 - 2s - loss: 0.3334 - accuracy: 0.8848 - val_loss: 0.3434 - val_accuracy: 0.8728 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 11/20
# 84/84 - 2s - loss: 0.3094 - accuracy: 0.8967 - val_loss: 0.3328 - val_accuracy: 0.8833 - lr: 1.0000e-04 - 2s/epoch - 26ms/step
# Epoch 12/20
# 84/84 - 2s - loss: 0.2855 - accuracy: 0.9005 - val_loss: 0.3264 - val_accuracy: 0.8803 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 13/20
# 84/84 - 2s - loss: 0.2770 - accuracy: 0.9059 - val_loss: 0.3070 - val_accuracy: 0.8886 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 14/20
# 84/84 - 2s - loss: 0.2507 - accuracy: 0.9141 - val_loss: 0.3105 - val_accuracy: 0.8863 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 15/20
# 84/84 - 2s - loss: 0.2383 - accuracy: 0.9155 - val_loss: 0.2973 - val_accuracy: 0.8953 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 16/20
# 84/84 - 2s - loss: 0.2190 - accuracy: 0.9276 - val_loss: 0.2944 - val_accuracy: 0.9028 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 17/20
# 84/84 - 2s - loss: 0.2160 - accuracy: 0.9261 - val_loss: 0.2727 - val_accuracy: 0.9095 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 18/20
# 84/84 - 2s - loss: 0.1995 - accuracy: 0.9314 - val_loss: 0.2667 - val_accuracy: 0.9095 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 19/20
# 84/84 - 2s - loss: 0.1872 - accuracy: 0.9357 - val_loss: 0.2541 - val_accuracy: 0.9125 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# Epoch 20/20
# 84/84 - 2s - loss: 0.1799 - accuracy: 0.9373 - val_loss: 0.2453 - val_accuracy: 0.9185 - lr: 1.0000e-04 - 2s/epoch - 27ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpjus4qzhf/assets
# INFO:tensorflow:Assets written to: /tmp/tmpjus4qzhf/assets
# 2026-03-05 02:48:13.705402: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:48:13.705475: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:48:13.705721: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpjus4qzhf
# 2026-03-05 02:48:13.710160: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:48:13.710174: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpjus4qzhf
# 2026-03-05 02:48:13.718376: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2026-03-05 02:48:13.720771: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:48:13.764746: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpjus4qzhf
# 2026-03-05 02:48:13.786952: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 81231 microseconds.
# INFO:tensorflow:Assets written to: /tmp/tmpq_uy8vl9/assets
# INFO:tensorflow:Assets written to: /tmp/tmpq_uy8vl9/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:48:18.511024: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:48:18.511069: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:48:18.511214: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpq_uy8vl9
# 2026-03-05 02:48:18.515770: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:48:18.515784: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpq_uy8vl9
# 2026-03-05 02:48:18.525176: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:48:18.570307: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpq_uy8vl9
# 2026-03-05 02:48:18.591926: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 80712 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/8
# 84/84 - 6s - loss: 0.1663 - accuracy: 0.9448 - val_loss: 0.2500 - val_accuracy: 0.9177 - 6s/epoch - 75ms/step
# Epoch 2/8
# 84/84 - 3s - loss: 0.1616 - accuracy: 0.9508 - val_loss: 0.2300 - val_accuracy: 0.9267 - 3s/epoch - 32ms/step
# Epoch 3/8
# 84/84 - 3s - loss: 0.1511 - accuracy: 0.9501 - val_loss: 0.2226 - val_accuracy: 0.9282 - 3s/epoch - 34ms/step
# Epoch 4/8
# 84/84 - 3s - loss: 0.1413 - accuracy: 0.9529 - val_loss: 0.2175 - val_accuracy: 0.9304 - 3s/epoch - 34ms/step
# Epoch 5/8
# 84/84 - 3s - loss: 0.1405 - accuracy: 0.9549 - val_loss: 0.2066 - val_accuracy: 0.9342 - 3s/epoch - 36ms/step
# Epoch 6/8
# 84/84 - 3s - loss: 0.1288 - accuracy: 0.9564 - val_loss: 0.2038 - val_accuracy: 0.9394 - 3s/epoch - 34ms/step
# Epoch 7/8
# 84/84 - 3s - loss: 0.1277 - accuracy: 0.9570 - val_loss: 0.1977 - val_accuracy: 0.9357 - 3s/epoch - 36ms/step
# Epoch 8/8
# 84/84 - 3s - loss: 0.1168 - accuracy: 0.9613 - val_loss: 0.1918 - val_accuracy: 0.9387 - 3s/epoch - 36ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpmohufx9w/assets
# INFO:tensorflow:Assets written to: /tmp/tmpmohufx9w/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:48:52.392438: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:48:52.392485: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:48:52.392622: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpmohufx9w
# 2026-03-05 02:48:52.398949: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:48:52.398970: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpmohufx9w
# 2026-03-05 02:48:52.417050: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:48:52.499615: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpmohufx9w
# 2026-03-05 02:48:52.528030: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 135406 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/20
# 83/83 - 6s - loss: 1.1426 - accuracy: 0.6106 - val_loss: 0.9330 - val_accuracy: 0.7194 - lr: 1.0000e-04 - 6s/epoch - 75ms/step
# Epoch 2/20
# 83/83 - 2s - loss: 0.7624 - accuracy: 0.7881 - val_loss: 0.7698 - val_accuracy: 0.7500 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 3/20
# 83/83 - 3s - loss: 0.5956 - accuracy: 0.8284 - val_loss: 0.6524 - val_accuracy: 0.7982 - lr: 1.0000e-04 - 3s/epoch - 30ms/step
# Epoch 4/20
# 83/83 - 3s - loss: 0.5028 - accuracy: 0.8438 - val_loss: 0.5887 - val_accuracy: 0.8196 - lr: 1.0000e-04 - 3s/epoch - 32ms/step
# Epoch 5/20
# 83/83 - 2s - loss: 0.4415 - accuracy: 0.8528 - val_loss: 0.5588 - val_accuracy: 0.8364 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 6/20
# 83/83 - 2s - loss: 0.3864 - accuracy: 0.8708 - val_loss: 0.5546 - val_accuracy: 0.8379 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 7/20
# 83/83 - 2s - loss: 0.3489 - accuracy: 0.8830 - val_loss: 0.5437 - val_accuracy: 0.8356 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 8/20
# 83/83 - 2s - loss: 0.3133 - accuracy: 0.8904 - val_loss: 0.6104 - val_accuracy: 0.8058 - lr: 1.0000e-04 - 2s/epoch - 28ms/step
# Epoch 9/20
# 83/83 - 2s - loss: 0.2812 - accuracy: 0.9024 - val_loss: 0.5749 - val_accuracy: 0.8127 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 10/20
# 83/83 - 2s - loss: 0.2581 - accuracy: 0.9165 - val_loss: 0.5826 - val_accuracy: 0.8226 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 11/20
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 83/83 - 2s - loss: 0.2332 - accuracy: 0.9239 - val_loss: 0.6458 - val_accuracy: 0.7974 - lr: 1.0000e-04 - 2s/epoch - 29ms/step
# Epoch 12/20
# 83/83 - 2s - loss: 0.2146 - accuracy: 0.9296 - val_loss: 0.6775 - val_accuracy: 0.7806 - lr: 5.0000e-05 - 2s/epoch - 30ms/step
# Epoch 13/20
# Restoring model weights from the end of the best epoch: 7.
# 83/83 - 2s - loss: 0.1974 - accuracy: 0.9344 - val_loss: 0.6389 - val_accuracy: 0.8020 - lr: 5.0000e-05 - 2s/epoch - 29ms/step
# Epoch 13: early stopping
# INFO:tensorflow:Assets written to: /tmp/tmpjsptoz4d/assets
# INFO:tensorflow:Assets written to: /tmp/tmpjsptoz4d/assets
# 2026-03-05 02:49:32.348037: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:49:32.348077: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:49:32.348200: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpjsptoz4d
# 2026-03-05 02:49:32.353572: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:49:32.353586: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpjsptoz4d
# 2026-03-05 02:49:32.364722: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:49:32.407670: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpjsptoz4d
# 2026-03-05 02:49:32.426031: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 77831 microseconds.
# INFO:tensorflow:Assets written to: /tmp/tmptibdrj7n/assets
# INFO:tensorflow:Assets written to: /tmp/tmptibdrj7n/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:49:37.361795: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:49:37.361835: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:49:37.361962: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmptibdrj7n
# 2026-03-05 02:49:37.367285: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:49:37.367299: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmptibdrj7n
# 2026-03-05 02:49:37.380359: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:49:37.424272: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmptibdrj7n
# 2026-03-05 02:49:37.444033: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 82071 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Epoch 1/8
# 83/83 - 6s - loss: 0.3158 - accuracy: 0.8893 - val_loss: 0.5860 - val_accuracy: 0.8196 - 6s/epoch - 74ms/step
# Epoch 2/8
# 83/83 - 3s - loss: 0.2822 - accuracy: 0.9041 - val_loss: 0.5761 - val_accuracy: 0.8303 - 3s/epoch - 37ms/step
# Epoch 3/8
# 83/83 - 3s - loss: 0.2564 - accuracy: 0.9121 - val_loss: 0.5422 - val_accuracy: 0.8280 - 3s/epoch - 34ms/step
# Epoch 4/8
# 83/83 - 3s - loss: 0.2347 - accuracy: 0.9201 - val_loss: 0.5975 - val_accuracy: 0.8157 - 3s/epoch - 35ms/step
# Epoch 5/8
# 83/83 - 3s - loss: 0.2162 - accuracy: 0.9247 - val_loss: 0.6210 - val_accuracy: 0.8112 - 3s/epoch - 38ms/step
# Epoch 6/8
# 83/83 - 3s - loss: 0.1933 - accuracy: 0.9351 - val_loss: 0.5909 - val_accuracy: 0.8219 - 3s/epoch - 38ms/step
# Epoch 7/8
# 83/83 - 3s - loss: 0.1834 - accuracy: 0.9387 - val_loss: 0.6230 - val_accuracy: 0.8127 - 3s/epoch - 37ms/step
# Epoch 8/8
# 83/83 - 3s - loss: 0.1669 - accuracy: 0.9435 - val_loss: 0.6736 - val_accuracy: 0.8005 - 3s/epoch - 34ms/step
# INFO:tensorflow:Assets written to: /tmp/tmpkpyhqv9l/assets
# INFO:tensorflow:Assets written to: /tmp/tmpkpyhqv9l/assets
# /home/dellio/anaconda3/envs/tinymlproj/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2026-03-05 02:50:11.143214: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-03-05 02:50:11.143260: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-03-05 02:50:11.143429: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpkpyhqv9l
# 2026-03-05 02:50:11.148402: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-03-05 02:50:11.148418: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpkpyhqv9l
# 2026-03-05 02:50:11.163435: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-03-05 02:50:11.248046: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpkpyhqv9l
# 2026-03-05 02:50:11.279728: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 136298 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/dellio/github/har-mcu/src/eval/reporting.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([existing, incoming], ignore_index=True)
# /home/dellio/github/har-mcu/src/eval/paper_comparison.py:193: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# {'paper_slug': 'xtinyhar',
#  'rows': [{'paper_slug': 'xtinyhar',
#    'protocol': 'random_stratified',
#    'variant': 'xtinyhar_student_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'gpu',
#    'eval_qat_device': 'gpu',
#    'fp32_training_time_sec': 52.20173649299977,
#    'fp32_model_size_kb': 320.5390625,
#    'fp32_tflite_model': '/home/dellio/github/har-mcu/models_tflite/xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0_fp32.tflite',
#    'fp32_tflite_status': 'ok',
#    'fp32_tflite_error': None,
#    'qat_training_time_sec': 26.643862249999984,
#    'accuracy': 0.9188942891859052,
#    'macro_f1': 0.8748371963957752,
#    'ptq_status': 'failed',
#    'qat_status': 'failed',
#    'ptq_allowed_ops_profile': 'micro_mutable_main',
#    'qat_allowed_ops_profile': 'micro_mutable_main',
#    'ptq_accuracy': 0.9185905224787363,
#    'ptq_macro_f1': 0.8741101749999727,
#    'qat_accuracy': 0.9365127582017011,
#    'qat_macro_f1': 0.908275252200763,
#    'ptq_model_size_kb': 119.1484375,
#    'qat_model_size_kb': 119.5859375,
#    'model_size_kb': 119.1484375,
#    'ptq_inference_latency_ms_median': 0.17823799953475827,
#    'ptq_inference_latency_ms_p95': 0.27427274972069426,
#    'qat_inference_latency_ms_median': 0.17706849985188455,
#    'qat_inference_latency_ms_p95': 0.2098507497976243,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/xtinyhar/curve_fp32_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/xtinyhar/curve_qat_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/xtinyhar/confusion_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/xtinyhar/confusion_ptq_xtinyhar_student_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/xtinyhar/confusion_qat_xtinyhar_student_conv2d_wisdm_r0_T200_Prandom_stratified.png',
#    'deploy_gate': {'ptq': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops_profile': ['GELU', 'REDUCE_PROD'],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': ['GELU', 'REDUCE_PROD']},
#     'qat': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops_profile': ['GELU', 'REDUCE_PROD'],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': ['GELU', 'REDUCE_PROD']}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/xtinyhar/xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/xtinyhar/ptq_xtinyhar_student_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/xtinyhar/qat_xtinyhar_student_conv2d_wisdm_r0_T200_Prandom_stratified.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/xtinyhar/ptq_export_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/xtinyhar/qat_export_xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/xtinyhar/artifacts/xtinyhar_xtinyhar_student_conv2d_random_stratified_wisdm_r0.json'},
#   {'paper_slug': 'xtinyhar',
#    'protocol': 'user_holdout',
#    'variant': 'xtinyhar_student_conv2d',
#    'run_id': 'wisdm_r0',
#    'window_size': 200,
#    'seed': 42,
#    'compression_focus': 'ptq_qat_only',
#    'run_mode': 'sanity_check',
#    'train_device': 'gpu',
#    'eval_fp32_device': 'gpu',
#    'ptq_device': 'gpu',
#    'eval_ptq_device': 'gpu',
#    'qat_device': 'gpu',
#    'eval_qat_device': 'gpu',
#    'fp32_training_time_sec': 35.25273950200062,
#    'fp32_model_size_kb': 320.84375,
#    'fp32_tflite_model': '/home/dellio/github/har-mcu/models_tflite/xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0_fp32.tflite',
#    'fp32_tflite_status': 'ok',
#    'fp32_tflite_error': None,
#    'qat_training_time_sec': 27.204162859000462,
#    'accuracy': 0.7686217008797654,
#    'macro_f1': 0.6084267116743621,
#    'ptq_status': 'failed',
#    'qat_status': 'failed',
#    'ptq_allowed_ops_profile': 'micro_mutable_main',
#    'qat_allowed_ops_profile': 'micro_mutable_main',
#    'ptq_accuracy': 0.7700879765395895,
#    'ptq_macro_f1': 0.611842800307793,
#    'qat_accuracy': 0.7656891495601174,
#    'qat_macro_f1': 0.6525526800191249,
#    'ptq_model_size_kb': 119.234375,
#    'qat_model_size_kb': 119.5859375,
#    'model_size_kb': 119.234375,
#    'ptq_inference_latency_ms_median': 0.18373800003246288,
#    'ptq_inference_latency_ms_p95': 0.29139275034140155,
#    'qat_inference_latency_ms_median': 0.17666350049694302,
#    'qat_inference_latency_ms_p95': 0.21942775038041873,
#    'fp32_history_json': '/home/dellio/github/har-mcu/checkpoints/history_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_history_json': '/home/dellio/github/har-mcu/checkpoints/history_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0_qat.json',
#    'fp32_curve_png': '/home/dellio/github/har-mcu/reports/xtinyhar/curve_fp32_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'qat_curve_png': '/home/dellio/github/har-mcu/reports/xtinyhar/curve_qat_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'fp32_confusion_plot': '/home/dellio/github/har-mcu/reports/xtinyhar/confusion_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.png',
#    'ptq_confusion_plot': '/home/dellio/github/har-mcu/reports/xtinyhar/confusion_ptq_xtinyhar_student_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'qat_confusion_plot': '/home/dellio/github/har-mcu/reports/xtinyhar/confusion_qat_xtinyhar_student_conv2d_wisdm_r0_T200_Puser_holdout.png',
#    'deploy_gate': {'ptq': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops_profile': ['GELU', 'REDUCE_PROD'],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': ['GELU', 'REDUCE_PROD']},
#     'qat': {'status': 'failed',
#      'full_integer_io': True,
#      'tflm_compatible': False,
#      'compatibility_scope': 'micro_mutable_main',
#      'unsupported_ops_micro_mutable': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops': ['GELU', 'REDUCE_PROD'],
#      'unsupported_ops_profile': ['GELU', 'REDUCE_PROD'],
#      'allowed_ops_profile': 'micro_mutable_main',
#      'allowed_ops_used': ['ADD',
#       'ARG_MAX',
#       'ARG_MIN',
#       'AVERAGE_POOL_2D',
#       'BATCH_MATMUL',
#       'BATCH_TO_SPACE_ND',
#       'CAST',
#       'CEIL',
#       'CIRCULAR_BUFFER',
#       'CONCATENATION',
#       'CONV_2D',
#       'COS',
#       'CUMSUM',
#       'DEPTHWISE_CONV_2D',
#       'DEPTH_TO_SPACE',
#       'DEQUANTIZE',
#       'DIV',
#       'ELU',
#       'EQUAL',
#       'ETHOSU',
#       'EXP',
#       'EXPAND_DIMS',
#       'FILL',
#       'FLOOR',
#       'FLOOR_DIV',
#       'FLOOR_MOD',
#       'FULLY_CONNECTED',
#       'GATHER',
#       'GATHER_ND',
#       'GREATER',
#       'GREATER_EQUAL',
#       'HARD_SWISH',
#       'IF',
#       'L2_NORMALIZATION',
#       'L2_POOL_2D',
#       'LEAKY_RELU',
#       'LESS',
#       'LESS_EQUAL',
#       'LOG',
#       'LOGICAL_AND',
#       'LOGICAL_NOT',
#       'LOGICAL_OR',
#       'LOGISTIC',
#       'LOG_SOFTMAX',
#       'MAXIMUM',
#       'MAX_POOL_2D',
#       'MEAN',
#       'MINIMUM',
#       'MIRROR_PAD',
#       'MUL',
#       'NEG',
#       'NOT_EQUAL',
#       'PACK',
#       'PAD',
#       'PADV2',
#       'PRELU',
#       'QUANTIZE',
#       'READ_VARIABLE',
#       'REDUCE_MAX',
#       'REDUCE_MIN',
#       'RELU',
#       'RELU6',
#       'RELU_0_TO_1',
#       'RELU_N1_TO_1',
#       'RESHAPE',
#       'RESIZE_BILINEAR',
#       'RESIZE_NEAREST_NEIGHBOR',
#       'ROUND',
#       'RSQRT',
#       'SELECT_V2',
#       'SHAPE',
#       'SIN',
#       'SLICE',
#       'SOFTMAX',
#       'SPACE_TO_BATCH_ND',
#       'SPACE_TO_DEPTH',
#       'SPLIT',
#       'SPLIT_V',
#       'SQRT',
#       'SQUARE',
#       'SQUARED_DIFFERENCE',
#       'SQUEEZE',
#       'STRIDED_SLICE',
#       'SUB',
#       'SVDF',
#       'TANH',
#       'TRANSPOSE',
#       'TRANSPOSE_CONV',
#       'UNIDIRECTIONAL_SEQUENCE_LSTM',
#       'UNPACK',
#       'VAR_HANDLE',
#       'WHILE',
#       'ZEROS_LIKE'],
#      'possibly_supported_upstream_tflm': [],
#      'unsupported_in_reference': ['GELU', 'REDUCE_PROD']}},
#    'paper_target_score': None,
#    'delta_vs_paper': None,
#    'notes_assumptions': None,
#    'fp32_metrics_json': '/home/dellio/github/har-mcu/reports/xtinyhar/xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'ptq_metrics_json': '/home/dellio/github/har-mcu/reports/xtinyhar/ptq_xtinyhar_student_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'qat_metrics_json': '/home/dellio/github/har-mcu/reports/xtinyhar/qat_xtinyhar_student_conv2d_wisdm_r0_T200_Puser_holdout.json',
#    'ptq_report_json': '/home/dellio/github/har-mcu/reports/xtinyhar/ptq_export_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'qat_report_json': '/home/dellio/github/har-mcu/reports/xtinyhar/qat_export_xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0.json',
#    'run_artifact_json': '/home/dellio/github/har-mcu/reports/xtinyhar/artifacts/xtinyhar_xtinyhar_student_conv2d_user_holdout_wisdm_r0.json'}],
#  'paper_exports': {'random_stratified': {'csv': '/home/dellio/github/har-mcu/reports/xtinyhar/xtinyhar_results_random_stratified.csv',
#    'md': '/home/dellio/github/har-mcu/reports/xtinyhar/xtinyhar_summary.md'},
#   'user_holdout': {'csv': '/home/dellio/github/har-mcu/reports/xtinyhar/xtinyhar_results_user_holdout.csv',
#    'md': '/home/dellio/github/har-mcu/reports/xtinyhar/xtinyhar_summary.md'}},
#  'comparison_exports': {'csv': '/home/dellio/github/har-mcu/reports/xtinyhar/comparison/xtinyhar_comparison.csv',
#   'md': '/home/dellio/github/har-mcu/reports/xtinyhar/comparison/xtinyhar_comparison.md',
#   'accuracy_png': '/home/dellio/github/har-mcu/reports/xtinyhar/comparison/xtinyhar_comparison_accuracy.png',
#   'size_png': '/home/dellio/github/har-mcu/reports/xtinyhar/comparison/xtinyhar_comparison_size.png',
#   'latency_png': '/home/dellio/github/har-mcu/reports/xtinyhar/comparison/xtinyhar_comparison_latency.png'},
#  'master_exports': {'csv': '/home/dellio/github/har-mcu/reports/results_master.csv',
#   'md': '/home/dellio/github/har-mcu/reports/results_master.md'}}

# %%
# Standardized shared notebook report rendering
from src.eval.notebook_reporting import render_paper_notebook_report

notebook_report = render_paper_notebook_report(cfg, out, drift_tol=1e-9)
notebook_report
# Out:
#   paper_slug           protocol                  variant    run_id  \
# 0   xtinyhar  random_stratified  xtinyhar_student_conv2d  wisdm_r0
# 1   xtinyhar       user_holdout  xtinyhar_student_conv2d  wisdm_r0
#
#    window_size  seed compression_focus      run_mode train_device  \
# 0          200    42      ptq_qat_only  sanity_check          gpu
# 1          200    42      ptq_qat_only  sanity_check          gpu
#
#   eval_fp32_device  ...                                        deploy_gate  \
# 0              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
# 1              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
#
#   paper_target_score delta_vs_paper notes_assumptions  \
# 0               None           None              None
# 1               None           None              None
#
#                                    fp32_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/xtinyhar/x...
# 1  /home/dellio/github/har-mcu/reports/xtinyhar/x...
#
#                                     ptq_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/xtinyhar/p...
# 1  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#
#                                     qat_metrics_json  \
# 0  /home/dellio/github/har-mcu/reports/xtinyhar/q...
# 1  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#
#                                      ptq_report_json  \
# 0  /home/dellio/github/har-mcu/reports/xtinyhar/p...
# 1  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#
#                                      qat_report_json  \
# 0  /home/dellio/github/har-mcu/reports/xtinyhar/q...
# 1  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#
#                                    run_artifact_json
# 0  /home/dellio/github/har-mcu/reports/xtinyhar/a...
# 1  /home/dellio/github/har-mcu/reports/xtinyhar/a...
#
# [2 rows x 54 columns]
# <style type="text/css">
# </style>
# <table id="T_37c6e">
#   <caption>Model Size Summary (FP32 float .tflite, PTQ INT8, QAT INT8)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37c6e_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_37c6e_level0_col1" class="col_heading level0 col1" >fp32_model_size_kb</th>
#       <th id="T_37c6e_level0_col2" class="col_heading level0 col2" >ptq_model_size_kb</th>
#       <th id="T_37c6e_level0_col3" class="col_heading level0 col3" >qat_model_size_kb</th>
#       <th id="T_37c6e_level0_col4" class="col_heading level0 col4" >fp32_tflite_status</th>
#       <th id="T_37c6e_level0_col5" class="col_heading level0 col5" >fp32_tflite_model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37c6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37c6e_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_37c6e_row0_col1" class="data row0 col1" >320.54 KB</td>
#       <td id="T_37c6e_row0_col2" class="data row0 col2" >119.15 KB</td>
#       <td id="T_37c6e_row0_col3" class="data row0 col3" >119.59 KB</td>
#       <td id="T_37c6e_row0_col4" class="data row0 col4" >ok</td>
#       <td id="T_37c6e_row0_col5" class="data row0 col5" >/home/dellio/github/har-mcu/models_tflite/xtinyhar_student_conv2d_T200_Prandom_stratified_wisdm_r0_fp32.tflite</td>
#     </tr>
#     <tr>
#       <th id="T_37c6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37c6e_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_37c6e_row1_col1" class="data row1 col1" >320.84 KB</td>
#       <td id="T_37c6e_row1_col2" class="data row1 col2" >119.23 KB</td>
#       <td id="T_37c6e_row1_col3" class="data row1 col3" >119.59 KB</td>
#       <td id="T_37c6e_row1_col4" class="data row1 col4" >ok</td>
#       <td id="T_37c6e_row1_col5" class="data row1 col5" >/home/dellio/github/har-mcu/models_tflite/xtinyhar_student_conv2d_T200_Puser_holdout_wisdm_r0_fp32.tflite</td>
#     </tr>
#   </tbody>
# </table>
# Note: fp32_model_size_kb is measured from exported float .tflite per protocol.
#
# PTQ operator visibility (per protocol):
# - interpreter_ops: delegate-free runtime ops from PTQ TFLite evaluation metrics
# - tflm_ops: flatbuffer ops used by strict deploy-gate compatibility check
#
# [random_stratified]
#   interpreter_ops (19): ['ADD', 'BATCH_MATMUL', 'CONCATENATION', 'CONV_2D', 'FULLY_CONNECTED', 'GATHER', 'GELU', 'MEAN', 'MUL', 'PACK', 'REDUCE_PROD', 'RESHAPE', 'RSQRT', 'SHAPE', 'SOFTMAX', 'SQUARED_DIFFERENCE', 'STRIDED_SLICE', 'SUB', 'TRANSPOSE']
#   tflm_ops       (19): ['ADD', 'BATCH_MATMUL', 'CONCATENATION', 'CONV_2D', 'FULLY_CONNECTED', 'GATHER', 'GELU', 'MEAN', 'MUL', 'PACK', 'REDUCE_PROD', 'RESHAPE', 'RSQRT', 'SHAPE', 'SOFTMAX', 'SQUARED_DIFFERENCE', 'STRIDED_SLICE', 'SUB', 'TRANSPOSE']
#
# [user_holdout]
#   interpreter_ops (19): ['ADD', 'BATCH_MATMUL', 'CONCATENATION', 'CONV_2D', 'FULLY_CONNECTED', 'GATHER', 'GELU', 'MEAN', 'MUL', 'PACK', 'REDUCE_PROD', 'RESHAPE', 'RSQRT', 'SHAPE', 'SOFTMAX', 'SQUARED_DIFFERENCE', 'STRIDED_SLICE', 'SUB', 'TRANSPOSE']
#   tflm_ops       (19): ['ADD', 'BATCH_MATMUL', 'CONCATENATION', 'CONV_2D', 'FULLY_CONNECTED', 'GATHER', 'GELU', 'MEAN', 'MUL', 'PACK', 'REDUCE_PROD', 'RESHAPE', 'RSQRT', 'SHAPE', 'SOFTMAX', 'SQUARED_DIFFERENCE', 'STRIDED_SLICE', 'SUB', 'TRANSPOSE']
#
# Strict deploy-gate status summary:
# [random_stratified] ptq_status=failed | qat_status=failed
#   PTQ failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']
#     reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD
#   QAT failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']
#     reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD
# [user_holdout] ptq_status=failed | qat_status=failed
#   PTQ failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']
#     reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD
#   QAT failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']
#     reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD
#
# Strict Deploy-Gate Details (from export reports):
# <style type="text/css">
# </style>
# <table id="T_0d0b0">
#   <caption>Strict deploy-gate details per protocol/tier (PTQ, QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d0b0_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_0d0b0_level0_col1" class="col_heading level0 col1" >tier</th>
#       <th id="T_0d0b0_level0_col2" class="col_heading level0 col2" >status</th>
#       <th id="T_0d0b0_level0_col3" class="col_heading level0 col3" >full_integer_io</th>
#       <th id="T_0d0b0_level0_col4" class="col_heading level0 col4" >tflm_compatible</th>
#       <th id="T_0d0b0_level0_col5" class="col_heading level0 col5" >allowed_ops_profile</th>
#       <th id="T_0d0b0_level0_col6" class="col_heading level0 col6" >compatibility_scope</th>
#       <th id="T_0d0b0_level0_col7" class="col_heading level0 col7" >unsupported_ops_micro_mutable</th>
#       <th id="T_0d0b0_level0_col8" class="col_heading level0 col8" >possibly_supported_upstream_tflm</th>
#       <th id="T_0d0b0_level0_col9" class="col_heading level0 col9" >unsupported_in_reference</th>
#       <th id="T_0d0b0_level0_col10" class="col_heading level0 col10" >error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d0b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d0b0_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_0d0b0_row0_col1" class="data row0 col1" >PTQ</td>
#       <td id="T_0d0b0_row0_col2" class="data row0 col2" >failed</td>
#       <td id="T_0d0b0_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_0d0b0_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_0d0b0_row0_col5" class="data row0 col5" >micro_mutable_main</td>
#       <td id="T_0d0b0_row0_col6" class="data row0 col6" >micro_mutable_main</td>
#       <td id="T_0d0b0_row0_col7" class="data row0 col7" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_0d0b0_row0_col9" class="data row0 col9" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row0_col10" class="data row0 col10" >Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD</td>
#     </tr>
#     <tr>
#       <th id="T_0d0b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d0b0_row1_col0" class="data row1 col0" >random_stratified</td>
#       <td id="T_0d0b0_row1_col1" class="data row1 col1" >QAT</td>
#       <td id="T_0d0b0_row1_col2" class="data row1 col2" >failed</td>
#       <td id="T_0d0b0_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_0d0b0_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_0d0b0_row1_col5" class="data row1 col5" >micro_mutable_main</td>
#       <td id="T_0d0b0_row1_col6" class="data row1 col6" >micro_mutable_main</td>
#       <td id="T_0d0b0_row1_col7" class="data row1 col7" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_0d0b0_row1_col9" class="data row1 col9" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row1_col10" class="data row1 col10" >Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD</td>
#     </tr>
#     <tr>
#       <th id="T_0d0b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d0b0_row2_col0" class="data row2 col0" >user_holdout</td>
#       <td id="T_0d0b0_row2_col1" class="data row2 col1" >PTQ</td>
#       <td id="T_0d0b0_row2_col2" class="data row2 col2" >failed</td>
#       <td id="T_0d0b0_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_0d0b0_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_0d0b0_row2_col5" class="data row2 col5" >micro_mutable_main</td>
#       <td id="T_0d0b0_row2_col6" class="data row2 col6" >micro_mutable_main</td>
#       <td id="T_0d0b0_row2_col7" class="data row2 col7" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_0d0b0_row2_col9" class="data row2 col9" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row2_col10" class="data row2 col10" >Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD</td>
#     </tr>
#     <tr>
#       <th id="T_0d0b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d0b0_row3_col0" class="data row3 col0" >user_holdout</td>
#       <td id="T_0d0b0_row3_col1" class="data row3 col1" >QAT</td>
#       <td id="T_0d0b0_row3_col2" class="data row3 col2" >failed</td>
#       <td id="T_0d0b0_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_0d0b0_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_0d0b0_row3_col5" class="data row3 col5" >micro_mutable_main</td>
#       <td id="T_0d0b0_row3_col6" class="data row3 col6" >micro_mutable_main</td>
#       <td id="T_0d0b0_row3_col7" class="data row3 col7" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_0d0b0_row3_col9" class="data row3 col9" >GELU, REDUCE_PROD</td>
#       <td id="T_0d0b0_row3_col10" class="data row3 col10" >Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD</td>
#     </tr>
#   </tbody>
# </table>
# Note: if you changed model_variant/run_id, compare only current run rows and artifacts. Older files may still exist under reports/<paper_slug>/.
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:410: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   comparison_df.style.format(
# <style type="text/css">
# </style>
# <table id="T_79957">
#   <caption>Table 1 — Accuracy, macro F1, model size, timing, and accuracy delta vs paper target (baseline/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79957_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_79957_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_79957_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_79957_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_79957_level0_col4" class="col_heading level0 col4" >macro_f1</th>
#       <th id="T_79957_level0_col5" class="col_heading level0 col5" >model_size_kb</th>
#       <th id="T_79957_level0_col6" class="col_heading level0 col6" >training_time_sec</th>
#       <th id="T_79957_level0_col7" class="col_heading level0 col7" >inference_latency_ms_median</th>
#       <th id="T_79957_level0_col8" class="col_heading level0 col8" >inference_latency_ms_p95</th>
#       <th id="T_79957_level0_col9" class="col_heading level0 col9" >status</th>
#       <th id="T_79957_level0_col10" class="col_heading level0 col10" >ptq_status</th>
#       <th id="T_79957_level0_col11" class="col_heading level0 col11" >qat_status</th>
#       <th id="T_79957_level0_col12" class="col_heading level0 col12" >paper_target_accuracy</th>
#       <th id="T_79957_level0_col13" class="col_heading level0 col13" >acc_delta_vs_target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79957_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79957_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_79957_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_79957_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_79957_row0_col3" class="data row0 col3" >0.9189</td>
#       <td id="T_79957_row0_col4" class="data row0 col4" >0.8748</td>
#       <td id="T_79957_row0_col5" class="data row0 col5" >320.54</td>
#       <td id="T_79957_row0_col6" class="data row0 col6" >52.20s</td>
#       <td id="T_79957_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_79957_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_79957_row0_col9" class="data row0 col9" >ok</td>
#       <td id="T_79957_row0_col10" class="data row0 col10" >failed</td>
#       <td id="T_79957_row0_col11" class="data row0 col11" >failed</td>
#       <td id="T_79957_row0_col12" class="data row0 col12" >None</td>
#       <td id="T_79957_row0_col13" class="data row0 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_79957_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79957_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_79957_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_79957_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_79957_row1_col3" class="data row1 col3" >0.9186</td>
#       <td id="T_79957_row1_col4" class="data row1 col4" >0.8741</td>
#       <td id="T_79957_row1_col5" class="data row1 col5" >119.15</td>
#       <td id="T_79957_row1_col6" class="data row1 col6" >—</td>
#       <td id="T_79957_row1_col7" class="data row1 col7" >0.178ms</td>
#       <td id="T_79957_row1_col8" class="data row1 col8" >0.274ms</td>
#       <td id="T_79957_row1_col9" class="data row1 col9" >failed</td>
#       <td id="T_79957_row1_col10" class="data row1 col10" >failed</td>
#       <td id="T_79957_row1_col11" class="data row1 col11" >None</td>
#       <td id="T_79957_row1_col12" class="data row1 col12" >None</td>
#       <td id="T_79957_row1_col13" class="data row1 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_79957_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_79957_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_79957_row2_col1" class="data row2 col1" >random_stratified</td>
#       <td id="T_79957_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_79957_row2_col3" class="data row2 col3" >0.9365</td>
#       <td id="T_79957_row2_col4" class="data row2 col4" >0.9083</td>
#       <td id="T_79957_row2_col5" class="data row2 col5" >119.59</td>
#       <td id="T_79957_row2_col6" class="data row2 col6" >26.64s</td>
#       <td id="T_79957_row2_col7" class="data row2 col7" >0.177ms</td>
#       <td id="T_79957_row2_col8" class="data row2 col8" >0.210ms</td>
#       <td id="T_79957_row2_col9" class="data row2 col9" >failed</td>
#       <td id="T_79957_row2_col10" class="data row2 col10" >None</td>
#       <td id="T_79957_row2_col11" class="data row2 col11" >failed</td>
#       <td id="T_79957_row2_col12" class="data row2 col12" >None</td>
#       <td id="T_79957_row2_col13" class="data row2 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_79957_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_79957_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_79957_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_79957_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_79957_row3_col3" class="data row3 col3" >0.7686</td>
#       <td id="T_79957_row3_col4" class="data row3 col4" >0.6084</td>
#       <td id="T_79957_row3_col5" class="data row3 col5" >320.84</td>
#       <td id="T_79957_row3_col6" class="data row3 col6" >35.25s</td>
#       <td id="T_79957_row3_col7" class="data row3 col7" >—</td>
#       <td id="T_79957_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_79957_row3_col9" class="data row3 col9" >ok</td>
#       <td id="T_79957_row3_col10" class="data row3 col10" >failed</td>
#       <td id="T_79957_row3_col11" class="data row3 col11" >failed</td>
#       <td id="T_79957_row3_col12" class="data row3 col12" >None</td>
#       <td id="T_79957_row3_col13" class="data row3 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_79957_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_79957_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_79957_row4_col1" class="data row4 col1" >user_holdout</td>
#       <td id="T_79957_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_79957_row4_col3" class="data row4 col3" >0.7701</td>
#       <td id="T_79957_row4_col4" class="data row4 col4" >0.6118</td>
#       <td id="T_79957_row4_col5" class="data row4 col5" >119.23</td>
#       <td id="T_79957_row4_col6" class="data row4 col6" >—</td>
#       <td id="T_79957_row4_col7" class="data row4 col7" >0.184ms</td>
#       <td id="T_79957_row4_col8" class="data row4 col8" >0.291ms</td>
#       <td id="T_79957_row4_col9" class="data row4 col9" >failed</td>
#       <td id="T_79957_row4_col10" class="data row4 col10" >failed</td>
#       <td id="T_79957_row4_col11" class="data row4 col11" >None</td>
#       <td id="T_79957_row4_col12" class="data row4 col12" >None</td>
#       <td id="T_79957_row4_col13" class="data row4 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_79957_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_79957_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_79957_row5_col1" class="data row5 col1" >user_holdout</td>
#       <td id="T_79957_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_79957_row5_col3" class="data row5 col3" >0.7657</td>
#       <td id="T_79957_row5_col4" class="data row5 col4" >0.6526</td>
#       <td id="T_79957_row5_col5" class="data row5 col5" >119.59</td>
#       <td id="T_79957_row5_col6" class="data row5 col6" >27.20s</td>
#       <td id="T_79957_row5_col7" class="data row5 col7" >0.177ms</td>
#       <td id="T_79957_row5_col8" class="data row5 col8" >0.219ms</td>
#       <td id="T_79957_row5_col9" class="data row5 col9" >failed</td>
#       <td id="T_79957_row5_col10" class="data row5 col10" >None</td>
#       <td id="T_79957_row5_col11" class="data row5 col11" >failed</td>
#       <td id="T_79957_row5_col12" class="data row5 col12" >None</td>
#       <td id="T_79957_row5_col13" class="data row5 col13" >—</td>
#     </tr>
#     <tr>
#       <th id="T_79957
# Note: Paper-target QAT may be unavailable in source papers; QAT rows here are replication extensions where target is N/A.
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:281: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# <style type="text/css">
# </style>
# <table id="T_f9740">
#   <caption>Table 2 — Model size (FP32/PTQ/QAT)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9740_level0_col0" class="col_heading level0 col0" >pipeline</th>
#       <th id="T_f9740_level0_col1" class="col_heading level0 col1" >protocol</th>
#       <th id="T_f9740_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_f9740_level0_col3" class="col_heading level0 col3" >model_size_kb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9740_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9740_row0_col0" class="data row0 col0" >WISDM replication</td>
#       <td id="T_f9740_row0_col1" class="data row0 col1" >random_stratified</td>
#       <td id="T_f9740_row0_col2" class="data row0 col2" >baseline float</td>
#       <td id="T_f9740_row0_col3" class="data row0 col3" >320.54 KB</td>
#     </tr>
#     <tr>
#       <th id="T_f9740_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9740_row1_col0" class="data row1 col0" >WISDM replication</td>
#       <td id="T_f9740_row1_col1" class="data row1 col1" >random_stratified</td>
#       <td id="T_f9740_row1_col2" class="data row1 col2" >PTQ int8</td>
#       <td id="T_f9740_row1_col3" class="data row1 col3" >119.15 KB</td>
#     </tr>
#     <tr>
#       <th id="T_f9740_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9740_row2_col0" class="data row2 col0" >WISDM replication</td>
#       <td id="T_f9740_row2_col1" class="data row2 col1" >random_stratified</td>
#       <td id="T_f9740_row2_col2" class="data row2 col2" >QAT int8</td>
#       <td id="T_f9740_row2_col3" class="data row2 col3" >119.59 KB</td>
#     </tr>
#     <tr>
#       <th id="T_f9740_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9740_row3_col0" class="data row3 col0" >WISDM replication</td>
#       <td id="T_f9740_row3_col1" class="data row3 col1" >user_holdout</td>
#       <td id="T_f9740_row3_col2" class="data row3 col2" >baseline float</td>
#       <td id="T_f9740_row3_col3" class="data row3 col3" >320.84 KB</td>
#     </tr>
#     <tr>
#       <th id="T_f9740_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9740_row4_col0" class="data row4 col0" >WISDM replication</td>
#       <td id="T_f9740_row4_col1" class="data row4 col1" >user_holdout</td>
#       <td id="T_f9740_row4_col2" class="data row4 col2" >PTQ int8</td>
#       <td id="T_f9740_row4_col3" class="data row4 col3" >119.23 KB</td>
#     </tr>
#     <tr>
#       <th id="T_f9740_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9740_row5_col0" class="data row5 col0" >WISDM replication</td>
#       <td id="T_f9740_row5_col1" class="data row5 col1" >user_holdout</td>
#       <td id="T_f9740_row5_col2" class="data row5 col2" >QAT int8</td>
#       <td id="T_f9740_row5_col3" class="data row5 col3" >119.59 KB</td>
#     </tr>
#   </tbody>
# </table>
# Reproducibility drift — WISDM replication (repeat evaluation on saved checkpoint):
# /home/dellio/github/har-mcu/src/eval/notebook_reporting.py:439: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   reproducibility_df[
# <style type="text/css">
# #T_e5496_row0_col5, #T_e5496_row1_col5 {
#   color: green;
# }
# </style>
# <table id="T_e5496">
#   <caption>Table 3 — Reproducibility drift (two consecutive FP32 evaluations)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5496_level0_col0" class="col_heading level0 col0" >protocol</th>
#       <th id="T_e5496_level0_col1" class="col_heading level0 col1" >split_hash</th>
#       <th id="T_e5496_level0_col2" class="col_heading level0 col2" >baseline_acc_first</th>
#       <th id="T_e5496_level0_col3" class="col_heading level0 col3" >baseline_acc_repeat</th>
#       <th id="T_e5496_level0_col4" class="col_heading level0 col4" >abs_drift</th>
#       <th id="T_e5496_level0_col5" class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5496_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5496_row0_col0" class="data row0 col0" >random_stratified</td>
#       <td id="T_e5496_row0_col1" class="data row0 col1" >68c9e31789bca103</td>
#       <td id="T_e5496_row0_col2" class="data row0 col2" >0.9189</td>
#       <td id="T_e5496_row0_col3" class="data row0 col3" >0.9189</td>
#       <td id="T_e5496_row0_col4" class="data row0 col4" >0.00e+00</td>
#       <td id="T_e5496_row0_col5" class="data row0 col5" >PASS</td>
#     </tr>
#     <tr>
#       <th id="T_e5496_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5496_row1_col0" class="data row1 col0" >user_holdout</td>
#       <td id="T_e5496_row1_col1" class="data row1 col1" >2498bff9ddcfc589</td>
#       <td id="T_e5496_row1_col2" class="data row1 col2" >0.7686</td>
#       <td id="T_e5496_row1_col3" class="data row1 col3" >0.7686</td>
#       <td id="T_e5496_row1_col4" class="data row1 col4" >0.00e+00</td>
#       <td id="T_e5496_row1_col5" class="data row1 col5" >PASS</td>
#     </tr>
#   </tbody>
# </table>
# ### Protocol: `random_stratified`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Protocol: `user_holdout`
# **FP32 training curve**
# **QAT training curve**
# **FP32 confusion**
# **PTQ confusion**
# **QAT confusion**
# ### Classification Report Snippets — `random_stratified`
# FP32: macro_f1=0.8748371963957752, weighted_f1=0.9150911131430893
# PTQ: macro_f1=0.8741101749999727, weighted_f1=0.9145835683670613
# QAT: macro_f1=0.908275252200763, weighted_f1=0.9355345875555964
# ### Classification Report Snippets — `user_holdout`
# FP32: macro_f1=0.6084267116743621, weighted_f1=0.7540546152115729
# PTQ: macro_f1=0.611842800307793, weighted_f1=0.754905729616172
# QAT: macro_f1=0.6525526800191249, weighted_f1=0.7673906228882417
# ## Saved Comparison CSV Snapshot
#             pipeline           protocol           model  accuracy  macro_f1  \
# 0  WISDM replication  random_stratified  baseline float  0.918894  0.874837
# 1  WISDM replication  random_stratified        PTQ int8  0.918591  0.874110
# 2  WISDM replication  random_stratified        QAT int8  0.936513  0.908275
# 3  WISDM replication       user_holdout  baseline float  0.768622  0.608427
# 4  WISDM replication       user_holdout        PTQ int8  0.770088  0.611843
# 5  WISDM replication       user_holdout        QAT int8  0.765689  0.652553
# 6       paper target                  —  baseline float       NaN       NaN
# 7       paper target                  —        PTQ int8       NaN       NaN
# 8       paper target                  —        QAT int8       NaN       NaN
#
#    model_size_kb  training_time_sec  inference_latency_ms_median  \
# 0     320.539062          52.201736                          NaN
# 1     119.148438                NaN                     0.178238
# 2     119.585938          26.643862                     0.177068
# 3     320.843750          35.252740                          NaN
# 4     119.234375                NaN                     0.183738
# 5     119.585938          27.204163                     0.176664
# 6            NaN                NaN                          NaN
# 7            NaN                NaN                          NaN
# 8            NaN                NaN                          NaN
#
#    inference_latency_ms_p95     status ptq_status qat_status  \
# 0                       NaN         ok     failed     failed
# 1                  0.274273     failed     failed        NaN
# 2                  0.209851     failed        NaN     failed
# 3                       NaN         ok     failed     failed
# 4                  0.291393     failed     failed        NaN
# 5                  0.219428     failed        NaN     failed
# 6                       NaN  reference        NaN        NaN
# 7                       NaN  reference        NaN        NaN
# 8                       NaN  reference        NaN        NaN
#
#    paper_target_accuracy  acc_delta_vs_target
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                    NaN                  NaN
# 7                    NaN                  NaN
# 8                    NaN                  NaN
# ## Master Results Snapshot
#    paper_slug           protocol                  variant    run_id  \
# 10   xtinyhar  random_stratified  xtinyhar_student_conv2d  wisdm_r0
# 11   xtinyhar       user_holdout  xtinyhar_student_conv2d  wisdm_r0
#
#     window_size  seed compression_focus      run_mode train_device  \
# 10          200    42      ptq_qat_only  sanity_check          gpu
# 11          200    42      ptq_qat_only  sanity_check          gpu
#
#    eval_fp32_device  ...                                   qat_metrics_json  \
# 10              gpu  ...  /home/dellio/github/har-mcu/reports/xtinyhar/q...
# 11              gpu  ...  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#
#                                       ptq_report_json  \
# 10  /home/dellio/github/har-mcu/reports/xtinyhar/p...
# 11  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#
#                                       qat_report_json  \
# 10  /home/dellio/github/har-mcu/reports/xtinyhar/q...
# 11  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#
#                                     run_artifact_json  \
# 10  /home/dellio/github/har-mcu/reports/xtinyhar/a...
# 11  /home/dellio/github/har-mcu/reports/xtinyhar/a...
#
#     ptq_allowed_ops_profile  qat_allowed_ops_profile  fp32_model_size_kb  \
# 10       micro_mutable_main       micro_mutable_main          320.539062
# 11       micro_mutable_main       micro_mutable_main          320.843750
#
#                                     fp32_tflite_model fp32_tflite_status  \
# 10  /home/dellio/github/har-mcu/models_tflite/xtin...                 ok
# 11  /home/dellio/github/har-mcu/models_tflite/xtin...                 ok
#
#    fp32_tflite_error
# 10               NaN
# 11               NaN
#
# [2 rows x 54 columns]
# Saved outputs root: /home/dellio/github/har-mcu/reports/xtinyhar
# {'rows_df':   paper_slug           protocol                  variant    run_id  \
#  0   xtinyhar  random_stratified  xtinyhar_student_conv2d  wisdm_r0
#  1   xtinyhar       user_holdout  xtinyhar_student_conv2d  wisdm_r0
#
#     window_size  seed compression_focus      run_mode train_device  \
#  0          200    42      ptq_qat_only  sanity_check          gpu
#  1          200    42      ptq_qat_only  sanity_check          gpu
#
#    eval_fp32_device  ...                                        deploy_gate  \
#  0              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
#  1              gpu  ...  {'ptq': {'status': 'failed', 'full_integer_io'...
#
#    paper_target_score delta_vs_paper notes_assumptions  \
#  0               None           None              None
#  1               None           None              None
#
#                                     fp32_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/xtinyhar/x...
#  1  /home/dellio/github/har-mcu/reports/xtinyhar/x...
#
#                                      ptq_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#  1  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#
#                                      qat_metrics_json  \
#  0  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#  1  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#
#                                       ptq_report_json  \
#  0  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#  1  /home/dellio/github/har-mcu/reports/xtinyhar/p...
#
#                                       qat_report_json  \
#  0  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#  1  /home/dellio/github/har-mcu/reports/xtinyhar/q...
#
#                                     run_artifact_json
#  0  /home/dellio/github/har-mcu/reports/xtinyhar/a...
#  1  /home/dellio/github/har-mcu/reports/xtinyhar/a...
#
#  [2 rows x 54 columns],
#  'ptq_operator_visibility': [{'protocol': 'random_stratified',
#    'interpreter_ops': ['ADD',
#     'BATCH_MATMUL',
#     'CONCATENATION',
#     'CONV_2D',
#     'FULLY_CONNECTED',
#     'GATHER',
#     'GELU',
#     'MEAN',
#     'MUL',
#     'PACK',
#     'REDUCE_PROD',
#     'RESHAPE',
#     'RSQRT',
#     'SHAPE',
#     'SOFTMAX',
#     'SQUARED_DIFFERENCE',
#     'STRIDED_SLICE',
#     'SUB',
#     'TRANSPOSE'],
#    'tflm_ops': ['ADD',
#     'BATCH_MATMUL',
#     'CONCATENATION',
#     'CONV_2D',
#     'FULLY_CONNECTED',
#     'GATHER',
#     'GELU',
#     'MEAN',
#     'MUL',
#     'PACK',
#     'REDUCE_PROD',
#     'RESHAPE',
#     'RSQRT',
#     'SHAPE',
#     'SOFTMAX',
#     'SQUARED_DIFFERENCE',
#     'STRIDED_SLICE',
#     'SUB',
#     'TRANSPOSE'],
#    'only_interpreter': [],
#    'only_tflm': []},
#   {'protocol': 'user_holdout',
#    'interpreter_ops': ['ADD',
#     'BATCH_MATMUL',
#     'CONCATENATION',
#     'CONV_2D',
#     'FULLY_CONNECTED',
#     'GATHER',
#     'GELU',
#     'MEAN',
#     'MUL',
#     'PACK',
#     'REDUCE_PROD',
#     'RESHAPE',
#     'RSQRT',
#     'SHAPE',
#     'SOFTMAX',
#     'SQUARED_DIFFERENCE',
#     'STRIDED_SLICE',
#     'SUB',
#     'TRANSPOSE'],
#    'tflm_ops': ['ADD',
#     'BATCH_MATMUL',
#     'CONCATENATION',
#     'CONV_2D',
#     'FULLY_CONNECTED',
#     'GATHER',
#     'GELU',
#     'MEAN',
#     'MUL',
#     'PACK',
#     'REDUCE_PROD',
#     'RESHAPE',
#     'RSQRT',
#     'SHAPE',
#     'SOFTMAX',
#     'SQUARED_DIFFERENCE',
#     'STRIDED_SLICE',
#     'SUB',
#     'TRANSPOSE'],
#    'only_interpreter': [],
#    'only_tflm': []}],
#  'ptq_operator_warnings': [],
#  'strict_deploy_df':             protocol tier  status  full_integer_io  tflm_compatible  \
#  0  random_stratified  PTQ  failed             True            False
#  1  random_stratified  QAT  failed             True            False
#  2       user_holdout  PTQ  failed             True            False
#  3       user_holdout  QAT  failed             True            False
#
#    allowed_ops_profile compatibility_scope unsupported_ops_micro_mutable  \
#  0  micro_mutable_main  micro_mutable_main             GELU, REDUCE_PROD
#  1  micro_mutable_main  micro_mutable_main             GELU, REDUCE_PROD
#  2  micro_mutable_main  micro_mutable_main             GELU, REDUCE_PROD
#  3  micro_mutable_main  micro_mutable_main             GELU, REDUCE_PROD
#
#    possibly_supported_upstream_tflm unsupported_in_reference  \
#  0                             None        GELU, REDUCE_PROD
#  1                             None        GELU, REDUCE_PROD
#  2                             None        GELU, REDUCE_PROD
#  3                             None        GELU, REDUCE_PROD
#
#                                                 error
#  0  Unsupported ops for micro_mutable_op_resolver....
#  1  Unsupported ops for micro_mutable_op_resolver....
#  2  Unsupported ops for micro_mutable_op_resolver....
#  3  Unsupported ops for micro_mutable_op_resolver....  ,
#  'legacy_artifact_detected': False,
#  'strict_summary_lines': ['[random_stratified] ptq_status=failed | qat_status=failed',
#   "  PTQ failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']",
#   '    reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD',
#   "  QAT failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']",
#   '    reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD',
#   '[user_holdout] ptq_status=failed | qat_status=failed',
#   "  PTQ failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']",
#   '    reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD',
#   "  QAT failed under compatibility_scope=micro_mutable_main; unsupported_ops=['GELU', 'REDUCE_PROD']",
#   '    reason: Unsupported ops for micro_mutable_op_resolver.h source: GELU, REDUCE_PROD'],
#  'comparison_df':             pipeline           protocol           model  accuracy  macro_f1  \
#  0  WISDM replication  random_stratified  baseline float  0.918894  0.874837
#  1  WISDM replication  random_stratified        PTQ int8  0.918591  0.874110
#  2  WISDM replication  random_stratified        QAT int8  0.936513  0.908275
#  3  WISDM replication       user_holdout  baseline float  0.768622  0.608427
#  4  WISDM replication       user_holdout        PTQ int8  0.770088  0.611843
#  5  WISDM replication       user_holdout        QAT int8  0.765689  0.652553
#  6       paper target                  —  baseline float       NaN       NaN
#  7       paper target                  —        PTQ int8       NaN       NaN
#  8       paper target                  —        QAT int8       NaN       NaN
#
#     model_size_kb  training_time_sec  inference_latency_ms_median  \
#  0     320.539062          52.201736                          NaN
#  1     119.148438                NaN                     0.178238
#  2     119.585938          26.643862                     0.177068
#  3     320.843750          35.252740                          NaN
#  4     119.234375                NaN                     0.183738
#  5     119.585938          27.204163                     0.176664
#  6            NaN                NaN                          NaN
#  7            NaN                NaN                          NaN
#  8            NaN                NaN                          NaN
#
#     inference_latency_ms_p95     status ptq_status qat_status  \
#  0                       NaN         ok     failed     failed
#  1                  0.274273     failed     failed       None
#  2                  0.209851     failed       None     failed
#  3                       NaN         ok     failed     failed
#  4                  0.291393     failed     failed       None
#  5                  0.219428     failed       None     failed
#  6                       NaN  reference       None       None
#  7                       NaN  reference       None       None
#  8                       NaN  reference       None       None
#
#    paper_target_accuracy acc_delta_vs_target
#  0                  None                None
#  1                  None                None
#  2                  None                None
#  3                  None                None
#  4                  None                None
#  5                  None                None
#  6                  None                None
#  7                  None                None
#  8                  None                None  ,
#  'reproducibility_df':             protocol        split_hash  baseline_acc_first  \
#  0  random_stratified  68c9e31789bca103            0.918894
#  1       user_holdout  2498bff9ddcfc589            0.768622
#
#     baseline_acc_repeat  abs_drift status
#  0             0.918894        0.0   PASS
#  1             0.768622        0.0   PASS  }

# %% [markdown]
# ## Notes
# - If QAT conversion fails strict deploy-gate checks, results are still exported with explicit failure reason.
# - Document unresolved paper ambiguities in `reports/paper_specs_<slug>.md`.
